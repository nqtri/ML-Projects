# %% [markdown]
# # Web-Scraping on SSENSE.COM - Men's

# %%
#Importing packages

from bs4 import BeautifulSoup
import requests
import json
from time import sleep

# %% [markdown]
# ## Getting a sense of HTML codes on the site

# %%
mens_page = requests.get("https://ssense.com/en-ca/men")
mens_soup = BeautifulSoup(mens_page.content, 'html.parser')

print(mens_soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-ca">
#  <head>
#   <meta content="en" name="language"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    Designer Clothes, Shoes &amp; Bags for Men | SSENSE Canada
#   </title>
#   <meta content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=no,minimal-ui" name="viewport"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <script type="text/javascript">
#    window.NREUM||(NREUM={});NREUM.info = {"agent":"","beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"901b49cf57","applicationID":"233360527","applicationTime":6.813033,"transactionName":"ZlFbYEBRXkdWV0wPDV8bfExCQlVHRF5LSSV0YBYbV14dDlRbTQgWQ00WWVde","queueTime":0,"ttGuid":"4be32fe704e050","agentToken":null}; (window.NREUM||(NREUM={})).loader_config={xpid:"VQIGUVBaCBACV1JRAQECVFM=",licenseKey:"901b49cf57",applicationID:"233360527"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{s.console&&console.log(t)}catch(e){}}var o,i=t("ee"),a=t(24),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,e,n){r(n.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,s){try{l?l-=1:o(s||new UncaughtException(t,e,n),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function o(t,e){var n=e?null:c.now();i("err",[t,n])}var i=t("handle"),a=t(25),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,p="nr@seenError",l=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(13),t(12),"addEventListener"in window&&t(6),c.xhrWrappable&&t(14),d=!0)}s.on("fn-start",function(t,e,n){d&&(l+=1)}),s.on("fn-err",function(t,e,n){d&&!n[p]&&(f(n,p,function(){return!0}),this.thrown=!0,o(n))}),s.on("fn-end",function(){d&&!this.thrown&&l>0&&(l-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})},{}],3:[function(t,e,n){t("loader").features.ins=!0},{}],4:[function(t,e,n){function r(){L++,C=g.hash,this[u]=y.now()}function o(){L--,g.hash!==C&&i(0,!0);var t=y.now();this[h]=~~this[h]+t-this[u],this[d]=t}function i(t,e){E.emit("newURL",[""+g,e])}function a(t,e){t.on(e,function(){this[e]=y.now()})}var s="-start",c="-end",f="-body",u="fn"+s,d="fn"+c,p="cb"+s,l="cb"+c,h="jsTime",m="fetch",v="addEventListener",w=window,g=w.location,y=t("loader");if(w[v]&&y.xhrWrappable){var x=t(10),b=t(11),E=t(8),R=t(6),O=t(13),N=t(7),P=t(14),M=t(9),T=t("ee"),S=T.get("tracer");t(16),y.features.spa=!0;var C,L=0;T.on(u,r),T.on(p,r),T.on(d,o),T.on(l,o),T.buffer([u,d,"xhr-done","xhr-resolved"]),R.buffer([u]),O.buffer(["setTimeout"+c,"clearTimeout"+s,u]),P.buffer([u,"new-xhr","send-xhr"+s]),N.buffer([m+s,m+"-done",m+f+s,m+f+c]),E.buffer(["newURL"]),x.buffer([u]),b.buffer(["propagate",p,l,"executor-err","resolve"+s]),S.buffer([u,"no-"+u]),M.buffer(["new-jsonp","cb-start","jsonp-error","jsonp-end"]),a(P,"send-xhr"+s),a(T,"xhr-resolved"),a(T,"xhr-done"),a(N,m+s),a(N,m+"-done"),a(M,"new-jsonp"),a(M,"jsonp-end"),a(M,"cb-start"),E.on("pushState-end",i),E.on("replaceState-end",i),w[v]("hashchange",i,!0),w[v]("load",i,!0),w[v]("popstate",function(){i(0,L>1)},!0)}},{}],5:[function(t,e,n){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(13),s=t(12),c="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",p="resource",l="-start",h="-end",m="fn"+l,v="fn"+h,w="bstTimer",g="pushState",y=t("loader");y.features.stn=!0,t(8),"addEventListener"in window&&t(6);var x=NREUM.o.EV;o.on(m,function(t,e){var n=t[0];n instanceof x&&(this.bstStart=y.now())}),o.on(v,function(t,e){var n=t[0];n instanceof x&&i("bst",[n,e,this.bstStart,y.now()])}),a.on(m,fu ...
#   </script>
#   <meta content="SSENSE" name="author"/>
#   <meta content="Buy designer clothing &amp; accessories and get Free Shipping &amp; Returns in Canada. Shop the latest FW19 collection of designer for Men on SSENSE.com. Find what you are looking for amongst our directional selection of designer fashion and luxury streetwear." name="description"/>
#   <link href="//beacon.riskified.com" rel="dns-prefetch"/>
#   <link href="//c.riskified.com" rel="dns-prefetch"/>
#   <link href="//googleads.g.doubleclick.net" rel="dns-prefetch"/>
#   <link href="//stats.g.doubleclick.net" rel="dns-prefetch"/>
#   <link href="//www.google-analytics.com" rel="dns-prefetch"/>
#   <link href="//www.google.ca" rel="dns-prefetch"/>
#   <link href="//www.google.com" rel="dns-prefetch"/>
#   <link href="//www.googleadservices.com" rel="dns-prefetch"/>
#   <link href="//bat.bing.com" rel="dns-prefetch"/>
#   <link href="//connect.facebook.net" rel="dns-prefetch"/>
#   <link href="//res.cloudinary.com" rel="preconnect"/>
#   <link href="//res-1.cloudinary.com" rel="preconnect"/>
#   <link href="//res-2.cloudinary.com" rel="preconnect"/>
#   <link href="//res-3.cloudinary.com" rel="preconnect"/>
#   <link href="//res-4.cloudinary.com" rel="preconnect"/>
#   <link href="//res-5.cloudinary.com" rel="preconnect"/>
#   <link href="https://www.ssense.com/en-ca/men" rel="canonical"/>
#   <link href="https://www.ssense.com/en-ca/men/opensearch.xml" rel="search" title="SSENSE Search Men" type="application/opensearchdescription+xml"/>
#   <link href="https://www.ssense.com/en-ca/women/opensearch.xml" rel="search" title="SSENSE Search Women" type="application/opensearchdescription+xml"/>
#   <link href="https://www.ssense.com/en-ca/en-ca/men?page=2" rel="next"/>
#   <link href="https://www.ssense.com/en-us/men" hreflang="en-us" rel="alternate"/>
#   <link href="https://www.ssense.com/en-ca/men" hreflang="en-ca" rel="alternate"/>
#   <link href="https://www.ssense.com/en-gb/men" hreflang="en-gb" rel="alternate"/>
#   <link href="https://www.ssense.com/ja-jp/men" hreflang="ja-jp" rel="alternate"/>
#   <link href="https://www.ssense.com/fr-fr/hommes" hreflang="fr-fr" rel="alternate"/>
#   <link href="https://www.ssense.com/zh-cn/men" hreflang="zh-Hans-cn" rel="alternate"/>
#   <link href="https://www.ssense.com/en-us/men" hreflang="en" rel="alternate"/>
#   <link href="https://www.ssense.com/ja-jp/men" hreflang="ja" rel="alternate"/>
#   <link href="https://www.ssense.com/fr-fr/hommes" hreflang="fr" rel="alternate"/>
#   <link href="https://www.ssense.com/zh-cn/men" hreflang="zh-Hans" rel="alternate"/>
#   <link href="//res.cloudinary.com/ssenseweb/image/upload/v1472005257/web/favicon.ico" rel="icon" type="image/x-icon"/>
#   <link href="//img.ssensemedia.com/image/upload/v1574192255/favicon_ssense/favicon-16x16_byyzld.png" rel="shortcut icon" type="image/png"/>
#   <link href="//img.ssensemedia.com/image/upload/v1574192255/favicon_ssense/favicon-16x16_byyzld.png" rel="apple-touch-icon"/>
#   <link href="//img.ssensemedia.com/image/upload/v1574192255/favicon_ssense/apple-touch-icon-57x57_prssda.png" rel="apple-touch-icon" sizes="57x57"/>
#   <link href="//img.ssensemedia.com/image/upload/v1574192255/favicon_ssense/apple-touch-icon-114x114_uep0gt.png" rel="apple-touch-icon" sizes="114x114"/>
#   <link href="//img.ssensemedia.com/image/upload/v1574192255/favicon_ssense/apple-touch-icon-72x72_h1wgtx.png" rel="apple-touch-icon" sizes="72x72"/>
#   <link href="//img.ssensemedia.com/image/upload/v1574192254/favicon_ssense/mstile-144x144_x0cjmg.png" rel="apple-touch-icon" sizes="144x144"/>
#   <link href="//img.ssensemedia.com/image/upload/v1574192255/favicon_ssense/apple-touch-icon-60x60_rasic3.png" rel="apple-touch-icon" sizes="60x60"/>
#   <link href="//img.ssensemedia.com/image/upload/v1574192254/favicon_ssense/mstile-70x70_zaidh0.png" rel="apple-touch-icon" sizes="70x70"/>
#   <link href="//img.ssensemedia.com/image/upload/v1574192254/favicon_ssense/apple-touch-icon-120x120_sdj78o.png" rel="apple-touch-icon" sizes="120x120"/>
#   <link href="//img.ssensemedia.com/image/upload/v1574192255/favicon_ssense/apple-touch-icon-76x76_r9mdrx.png" rel="apple-touch-icon" sizes="76x76"/>
#   <link href="//img.ssensemedia.com/image/upload/v1574192254/favicon_ssense/mstile-150x150_aawpmj.png" rel="apple-touch-icon" sizes="150x150"/>
#   <link href="//img.ssensemedia.com/image/upload/v1574192254/favicon_ssense/apple-touch-icon-152x152_b8pday.png" rel="apple-touch-icon" sizes="152x152"/>
#   <link href="//img.ssensemedia.com/image/upload/v1574192255/favicon_ssense/favicon-196x196_vvei5a.png" rel="icon" sizes="196x196"/>
#   <link href="//img.ssensemedia.com/image/upload/v1574192254/favicon_ssense/mstile-150x150_aawpmj.png" rel="icon" sizes="150x150"/>
#   <link href="//img.ssensemedia.com/image/upload/v1574192255/favicon_ssense/favicon-96x96_f2fnwr.png" rel="icon" sizes="96x96"/>
#   <link href="//img.ssensemedia.com/image/upload/v1574192255/favicon_ssense/favicon-16x16_byyzld.png" rel="icon" sizes="16x16"/>
#   <link href="//img.ssensemedia.com/image/upload/v1574192255/favicon_ssense/favicon-32x32_sdslfh.png" rel="icon" sizes="32x32"/>
#   <link href="/assets/app.2d99c1d4b15b4ea364bd38a424126182.css" rel="stylesheet" type="text/css"/>
#   <!--  Hide retargeting iframe -->
#   <style type="text/css">
#    iframe[name="google_conversion_frame"] { display:none; }
#   </style>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=AW-1063827787">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#   function gtag() {
#     dataLayer.push(arguments);
#   }
#   gtag('js', new Date());
#   gtag('config', 'AW-1063827787', { 'send_page_view': false });
#   </script>
#   <!--
#   script enabled:
#   Add here the <script> portion of tracking
#   -->
#   <script>
#    // ----------------------------------------------
#   // Google Analytics initialization
#   // ----------------------------------------------
#   window.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new Date;
#
#   // Method to parse cookie value and set to window property
#   // params:
#   // cookieName: name of cookie to parse (string)
#   // nullReturnValue: what to set if cookie doesn't exist (any)
#   function getCookie(cookieName, nullReturnValue) {
#      return document.cookie.split('; ').filter(
#          function(pair){
#              return pair.indexOf(cookieName + '=') == 0 })[0] ?
#           document.cookie.split('; ').filter(
#               function(pair){
#                   return pair.indexOf(cookieName + '=') == 0 })[0].split('=')[1]
#           : nullReturnValue;
#   }
#
#   window.trackingId = getCookie('trackingId', null);
#   window.guestExperimentStatus = getCookie('guest_checkout_enabled', 'no-cookie');
#
#   try {
#     ga('create', 'UA-519637-1', {'siteSpeedSampleRate': 100});
#     if (window.trackingId){
#       ga('set', 'dimension9', window.trackingId);
#     }
#     // Dimension 10 is the new custom dimension to track conversion on legacy stack and legacy/new hybrid stack
#     ga('set', 'dimension10', '1');
#
#     // send value of guest checkout cookie to ga
#     if(window.guestExperimentStatus) {
#       ga('set', 'dimension18', window.guestExperimentStatus);
#     }
#     ga('require', 'ecommerce');
#     ga('require', 'eventTracker');
#     ga('require', 'outboundLinkTracker');
#     ga('require', 'urlChangeTracker');
#     ga('send', 'pageview');
#   } catch (e) {
#     // Rethrow errors from external scripts due to Same-Origin Policy
#     throw e;
#   }
#
#   /**
#    * Utils function to inject script src tag
#    */
#   function injectScript(src, supportsCors, onload) {
#     var head = document.getElementsByTagName('head')[0],
#         script = document.createElement('script');
#
#     script.type = 'text/javascript';
#     script.src = src;
#     script.onload = onload || function() {};
#
#     if (supportsCors) {
#       script.crossOrigin = 'anonymous';
#     }
#
#     head.appendChild(script);
#   }
#
#   // -------------------
#   // Riskified Beacon
#   // ----------------------------------------------
#   window.riskifiedBeaconLoad = function(sid) {
#       var store_domain = 'ssense.com';
#       var url = ('https:' == document.location.protocol ? 'https://' : 'http://') + "beacon.riskified.com?shop="+store_domain + "&sid="+sid;
#       var s = document.createElement('script');
#       s.type = 'text/javascript';
#       s.async = true;
#       s.defer = true;
#       s.src = url;
#       s.crossOrigin = "anonymous";
#       var x = document.getElementsByTagName('script')[0];
#       x.parentNode.insertBefore(s, x);
#   };
#
#   /**
#    * Initialize tracking when page is loaded
#    */
#   window.addEventListener('load', function(event) {
#     // -------------------
#     // Google Analytics
#     // ----------------------------------------------
#     injectScript('//www.google-analytics.com/analytics.js', false);
#
#     injectScript('//cdnjs.cloudflare.com/ajax/libs/autotrack/1.0.1/autotrack.js', true);
#   });
#   </script>
#   <!-- No script:Add here the <noscript> portion of tracking -->
#   <noscript>
#    <!-- Google Conversion -->
#    <div style="display:inline">
#     <img alt="" height="1" src="//googleads.g.doubleclick.net/pagead/viewthroughconversion/1063827787/?value=0&amp;label=IFM5CImLwQMQy_Ki-wM&amp;guid=ON&amp;script=0" style="border-style:none" width="1"/>
#    </div>
#    <!-- Bing ads -->
#    <img alt="" height="0" src="//bat.bing.com/action/0?ti=4008316&amp;Ver=2" style="display:none; visibility: hidden" width="0"/>
#    <!-- Facebook pixel code -->
#    <img alt="" height="1" src="https://www.facebook.com/tr?id=1084416341572353&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
#   </noscript>
#  </head>
#  <body>
#   <script type="text/javascript">
#    /* We do not support all browsers; When a user is using one of these
#   unsupported browsers show them a warning. */
#
#   (function() {
#
#     /* Browsers with HTMLPictureElement defined should be modern enough to
#     support everything we do [1]. Exceptions are IE 10-12 and Safari 8 which
#     we support via an HTMLPictureElement polyfill, but adds support for many
#     browsers including those we do not want to support (ie9, Safari7, ...).
#     Thus we must find another way to not-warn said exceptions. We do this by
#     UA sniffing (gasp)[2].
#
#     [1] http://caniuse.com/#feat=picture
#     [2] For details on our regex see http://regexr.com/3emos. */
#
#     var polyfilledUserAgents = /MSIE 10|MSIE 11|IE 11|Trident.*rv:11|WOW64;.*rv:11|Edge\/12|AppleWebKit.*Version\/(:?8|9\.0|9\.1|9\.2)/;
#
#     var isSupported = window.HTMLPictureElement
#                    || polyfilledUserAgents.test(navigator.userAgent);
#
#     if (!isSupported) {
#       var div = document.createElement("div");
#       div.innerHTML = "Sorry, your browser is not supported. You may experience some difficulties when shopping on SSENSE.";
#       div.className = "message-box failed";
#       div.style.position = "relative"; // [1]
#       div.style.opacity = "1"; // [2]
#       div.onclick = function () { document.body.removeChild(div); };
#       document.body.insertBefore(div, document.body.firstChild); // [3]
#
#       /*
#       [1] .message-box is `position: fixed` so it "hovers" over body content,
#       but we want this warning to push body content down instead.
#
#       [2] .message-box is designed to be faded in by our JS app, but we cannot
#       rely on any external JS here, so force opacity to 100%.
#
#       [3] If firstChild is `null` then `insertBefore` will put `div` at
#       end of child list of body which in this case would just mean first
#       child. Reference:
#       https://developer.mozilla.org/en-US/docs/Web/API/Node/insertBefore. */
#     }
#   })();
#   </script>
#   <script type="text/javascript">
#    /* Include babel-polyfill if browser dos not support Object.assign or window.Promise */
#
#   (function() {
#     if (typeof Object.assign !== "function" ||
#         typeof window.Promise !== "function") {
#
#       var head = document.getElementsByTagName('head')[0],
#           script = document.createElement('script');
#
#       script.type = 'text/javascript';
#       script.src = 'https://cdnjs.cloudflare.com/ajax/libs/babel-polyfill/6.23.0/polyfill.min.js';
#       script.crossOrigin = 'anonymous';
#       head.appendChild(script);
#     }
#   })();
#   </script>
#   <div data-server-rendered="true">
#    <div class="lang-en" id="app">
#     <div class="body-wrapper" style="padding-top:55px;">
#      <!-- -->
#      <header class="header opaque-header">
#       <div class="container-fluid">
#        <div class="row-fluid">
#         <nav class="span7 header-nav header-nav-left" data-v-6734adc4="" role="navigation">
#          <ul class="nav hidden-tablet-landscape">
#           <li>
#            <a class="router-link-exact-active router-link-active" data-v-6734adc4="" href="/en-ca/men" id="men-link">
#             Men
#            </a>
#           </li>
#           <li>
#            <a data-v-6734adc4="" href="/en-ca/women" id="women-link">
#             Women
#            </a>
#           </li>
#           <li>
#            <a data-v-6734adc4="" href="/en-ca/men/sale" id="sale-link">
#             sale
#            </a>
#           </li>
#           <!-- -->
#          </ul>
#          <ul class="nav mobile-navigation display-block-tablet-landscape">
#           <li class="side-menu-toggle">
#            <a href="#">
#             <i class="fa fa-ssense-menu">
#             </i>
#             <span class="menu-animated">
#             </span>
#            </a>
#           </li>
#           <li>
#            <a class="display-block-tablet-landscape" href="#">
#             <i class="fa fa-ssense-magnifier">
#             </i>
#            </a>
#           </li>
#          </ul>
#         </nav>
#         <div class="header-logo span2" data-v-37baba0c="" role="banner">
#          <a class="router-link-active" data-v-37baba0c="" href="/en-ca">
#           <img alt="SSENSE" class="site-logo dark" data-v-37baba0c="" src="//res.cloudinary.com/ssenseweb/image/upload/v1409080279/web/ssense_logo_v2.png"/>
#          </a>
#         </div>
#         <nav class="span7 header-nav header-nav-right" data-v-bd126e56="" role="navigation">
#          <ul class="nav hidden-tablet-landscape">
#           <li>
#            <a class="popover-hover-link" href="https://www.ssense.com/en-ca/men">
#             English
#            </a>
#            <div class="popover-center" data-v-88391330="" data-v-bd126e56="">
#             <div class="popover popover-alternate" id="language-menu-popover">
#              <ul data-v-bd126e56="">
#               <li>
#                <a href="https://www.ssense.com/fr-ca/hommes" rel="nofollow">
#                 Français
#                </a>
#               </li>
#               <li>
#                <a href="https://www.ssense.com/ja-ca/men" rel="nofollow">
#                 日本語
#                </a>
#               </li>
#               <li>
#                <a href="https://www.ssense.com/zh-ca/men" rel="nofollow">
#                 中文
#                </a>
#               </li>
#              </ul>
#             </div>
#            </div>
#           </li>
#           <li>
#            <a data-v-bd126e56="" href="/en-ca/account/login">
#             login
#            </a>
#           </li>
#           <li>
#            <a class="right-nav-items" data-v-bd126e56="" href="/en-ca/account/wishlist">
#             wishlist
#            </a>
#           </li>
#           <li>
#            <a class="shopping-bag-link" data-v-bd126e56="" href="/en-ca/shopping-bag">
#             shopping bag (0)
#            </a>
#           </li>
#          </ul>
#          <ul class="nav mobile-navigation display-block-tablet-landscape">
#           <li class="account">
#            <a class="popover-hover-link" data-v-bd126e56="" href="/en-ca/account">
#             <i class="fa fa-ssense-account" data-v-bd126e56="">
#             </i>
#            </a>
#           </li>
#           <li class="shopping-bag">
#            <a class="shopping-bag-link" data-v-bd126e56="" href="/en-ca/shopping-bag">
#             <i class="fa fa-ssense-bag" data-v-bd126e56="">
#             </i>
#             <span class="header-shopping-bag-count miniBagCount" data-v-bd126e56="">
#              <span data-v-bd126e56="">
#               (
#              </span>
#              0
#              <span data-v-bd126e56="">
#               )
#              </span>
#             </span>
#            </a>
#           </li>
#          </ul>
#         </nav>
#        </div>
#       </div>
#       <!-- -->
#      </header>
#      <div>
#      </div>
#      <div class="notification-manager-container">
#       <span>
#       </span>
#      </div>
#      <!-- -->
#      <main class="main container-fluid" id="wrap" role="main">
#       <div class="browsing-page-root browsing-section-container view">
#        <div class="span12 browsing-column browsing-center-column tablet-landscape-full-fluid-width">
#         <section aria-labelledby="listing-title" class="browsing-product-container span12">
#          <div class="browsing-product-content">
#           <!-- -->
#           <!-- -->
#           <!-- -->
#           <div class="browsing-product-list">
#            <figure class="browsing-product-item">
#             <script type="application/ld+json">
#              {
#   "@context": "https://schema.org",
#   "@type": "Product",
#   "productID": 5190561,
#   "name": "Brown Above The Knee Oil Coat",
#   "sku": "201278M176022",
#   "brand": {
#     "@type": "Brand",
#     "name": "Kassl Editions"
#   },
#   "offers": {
#     "@type": "Offer",
#     "price": 1810,
#     "priceCurrency": "CAD",
#     "availability": "https://schema.org/InStock",
#     "url": "/men/product/kassl-editions/brown-above-the-knee-oil-coat/5190561"
#   },
#   "url": "/men/product/kassl-editions/brown-above-the-knee-oil-coat/5190561",
#   "image": "https://res.cloudinary.com/ssenseweb/image/upload/201278M176022_1.jpg"
# }
#             </script>
#             <a href="/en-ca/men/product/kassl-editions/brown-above-the-knee-oil-coat/5190561">
#              <div class="image-container">
#               <picture data-v-60b7d3e3="">
#                <!-- -->
#                <!-- -->
#                <img alt="Kassl Editions - Brown Above The Knee Oil Coat" class="product-thumbnail lazyload" data-srcset="https://img.ssensemedia.com/images/b_white,c_lpad,g_south,h_706,w_470/c_scale,h_280/f_auto,dpr_1.0/201278M176022_1/kassl-editions-brown-above-the-knee-oil-coat.jpg" src="https://res.cloudinary.com/ssenseweb/image/upload/v1472069180/product-placeholder_qulza9.png"/>
#               </picture>
#              </div>
#              <figcaption class="browsing-product-description text-center vspace1">
#               <p class="bold">
#                Kassl Editions
#               </p>
#               <p class="product-name-plp">
#                Brown Above The Knee Oil Coat
#               </p>
#              </figcaption>
#              <!-- -->
#             </a>
#             <div>
#              <p class="price">
#               <span class="price">
#                $1810
#               </span>
#               <!-- -->
#              </p>
#             </div>
#            </figure>
#            <figure class="browsing-product-item">
#             <script type="application/ld+json">
#              {
#   "@context": "https://schema.org",
#   "@type": "Product",
#   "productID": 5230331,
#   "name": "Black Faux-Leather Hoodie",
#   "sku": "192172M202054",
#   "brand": {
#     "@type": "Brand",
#     "name": "Random Identities"
#   },
#   "offers": {
#     "@type": "Offer",
#     "price": 761,
#     "priceCurrency": "CAD",
#     "availability": "https://schema.org/InStock",
#     "url": "/men/product/random-identities/black-faux-leather-hoodie/5230331"
#   },
#   "url": "/men/product/random-identities/black-faux-leather-hoodie/5230331",
#   "image": "https://res.cloudinary.com/ssenseweb/image/upload/192172M202054_1.jpg"
# }
#             </script>
#             <a href="/en-ca/men/product/random-identities/black-faux-leather-hoodie/5230331">
#              <div class="image-container">
#               <picture data-v-60b7d3e3="">
#                <!-- -->
#                <!-- -->
#                <img alt="Random Identities - Black Faux-Leather Hoodie" class="product-thumbnail lazyload" data-srcset="https://img.ssensemedia.com/images/b_white,c_lpad,g_south,h_706,w_470/c_scale,h_280/f_auto,dpr_1.0/192172M202054_1/random-identities-black-faux-leather-hoodie.jpg" src="https://res.cloudinary.com/ssenseweb/image/upload/v1472069180/product-placeholder_qulza9.png"/>
#               </picture>
#              </div>
#              <figcaption class="browsing-product-description text-center vspace1">
#               <p class="bold">
#                Random Identities
#               </p>
#               <p class="product-name-plp">
#                Black Faux-Leather Hoodie
#               </p>
#              </figcaption>
#              <!-- -->
#             </a>
#             <div>
#              <p class="price">
#               <span class="price sale">
#                $975
#               </span>
#               <span class="price">
#                $761
#               </span>
#              </p>
#             </div>
#            </figure>
#            <figure class="browsing-product-item">
#             <script type="application/ld+json">
#              {
#   "@context": "https://schema.org",
#   "@type": "Product",
#   "productID": 5230341,
#   "name": "White Cropped Mesh Jacket",
#   "sku": "192172M180094",
#   "brand": {
#     "@type": "Brand",
#     "name": "Random Identities"
#   },
#   "offers": {
#     "@type": "Offer",
#     "price": 445,
#     "priceCurrency": "CAD",
#     "availability": "https://schema.org/InStock",
#     "url": "/men/product/random-identities/white-cropped-mesh-jacket/5230341"
#   },
#   "url": "/men/product/random-identities/white-cropped-mesh-jacket/5230341",
#   "image": "https://res.cloudinary.com/ssenseweb/image/upload/192172M180094_1.jpg"
# }
#             </script>
#             <a href="/en-ca/men/product/random-identities/white-cropped-mesh-jacket/5230341">
#              <div class="image-container">
#               <picture data-v-60b7d3e3="">
#                <!-- -->
#                <!-- -->
#                <img alt="Random Identities - White Cropped Mesh Jacket" class="product-thumbnail lazyload" data-srcset="https://img.ssensemedia.com/images/b_white,c_lpad,g_south,h_706,w_470/c_scale,h_280/f_auto,dpr_1.0/192172M180094_1/random-identities-white-cropped-mesh-jacket.jpg" src="https://res.cloudinary.com/ssenseweb/image/upload/v1472069180/product-placeholder_qulza9.png"/>
#               </picture>
#              </div>
#              <figcaption class="browsing-product-description text-center vspace1">
#               <p class="bold">
#                Random Identities
#               </p>
#               <p class="product-name-plp">
#                White Cropped Mesh Jacket
#               </p>
#              </figcaption>
#              <!-- -->
#             </a>
#             <div>
#              <p class="price">
#               <span class="price sale">
#                $570
#               </span>
#               <span class="price">
#                $445
#               </span>
#              </p>
#             </div>
#            </figure>
#            <figure class="browsing-product-item">
#             <script type="application/ld+json">
#              {
#   "@context": "https://schema.org",
#   "@type": "Product",
#   "productID": 5230321,
#   "name": "Black Cropped Banana Hoodie",
#   "sku": "192172M202053",
#   "brand": {
#     "@type": "Brand",
#     "name": "Random Identities"
#   },
#   "offers": {
#     "@type": "Offer",
#     "price": 190,
#     "priceCurrency": "CAD",
#     "availability": "https://schema.org/InStock",
#     "url": "/men/product/random-identities/black-cropped-banana-hoodie/5230321"
#   },
#   "url": "/men/product/random-identities/black-cropped-banana-hoodie/5230321",
#   "image": "https://res.cloudinary.com/ssenseweb/image/upload/192172M202053_1.jpg"
# }
#             </script>
#             <a href="/en-ca/men/product/random-identities/black-cropped-banana-hoodie/5230321">
#              <div class="image-container">
#               <picture data-v-60b7d3e3="">
#                <!-- -->
#                <!-- -->
#                <img alt="Random Identities - Black Cropped Banana Hoodie" class="product-thumbnail lazyload" data-srcset="https://img.ssensemedia.com/images/b_white,c_lpad,g_south,h_706,w_470/c_scale,h_280/f_auto,dpr_1.0/192172M202053_1/random-identities-black-cropped-banana-hoodie.jpg" src="https://res.cloudinary.com/ssenseweb/image/upload/v1472069180/product-placeholder_qulza9.png"/>
#               </picture>
#              </div>
#              <figcaption class="browsing-product-description text-center vspace1">
#               <p class="bold">
#                Random Identities
#               </p>
#               <p class="product-name-plp">
#                Black Cropped Banana Hoodie
#               </p>
#              </figcaption>
#              <!-- -->
#             </a>
#             <div>
#              <p class="price">
#               <span class="price sale">
#                $235
#               </span>
#               <span class="price">
#                $190
#               </span>
#              </p>
#             </div>
#            </figure>
#            <figure class="browsing-product-item">
#             <script type="application/ld+json">
#              {
#   "@context": "https://schema.org",
#   "@type": "Product",
#   "productID": 4333271,
#   "name": "5 Moncler Craig Green Black Logo Long Sleeve T-Shirt",
#   "sku": "201171M213003",
#   "brand": {
#     "@type": "Brand",
#     "name": "Moncler Genius"
#   },
#   "offers": {
#     "@type": "Offer",
#     "price": 520,
#     "priceCurrency": "CAD",
#     "availability": "https://schema.org/InStock",
#     "url": "/men/product/moncler-genius/5-moncler-craig-green-black-logo-long-sleeve-t-shirt/4333271"
#   },
#   "url": "/men/product/moncler-genius/5-moncler-craig-green-black-logo-long-sleeve-t-shirt/4333271",
#   "image": "https://res.cloudinary.com/ssenseweb/image/upload/201171M213003_1.jpg"
# }
#             </script>
#             <a href="/en-ca/men/product/moncler-genius/5-moncler-craig-green-black-logo-long-sleeve-t-shirt/4333271">
#              <div class="image-container">
#               <picture data-v-60b7d3e3="">
#                <!-- -->
#                <!-- -->
#                <img alt="Moncler Genius - 5 Moncler Craig Green Black Logo Long Sleeve T-Shirt" class="product-thumbnail lazyload" data-srcset="https://img.ssensemedia.com/images/b_white,c_lpad,g_south,h_706,w_470/c_scale,h_280/f_auto,dpr_1.0/201171M213003_1/moncler-genius-5-moncler-craig-green-black-logo-long-sleeve-t-shirt.jpg" src="https://res.cloudinary.com/ssenseweb/image/upload/v1472069180/product-placeholder_qulza9.png"/>
#               </picture>
#              </div>
#              <figcaption class="browsing-product-description text-center vspace1">
#               <p class="bold">
#                Moncler Genius
#               </p>
#               <p class="product-name-plp">
#                5 Moncler Craig Green Black Logo Long Sleeve T-Shirt
#               </p>
#              </figcaption>
#              <!-- -->
#             </a>
#             <div>
#              <p class="price">
#               <span class="price">
#                $520
#               </span>
#               <!-- -->
#              </p>
#             </div>
#            </figure>
#            <figure class="browsing-product-item">
#             <script type="application/ld+json">
#              {
#   "@context": "https://schema.org",
#   "@type": "Product",
#   "productID": 5230301,
#   "name": "White Cropped Banana Hoodie",
#   "sku": "192172M202052",
#   "brand": {
#     "@type": "Brand",
#     "name": "Random Identities"
#   },
#   "offers": {
#     "@type": "Offer",
#     "price": 190,
#     "priceCurrency": "CAD",
#     "availability": "https://schema.org/InStock",
#     "url": "/men/product/random-identities/white-cropped-banana-hoodie/5230301"
#   },
#   "url": "/men/product/random-identities/white-cropped-banana-hoodie/5230301",
#   "image": "https://res.cloudinary.com/ssenseweb/image/upload/192172M202052_1.jpg"
# }
#             </script>
#             <a href="/en-ca/men/product/random-identities/white-cropped-banana-hoodie/5230301">
#              <div class="image-container">
#               <picture data-v-60b7d3e3="">
#                <!-- -->
#                <!-- -->
#                <img alt="Random Identities - White Cropped Banana Hoodie" class="product-thumbnail lazyload" data-srcset="https://img.ssensemedia.com/images/b_white,c_lpad,g_south,h_706,w_470/c_scale,h_280/f_auto,dpr_1.0/192172M202052_1/random-identities-white-cropped-banana-hoodie.jpg" src="https://res.cloudinary.com/ssenseweb/image/upload/v1472069180/product-placeholder_qulza9.png"/>
#               </picture>
#              </div>
#              <figcaption class="browsing-product-description text-center vspace1">
#               <p class="bold">
#                Random Identities
#               </p>
#               <p class="product-name-plp">
#                White Cropped Banana Hoodie
#               </p>
#              </figcaption>
#              <!-- -->
#             </a>
#             <div>
#              <p class="price">
#               <span class="price sale">
#                $235
#               </span>
#               <span class="price">
#                $190
#               </span>
#              </p>
#             </div>
#            </figure>
#            <figure class="browsing-product-item">
#             <script type="application/ld+json">
#              {
#   "@context": "https://schema.org",
#   "@type": "Product",
#   "productID": 4333191,
#   "name": "5 Moncler Craig Green Green & Black Nylon Trousers",
#   "sku": "201171M191001",
#   "brand": {
#     "@type": "Brand",
#     "name": "Moncler Genius"
#   },
#   "offers": {
#     "@type": "Offer",
#     "price": 575,
#     "priceCurrency": "CAD",
#     "availability": "https://schema.org/InStock",
#     "url": "/men/product/moncler-genius/5-moncler-craig-green-green-and-black-nylon-trousers/4333191"
#   },
#   "url": "/men/product/moncler-genius/5-moncler-craig-green-green-and-black-nylon-trousers/4333191",
#   "image": "https://res.cloudinary.com/ssenseweb/image/upload/201171M191001_1.jpg"
# }
#             </script>
#             <a href="/en-ca/men/product/moncler-genius/5-moncler-craig-green-green-and-black-nylon-trousers/4333191">
#              <div class="image-container">
#               <picture data-v-60b7d3e3="">
#                <!-- -->
#                <!-- -->
#                <img alt="Moncler Genius - 5 Moncler Craig Green Green &amp; Black Nylon Trousers" class="product-thumbnail lazyload" data-srcset="https://img.ssensemedia.com/images/b_white,c_lpad,g_south,h_706,w_470/c_scale,h_280/f_auto,dpr_1.0/201171M191001_1/moncler-genius-5-moncler-craig-green-green--black-nylon-trousers.jpg" src="https://res.cloudinary.com/ssenseweb/image/upload/v1472069180/product-placeholder_qulza9.png"/>
#               </picture>
#              </div>
#              <figcaption class="browsing-product-description text-center vspace1">
#               <p class="bold">
#                Moncler Genius
#               </p>
#               <p class="product-name-plp">
#                5 Moncler Craig Green Green &amp; Black Nylon Trousers
#               </p>
#              </figcaption>
#              <!-- -->
#             </a>
#             <div>
#              <p class="price">
#               <span class="price">
#                $575
#               </span>
#               <!-- -->
#              </p>
#             </div>
#            </figure>
#            <figure class="browsing-product-item">
#             <script type="application/ld+json">
#              {
#   "@context": "https://schema.org",
#   "@type": "Product",
#   "productID": 5230311,
#   "name": "Black Velvet Boxing Shorts",
#   "sku": "192172M193052",
#   "brand": {
#     "@type": "Brand",
#     "name": "Random Identities"
#   },
#   "offers": {
#     "@type": "Offer",
#     "price": 256,
#     "priceCurrency": "CAD",
#     "availability": "https://schema.org/InStock",
#     "url": "/men/product/random-identities/black-velvet-boxing-shorts/5230311"
#   },
#   "url": "/men/product/random-identities/black-velvet-boxing-shorts/5230311",
#   "image": "https://res.cloudinary.com/ssenseweb/image/upload/192172M193052_1.jpg"
# }
#             </script>
#             <a href="/en-ca/men/product/random-identities/black-velvet-boxing-shorts/5230311">
#              <div class="image-container">
#               <picture data-v-60b7d3e3="">
#                <!-- -->
#                <!-- -->
#                <img alt="Random Identities - Black Velvet Boxing Shorts" class="product-thumbnail lazyload" data-srcset="https://img.ssensemedia.com/images/b_white,c_lpad,g_south,h_706,w_470/c_scale,h_280/f_auto,dpr_1.0/192172M193052_1/random-identities-black-velvet-boxing-shorts.jpg" src="https://res.cloudinary.com/ssenseweb/image/upload/v1472069180/product-placeholder_qulza9.png"/>
#               </picture>
#              </div>
#              <figcaption class="browsing-product-description text-center vspace1">
#               <p class="bold">
#                Random Identities
#               </p>
#               <p class="product-name-plp">
#                Black Velvet Boxing Shorts
#               </p>
#              </figcaption>
#              <!-- -->
#             </a>
#             <div>
#              <p class="price">
#               <span class="price sale">
#                $320
#               </span>
#               <span class="price">
#                $256
#               </span>
#              </p>
#             </div>
#            </figure>
#            <figure class="browsing-product-item">
#             <script type="application/ld+json">
#              {
#   "@context": "https://schema.org",
#   "@type": "Product",
#   "productID": 4607571,
#   "name": "Blue William De Morgan Edition Dragon Beanie",
#   "sku": "201677M138033",
#   "brand": {
#     "@type": "Brand",
#     "name": "Loewe"
#   },
#   "offers": {
#     "@type": "Offer",
#     "price": 1500,
#     "priceCurrency": "CAD",
#     "availability": "https://schema.org/InStock",
#     "url": "/men/product/loewe/blue-william-de-morgan-edition-dragon-beanie/4607571"
#   },
#   "url": "/men/product/loewe/blue-william-de-morgan-edition-dragon-beanie/4607571",
#   "image": "https://res.cloudinary.com/ssenseweb/image/upload/201677M138033_1.jpg"
# }
#             </script>
#             <a href="/en-ca/men/product/loewe/blue-william-de-morgan-edition-dragon-beanie/4607571">
#              <div class="image-container">
#               <picture data-v-60b7d3e3="">
#                <!-- -->
#                <!-- -->
#                <img alt="Loewe - Blue William De Morgan Edition Dragon Beanie" class="product-thumbnail lazyload" data-srcset="https://img.ssensemedia.com/images/b_white,c_lpad,g_south,h_706,w_470/c_scale,h_280/f_auto,dpr_1.0/201677M138033_1/loewe-blue-william-de-morgan-edition-dragon-beanie.jpg" src="https://res.cloudinary.com/ssenseweb/image/upload/v1472069180/product-placeholder_qulza9.png"/>
#               </picture>
#              </div>
#              <figcaption class="browsing-product-description text-center vspace1">
#               <p class="bold">
#                Loewe
#               </p>
#               <p class="product-name-plp">
#                Blue William De Morgan Edition Dragon Beanie
#               </p>
#              </figcaption>
#              <!-- -->
#             </a>
#             <div>
#              <p class="price">
#               <span class="price">
#                $1500
#               </span>
#               <!-- -->
#              </p>
#             </div>
#            </figure>
#            <figure class="browsing-product-item">
#             <script type="application/ld+json">
#              {
#   "@context": "https://schema.org",
#   "@type": "Product",
#   "productID": 4405281,
#   "name": "White 'NA' Long Sleeve T-Shirt",
#   "sku": "192889M213015",
#   "brand": {
#     "@type": "Brand",
#     "name": "Enfants Riches Déprimés"
#   },
#   "offers": {
#     "@type": "Offer",
#     "price": 940,
#     "priceCurrency": "CAD",
#     "availability": "https://schema.org/InStock",
#     "url": "/men/product/enfants-riches-deprimes/white-na-long-sleeve-t-shirt/4405281"
#   },
#   "url": "/men/product/enfants-riches-deprimes/white-na-long-sleeve-t-shirt/4405281",
#   "image": "https://res.cloudinary.com/ssenseweb/image/upload/192889M213015_1.jpg"
# }
#             </script>
#             <a href="/en-ca/men/product/enfants-riches-deprimes/white-na-long-sleeve-t-shirt/4405281">
#              <div class="image-container">
#               <picture data-v-60b7d3e3="">
#                <!-- -->
#                <!-- -->
#                <img alt="Enfants Riches Déprimés - White 'NA' Long Sleeve T-Shirt" class="product-thumbnail lazyload" data-srcset="https://img.ssensemedia.com/images/b_white,c_lpad,g_south,h_706,w_470/c_scale,h_280/f_auto,dpr_1.0/192889M213015_1/enfants-riches-deprimes-white-na-long-sleeve-t-shirt.jpg" src="https://res.cloudinary.com/ssenseweb/image/upload/v1472069180/product-placeholder_qulza9.png"/>
#               </picture>
#              </div>
#              <figcaption class="browsing-product-description text-center vspace1">
#               <p class="bold">
#                Enfants Riches Déprimés
#               </p>
#               <p class="product-name-plp">
#                White 'NA' Long Sleeve T-Shirt
#               </p>
#              </figcaption>
#              <!-- -->
#             </a>
#             <div>
#              <p class="price">
#               <span class="price">
#                $940
#               </span>
#               <!-- -->
#              </p>
#             </div>
#            </figure>
#            <figure class="browsing-product-item">
#             <script type="application/ld+json">
#              {
#   "@context": "https://schema.org",
#   "@type": "Product",
#   "productID": 4404861,
#   "name": "Black Leather Logo Cropped Jacket",
#   "sku": "192889M181004",
#   "brand": {
#     "@type": "Brand",
#     "name": "Enfants Riches Déprimés"
#   },
#   "offers": {
#     "@type": "Offer",
#     "price": 4025,
#     "priceCurrency": "CAD",
#     "availability": "https://schema.org/InStock",
#     "url": "/men/product/enfants-riches-deprimes/black-leather-logo-cropped-jacket/4404861"
#   },
#   "url": "/men/product/enfants-riches-deprimes/black-leather-logo-cropped-jacket/4404861",
#   "image": "https://res.cloudinary.com/ssenseweb/image/upload/192889M181004_1.jpg"
# }
#             </script>
#             <a href="/en-ca/men/product/enfants-riches-deprimes/black-leather-logo-cropped-jacket/4404861">
#              <div class="image-container">
#               <picture data-v-60b7d3e3="">
#                <!-- -->
#                <!-- -->
#                <img alt="Enfants Riches Déprimés - Black Leather Logo Cropped Jacket" class="product-thumbnail lazyload" data-srcset="https://img.ssensemedia.com/images/b_white,c_lpad,g_south,h_706,w_470/c_scale,h_280/f_auto,dpr_1.0/192889M181004_1/enfants-riches-deprimes-black-leather-logo-cropped-jacket.jpg" src="https://res.cloudinary.com/ssenseweb/image/upload/v1472069180/product-placeholder_qulza9.png"/>
#               </picture>
#              </div>
#              <figcaption class="browsing-product-description text-center vspace1">
#               <p class="bold">
#                Enfants Riches Déprimés
#               </p>
#               <p class="product-name-plp">
#                Black Leather Logo Cropped Jacket
#               </p>
#              </figcaption>
#              <!-- -->
#             </a>
#             <div>
#              <p class="price">
#               <span class="price">
#                $4025
#               </span>
#               <!-- -->
#              </p>
#             </div>
#            </figure>
#            <figure class="browsing-product-item">
#             <script type="application/ld+json">
#              {
#   "@context": "https://schema.org",
#   "@type": "Product",
#   "productID": 4404881,
#   "name": "White 'Name Your Poison' T-Shirt",
#   "sku": "192889M213010",
#   "brand": {
#     "@type": "Brand",
#     "name": "Enfants Riches Déprimés"
#   },
#   "offers": {
#     "@type": "Offer",
#     "price": 830,
#     "priceCurrency": "CAD",
#     "availability": "https://schema.org/InStock",
#     "url": "/men/product/enfants-riches-deprimes/white-name-your-poison-t-shirt/4404881"
#   },
#   "url": "/men/product/enfants-riches-deprimes/white-name-your-poison-t-shirt/4404881",
#   "image": "https://res.cloudinary.com/ssenseweb/image/upload/192889M213010_1.jpg"
# }
#             </script>
#             <a href="/en-ca/men/product/enfants-riches-deprimes/white-name-your-poison-t-shirt/4404881">
#              <div class="image-container">
#               <picture data-v-60b7d3e3="">
#                <!-- -->
#                <!-- -->
#                <img alt="Enfants Riches Déprimés - White 'Name Your Poison' T-Shirt" class="product-thumbnail lazyload" data-srcset="https://img.ssensemedia.com/images/b_white,c_lpad,g_south,h_706,w_470/c_scale,h_280/f_auto,dpr_1.0/192889M213010_1/enfants-riches-deprimes-white-name-your-poison-t-shirt.jpg" src="https://res.cloudinary.com/ssenseweb/image/upload/v1472069180/product-placeholder_qulza9.png"/>
#               </picture>
#              </div>
#              <figcaption class="browsing-product-description text-center vspace1">
#               <p class="bold">
#                Enfants Riches Déprimés
#               </p>
#               <p class="product-name-plp">
#                White 'Name Your Poison' T-Shirt
#               </p>
#              </figcaption>
#              <!-- -->
#             </a>
#             <div>
#              <p class="price">
#               <span class="price">
#                $830
#               </span>
#               <!-- -->
#              </p>
#             </div>
#            </figure>
#            <figure class="browsing-product-item">
#             <script type="application/ld+json">
#              {
#   "@context": "https://schema.org",
#   "@type": "Product",
#   "productID": 4405181,
#   "name": "Blue Denim Echecs Jacket",
#   "sku": "192889M177003",
#   "brand": {
#     "@type": "Brand",
#     "name": "Enfants Riches Déprimés"
#   },
#   "offers": {
#     "@type": "Offer",
#     "price": 2500,
#     "priceCurrency": "CAD",
#     "availability": "https://schema.org/InStock",
#     "url": "/men/product/enfants-riches-deprimes/blue-denim-echecs-jacket/4405181"
#   },
#   "url": "/men/product/enfants-riches-deprimes/blue-denim-echecs-jacket/4405181",
#   "image": "https://res.cloudinary.com/ssenseweb/image/upload/192889M177003_1.jpg"
# }
#             </script>
#             <a href="/en-ca/men/product/enfants-riches-deprimes/blue-denim-echecs-jacket/4405181">
#              <div class="image-container">
#               <picture data-v-60b7d3e3="">
#                <!-- -->
#                <!-- -->
#                <img alt="Enfants Riches Déprimés - Blue Denim Echecs Jacket" class="product-thumbnail lazyload" data-srcset="https://img.ssensemedia.com/images/b_white,c_lpad,g_south,h_706,w_470/c_scale,h_280/f_auto,dpr_1.0/192889M177003_1/enfants-riches-deprimes-blue-denim-echecs-jacket.jpg" src="https://res.cloudinary.com/ssenseweb/image/upload/v1472069180/product-placeholder_qulza9.png"/>
#               </picture>
#              </div>
#              <figcaption class="browsing-product-description text-center vspace1">
#               <p class="bold">
#                Enfants Riches Déprimés
#               </p>
#               <p class="product-name-plp">
#                Blue Denim Echecs Jacket
#               </p>
#              </figcaption>
#              <!-- -->
#             </a>
#             <div>
#              <p class="price">
#               <span class="price">
#                $2500
#               </span>
#               <!-- -->
#              </p>
#             </div>
#            </figure>
#            <figure class="browsing-product-item">
#             <script type="application/ld+json">
#              {
#   "@context": "https://schema.org",
#   "@type": "Product",
#   "productID": 4404961,
#   "name": "Blue 'Name Your Poison' Sweatshirt",
#   "sku": "192889M201004",
#   "brand": {
#     "@type": "Brand",
#     "name": "Enfants Riches Déprimés"
#   },
#   "offers": {
#     "@type": "Offer",
#     "price": 1125,
#     "priceCurrency": "CAD",
#     "availability": "https://schema.org/InStock",
#     "url": "/men/product/enfants-riches-deprimes/blue-name-your-poison-sweatshirt/4404961"
#   },
#   "url": "/men/product/enfants-riches-deprimes/blue-name-your-poison-sweatshirt/4404961",
# ...
#                Price: High to low
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#           <!-- -->
#          </nav>
#         </div>
#        </div>
#       </div>
#      </main>
#     </div>
#     <footer class="footer" data-v-17f2a208="" style="visibility:visible;">
#      <div class="container-fluid">
#       <div class="row-fluid">
#        <div class="footer-desktop span16 hidden-tablet-landscape" data-v-17f2a208="">
#         <nav class="footer-desktop-right-nav" data-v-17f2a208="" data-v-363cdc87="" role="navigation">
#          <div class="row-fluid">
#           <div class="span16">
#            <ul class="social hide-social-tablet" data-v-363cdc87="">
#             <li>
#              <a aria-label="facebook" class="i facebook" href="//www.facebook.com/SSENSEofficial" target="_blank">
#               <i class="fa fa-facebook fa-fw">
#               </i>
#              </a>
#             </li>
#             <li>
#              <a aria-label="twitter" class="i twitter" href="//twitter.com/ssense" target="_blank">
#               <i class="fa fa-twitter fa-fw">
#               </i>
#              </a>
#             </li>
#             <li>
#              <a aria-label="instagram" class="i instagram" href="//instagram.com/ssense" target="_blank">
#               <i class="fa fa-instagram fa-fw">
#               </i>
#              </a>
#             </li>
#             <li>
#              <a aria-label="youtube" class="i youtube" href="//www.youtube.com/user/ssense" target="_blank">
#               <i class="fa fa-youtube fa-fw">
#               </i>
#              </a>
#             </li>
#            </ul>
#            <ul class="nav footer-links">
#             <li>
#              <a data-current-country="Canada" href="#">
#               COUNTRY/REGION: Canada
#              </a>
#              <div class="popover-center" data-v-363cdc87="" data-v-88391330="">
#               <div class="popover popover-alternate popover-padding no-border" id="footer-country-select">
#                <div class="footer-country-popover popover-alternate" data-v-363cdc87="" data-v-7d47f068="" style="display:block;">
#                 <ul class="country-list" data-v-1011490a="" data-v-7d47f068="">
#                  <div>
#                   <li>
#                    <a href="https://www.ssense.com/en-ca/men">
#                     Canada
#                    </a>
#                   </li>
#                   <li>
#                    <a href="https://www.ssense.com/en-us/men">
#                     United States
#                    </a>
#                   </li>
#                   <li>
#                    <a href="https://www.ssense.com/en-gb/men">
#                     United Kingdom
#                    </a>
#                   </li>
#                   <li>
#                    <a href="https://www.ssense.com/ja-jp/men">
#                     Japan
#                    </a>
#                   </li>
#                   <li>
#                    <a href="https://www.ssense.com/zh-cn/men">
#                     China
#                    </a>
#                   </li>
#                   <li>
#                    <a href="https://www.ssense.com/fr-fr/hommes">
#                     France
#                    </a>
#                   </li>
#                  </div>
#                  <!-- -->
#                  <li>
#                   <a data-v-1011490a="" href="/en-ca/countries" rel="nofollow">
#                    <b data-v-1011490a="">
#                     View all
#                    </b>
#                   </a>
#                  </li>
#                 </ul>
#                 <input class="country-search-input" placeholder="SEARCH COUNTRY/REGION" type="text" value=""/>
#                </div>
#               </div>
#              </div>
#             </li>
#             <li>
#              <a href="#">
#               newsletter signup
#              </a>
#              <div class="popover-center" data-v-363cdc87="" data-v-88391330="">
#               <div class="popover popover-alternate popover-padding" id="footer-nl-form">
#                <div data-v-09e96a47="" data-v-363cdc87="">
#                 <!-- -->
#                 <form action="/en-ca/newsletters/subscribers" class="newsletter-form-container" method="POST">
#                  <input id="source" name="source" type="hidden" value="SSENSE_NL_SIGNUP"/>
#                  <div class="row-fluid">
#                   <div class="span16">
#                    <p>
#                     Sign up for email updates and promotions
#                    </p>
#                   </div>
#                   <div class="span16 relative tablet-portrait-full-fluid-width vspace2">
#                    <input autocapitalize="off" autocorrect="off" class="email-input" id="popover-footer_email" name="email" placeholder="Email address" tabindex="1" type="text" value=""/>
#                    <!-- -->
#                   </div>
#                   <div class="relative smartphone-portrait-full-fluid-width genders-container visible span16 vspace1">
#                    <div class="radio-input-wrap">
#                     <input checked="checked" class="capitalize" name="genderFooter" tabindex="2" type="radio" value="men"/>
#                     <label class="capitalize" for="popover-footer_gender_men">
#                      Men
#                     </label>
#                    </div>
#                    <div class="radio-input-wrap">
#                     <input class="capitalize" name="genderFooter" tabindex="2" type="radio" value="women"/>
#                     <label class="capitalize" for="popover-footer_gender_women">
#                      Women
#                     </label>
#                    </div>
#                    <div id="error_genderFooter" style="display:none;">
#                    </div>
#                   </div>
#                   <!-- -->
#                   <div class="span16 vspace1 submit-container visible">
#                    <button class="button full-width lighter" data-v-09e96a47="" type="submit">
#                     <span class="button-label">
#                      subscribe
#                     </span>
#                     <span class="load-wrapper" style="display:none;">
#                      <span class="load-animation">
#                       <span class="dot" style="width:3px;height:3px;border-radius:3px;margin-right:12px;animation:0.44999999999999996s 0s blink step-end infinite;">
#                       </span>
#                       <span class="dot" style="width:3px;height:3px;border-radius:3px;margin-right:12px;animation:0.44999999999999996s 0.075s blink step-end infinite;">
#                       </span>
#                       <span class="dot" style="width:3px;height:3px;border-radius:3px;margin-right:0px;animation:0.44999999999999996s 0.15s blink step-end infinite;">
#                       </span>
#                      </span>
#                     </span>
#                    </button>
#                   </div>
#                   <div class="relative smartphone-portrait-full-fluid-width legal-consent-wrapper span16 visible">
#                    <p class="legal-consent-1">
#                     You may unsubscribe at any time.
#                    </p>
#                    <p>
#                     To find out more, please visit our
#                     <a href="/en-ca/privacy-policy">
#                      Privacy Policy
#                     </a>
#                     .
#                    </p>
#                   </div>
#                  </div>
#                 </form>
#                 <!-- -->
#                </div>
#               </div>
#              </div>
#             </li>
#             <li>
#              <a data-v-363cdc87="" href="/en-ca/customer-service">
#               customer care
#              </a>
#             </li>
#             <li>
#              <a href="#">
#               locations
#              </a>
#              <div class="popover-center footer-location-select" data-v-363cdc87="" data-v-88391330="">
#               <div class="popover popover-alternate" id="footer-locations-select">
#                <ul class="footer-location-select-items" data-v-363cdc87="" data-v-addbeaa0="">
#                 <li>
#                  <a class-active="" data-v-addbeaa0="" href="/en-ca/locations/montreal">
#                   <span data-v-addbeaa0="">
#                    SSENSE MONTRÉAL
#                   </span>
#                  </a>
#                 </li>
#                 <li class="footer-location-select-items-border-top">
#                  <a class-active="" data-v-addbeaa0="" href="/en-ca/appointments">
#                   <span data-v-addbeaa0="">
#                    APPOINTMENTS
#                   </span>
#                  </a>
#                 </li>
#                </ul>
#               </div>
#              </div>
#             </li>
#             <li>
#              <a data-v-363cdc87="" href="/en-ca/editorial">
#               Editorial Archive
#              </a>
#             </li>
#             <li>
#              <a href="/en-ca/careers">
#               careers
#              </a>
#             </li>
#             <li>
#              <a href="/en-ca/affiliates">
#               affiliates
#              </a>
#             </li>
#             <li>
#              <a data-v-363cdc87="" href="/en-ca/sitemap">
#               sitemap
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </nav>
#         <div class="footer-desktop-left-nav" data-v-17f2a208="" data-v-5d95572c="" role="contentinfo">
#          <div class="row-fluid">
#           <div class="span16 flex-straight">
#            <ul class="nav copyright">
#             <li>
#              © 2019 ssense.com
#             </li>
#             <li class="hidden-tablet-landscape">
#              <a data-v-5d95572c="" href="/en-ca/terms-conditions">
#               Terms &amp; Conditions
#              </a>
#             </li>
#             <li class="hidden-tablet-landscape">
#              <a data-v-5d95572c="" href="/en-ca/privacy-policy">
#               Privacy Policy
#              </a>
#             </li>
#             <li>
#              <a data-v-5d95572c="" href="/en-ca/customer-service/accessibility">
#               Accessibility
#              </a>
#             </li>
#            </ul>
#            <ul class="social show-social-tablet" data-v-5d95572c="">
#             <li>
#              <a aria-label="facebook" class="i facebook" href="//www.facebook.com/SSENSEofficial" target="_blank">
#               <i class="fa fa-facebook fa-fw">
#               </i>
#              </a>
#             </li>
#             <li>
#              <a aria-label="twitter" class="i twitter" href="//twitter.com/ssense" target="_blank">
#               <i class="fa fa-twitter fa-fw">
#               </i>
#              </a>
#             </li>
#             <li>
#              <a aria-label="instagram" class="i instagram" href="//instagram.com/ssense" target="_blank">
#               <i class="fa fa-instagram fa-fw">
#               </i>
#              </a>
#             </li>
#             <li>
#              <a aria-label="youtube" class="i youtube" href="//www.youtube.com/user/ssense" target="_blank">
#               <i class="fa fa-youtube fa-fw">
#               </i>
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </footer>
#     <div class="gdpr-popup desktop" data-v-198a9b00="" style="display:none;">
#      <p>
#       SSENSE uses cookies that identify your device to provide you with a better online shopping experience, tailored to your preferences.
#      </p>
#      <p>
#       To find out more and learn how to opt out, please visit our
#       <a data-v-198a9b00="" href="/en-ca/privacy-policy">
#        Privacy Policy
#       </a>
#       .
#      </p>
#      <button>
#       accept and close
#      </button>
#     </div>
#     <!-- -->
#    </div>
#   </div>
#   <script>
#    window.INITIAL_STATE={"modals":{"modals":{}},"component":{"name":"ProductList","props":{"gender":"men","page":1,"displayLaunchingSoon":null}},"context":{"isBrowser":false,"viewport":{"width":0,"height":0,"isDesktop":false,"isMobile":false,"isTablet":false,"isTabletMobile":false,"isSmartphone":false},"locale":"en","region":"ca","country":{"name":"Canada","code":"ca","currency":"CAD","showOrigin":true,"priceDisplayRule":"base_price","freeShippingThreshold":100,"shippingThresholds":[{"shippingType":"outbound","thresholds":[{"countryCode":"CA","currencyCode":"CAD","orderMinValue":100,"orderMaxValue":null,"price":0},{"countryCode":"CA","currencyCode":"USD","orderMinValue":null,"orderMaxValue":null,"price":0}]},{"shippingType":"returns","thresholds":[{"countryCode":"CA","currencyCode":"CAD","orderMinValue":null,"orderMaxValue":null,"price":0},{"countryCode":"CA","currencyCode":"USD","orderMinValue":null,"orderMaxValue":null,"price":0}]}]},"title":"Designer Clothes, Shoes & Bags for Men | SSENSE Canada","alternateUrls":{"en-us":"https:\u002F\u002Fwww.ssense.com\u002Fen-us\u002Fmen","en-ca":"https:\u002F\u002Fwww.ssense.com\u002Fen-ca\u002Fmen","en-gb":"https:\u002F\u002Fwww.ssense.com\u002Fen-gb\u002Fmen","ja-jp":"https:\u002F\u002Fwww.ssense.com\u002Fja-jp\u002Fmen","fr-fr":"https:\u002F\u002Fwww.ssense.com\u002Ffr-fr\u002Fhommes","zh-cn":"https:\u002F\u002Fwww.ssense.com\u002Fzh-cn\u002Fmen"},"hostUrl":"https:\u002F\u002Fwww.ssense.com","gender":"men","isSaleEnabled":true,"isSearchEnabled":true,"isSaleSoon":false,"isFreeShippingEnabled":true,"isNilSearchEnabled":true,"isRetailLinksEnabled":true,"isLiveAssistanceEnabled":true,"isAppointmentsEnabled":true,"isAppointmentSectionEnabled":false,"isAutocompleteEnabled":true,"maxPendingAppointments":2,"liveAssistanceApiKey":"4EUlI6cuYHKKYy7MRbJs2FL8EdPFQrrS","liveAssistanceVersion":"4EUlI6cuYHKKYy7MRbJs2FL8EdPFQrrS","isCaptchaEnabled":true,"isNewLoginCaptchaEnabled":true,"isGoogleHireIFrameEnabled":false,"isGdprPopupEnabled":true,"captchaPublicKey":"6LcJOjkUAAAAAL3zscDofxFZre0jDq_Yi-o24XVh","captchaModules":["pdp","login"],"isSkuCaptchaProtected":false,"gaProperty":"UA-519637-1","displayRemainingStockWishlist":true,"displayRemainingStockPdp":true,"displayRemainingStockCart":true,"geoCountry":{"code":"ca","name":"Canada"},"countryDefaultLanguage":["en-us","ja-jp","fr-fr","zh-cn"],"facets":{"categories":[],"brands":[]},"opaqueHeader":false,"departmentsWithSizeFiltering":[4],"captchaSupportedCountry":true,"displayPrivacyPolicy":true,"china":{"homepageImageUrl":{"men":"","women":""}},"isHongKongFreeReturnEnabled":true,"memberVerification":null,"isLVEnabled":false,"isAlipayBannerEnabled":true,"isGAServerSideEnabled":true,"isFreeReturnBannerEnabled":false,"isNewPDPShippingThresholdsEnabled":true,"isInternalCustomer":false,"environment":"production","isRelatedProductsEnabled":true,"isSizeChartEnabled":true,"isStyledWithEnabled":true,"defaultCountries":[{"code":"ca","lang":"en"},{"code":"us","lang":"en"},{"code":"gb","lang":"en"},{"code":"jp","lang":"ja"},{"code":"cn","lang":"zh"},{"code":"fr","lang":"fr"}],"captchaBlockedCountries":["cn"],"cdnLocation":"img.ssensemedia.com","googleMapAPIKey":"AIzaSyDsCqVhVNjLw6KyPU_pQdErXErFCY6xSmg","newRelicBrowser":"\u003Cscript type='text\u002Fjavascript' \u003Ewindow.NREUM||(NREUM={});NREUM.info = {\"agent\":\"\",\"beacon\":\"bam.nr-data.net\",\"errorBeacon\":\"bam.nr-data.net\",\"licenseKey\":\"901b49cf57\",\"applicationID\":\"233360527\",\"applicationTime\":6.813033,\"transactionName\":\"ZlFbYEBRXkdWV0wPDV8bfExCQlVHRF5LSSV0YBYbV14dDlRbTQgWQ00WWVde\",\"queueTime\":0,\"ttGuid\":\"4be32fe704e050\",\"agentToken\":null}; (window.NREUM||(NREUM={})).loader_config={xpid:\"VQIGUVBaCBACV1JRAQECVFM=\",licenseKey:\"901b49cf57\",applicationID:\"233360527\"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if(\"funct ...
#   </script>
#   <script src="/assets/manifest.7cc1932d1fccb35f5224.js" type="text/javascript">
#   </script>
#   <script src="/assets/vendor.1b90a8723c89089173c2.js" type="text/javascript">
#   </script>
#   <script src="/assets/app.ae7d67ab604f3795b02d.js" type="text/javascript">
#   </script>
#  </body>
# </html>

# %% [markdown]
# ## Testing individual steps

# %% [markdown]
# ### Category Level

# %%
#Getting all categories on men's products

cat = mens_soup.find_all('ul', class_='nav nav--stacked')[0]
categories = cat.find_all('li')
categories = [i.get_text().strip() for i in categories][1:]

print(categories)
# Out:
# ['ACCESSORIES', 'BAGS', 'CLOTHING', 'SHOES']

# %%
#Getting URLs to each categories

categories_url = cat.find_all('a',href=True)
categories_url = [i['href'] for i in categories_url][1:]

# %%
#Dictionary containing men's categories and their URLs 

mens_categories = dict(zip(categories, categories_url))
print(mens_categories)
# Out:
# {'ACCESSORIES': '/en-ca/men/accessories', 'BAGS': '/en-ca/men/bags', 'CLOTHING': '/en-ca/men/clothing', 'SHOES': '/en-ca/men/shoes'}

# %%
#Diving into individual page of each categories - Example: Accessories

cat_page = requests.get("https://ssense.com" + mens_categories['ACCESSORIES'])
cat_soup = BeautifulSoup(cat_page.content, 'html.parser')

print(cat_soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-ca">
#  <head>
#   <meta content="en" name="language"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    Designer accessories for Men | SSENSE Canada
#   </title>
#   <meta content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=no,minimal-ui" name="viewport"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <script type="text/javascript">
#    window.NREUM||(NREUM={});NREUM.info = {"agent":"","beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"901b49cf57","applicationID":"233360527","applicationTime":7.554257,"transactionName":"ZlFbYEBRXkdWV0wPDV8bfExCQlVHRF5LSSV0YBYbV14dDlRbTQgWQ00WWVdeHw5UVUwDBV5GQA==","queueTime":0,"ttGuid":"888bd04c9cd1b0","agentToken":null}; (window.NREUM||(NREUM={})).loader_config={xpid:"VQIGUVBaCBACV1JRAQECVFM=",licenseKey:"901b49cf57",applicationID:"233360527"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{s.console&&console.log(t)}catch(e){}}var o,i=t("ee"),a=t(24),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,e,n){r(n.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,s){try{l?l-=1:o(s||new UncaughtException(t,e,n),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function o(t,e){var n=e?null:c.now();i("err",[t,n])}var i=t("handle"),a=t(25),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,p="nr@seenError",l=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(13),t(12),"addEventListener"in window&&t(6),c.xhrWrappable&&t(14),d=!0)}s.on("fn-start",function(t,e,n){d&&(l+=1)}),s.on("fn-err",function(t,e,n){d&&!n[p]&&(f(n,p,function(){return!0}),this.thrown=!0,o(n))}),s.on("fn-end",function(){d&&!this.thrown&&l>0&&(l-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})},{}],3:[function(t,e,n){t("loader").features.ins=!0},{}],4:[function(t,e,n){function r(){L++,C=g.hash,this[u]=y.now()}function o(){L--,g.hash!==C&&i(0,!0);var t=y.now();this[h]=~~this[h]+t-this[u],this[d]=t}function i(t,e){E.emit("newURL",[""+g,e])}function a(t,e){t.on(e,function(){this[e]=y.now()})}var s="-start",c="-end",f="-body",u="fn"+s,d="fn"+c,p="cb"+s,l="cb"+c,h="jsTime",m="fetch",v="addEventListener",w=window,g=w.location,y=t("loader");if(w[v]&&y.xhrWrappable){var x=t(10),b=t(11),E=t(8),R=t(6),O=t(13),N=t(7),P=t(14),M=t(9),T=t("ee"),S=T.get("tracer");t(16),y.features.spa=!0;var C,L=0;T.on(u,r),T.on(p,r),T.on(d,o),T.on(l,o),T.buffer([u,d,"xhr-done","xhr-resolved"]),R.buffer([u]),O.buffer(["setTimeout"+c,"clearTimeout"+s,u]),P.buffer([u,"new-xhr","send-xhr"+s]),N.buffer([m+s,m+"-done",m+f+s,m+f+c]),E.buffer(["newURL"]),x.buffer([u]),b.buffer(["propagate",p,l,"executor-err","resolve"+s]),S.buffer([u,"no-"+u]),M.buffer(["new-jsonp","cb-start","jsonp-error","jsonp-end"]),a(P,"send-xhr"+s),a(T,"xhr-resolved"),a(T,"xhr-done"),a(N,m+s),a(N,m+"-done"),a(M,"new-jsonp"),a(M,"jsonp-end"),a(M,"cb-start"),E.on("pushState-end",i),E.on("replaceState-end",i),w[v]("hashchange",i,!0),w[v]("load",i,!0),w[v]("popstate",function(){i(0,L>1)},!0)}},{}],5:[function(t,e,n){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(13),s=t(12),c="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",p="resource",l="-start",h="-end",m="fn"+l,v="fn"+h,w="bstTimer",g="pushState",y=t("loader");y.features.stn=!0,t(8),"addEventListener"in window&&t(6);var x=NREUM.o.EV;o.on(m,function(t,e){var n=t[0];n instanceof x&&(this.bstStart=y.now())}),o.on(v,function(t,e){var n=t[0];n instanceof x&&i("bst",[n,e,this.bstStart,y.now ...
#   </script>
#   <meta content="SSENSE" name="author"/>
#   <meta content="Buy designer accessories and get Free Shipping &amp; Returns in Canada. Shop the latest FW19 collection of designer for Men on SSENSE.com. Find what you are looking for amongst our directional selection of designer fashion and luxury streetwear." name="description"/>
#   <link href="//beacon.riskified.com" rel="dns-prefetch"/>
#   <link href="//c.riskified.com" rel="dns-prefetch"/>
#   <link href="//googleads.g.doubleclick.net" rel="dns-prefetch"/>
#   <link href="//stats.g.doubleclick.net" rel="dns-prefetch"/>
#   <link href="//www.google-analytics.com" rel="dns-prefetch"/>
#   <link href="//www.google.ca" rel="dns-prefetch"/>
#   <link href="//www.google.com" rel="dns-prefetch"/>
#   <link href="//www.googleadservices.com" rel="dns-prefetch"/>
#   <link href="//bat.bing.com" rel="dns-prefetch"/>
#   <link href="//connect.facebook.net" rel="dns-prefetch"/>
#   <link href="//res.cloudinary.com" rel="preconnect"/>
#   <link href="//res-1.cloudinary.com" rel="preconnect"/>
#   <link href="//res-2.cloudinary.com" rel="preconnect"/>
#   <link href="//res-3.cloudinary.com" rel="preconnect"/>
#   <link href="//res-4.cloudinary.com" rel="preconnect"/>
#   <link href="//res-5.cloudinary.com" rel="preconnect"/>
#   <link href="https://www.ssense.com/en-ca/men/accessories" rel="canonical"/>
#   <link href="https://www.ssense.com/en-ca/men/opensearch.xml" rel="search" title="SSENSE Search Men" type="application/opensearchdescription+xml"/>
#   <link href="https://www.ssense.com/en-ca/women/opensearch.xml" rel="search" title="SSENSE Search Women" type="application/opensearchdescription+xml"/>
#   <link href="https://www.ssense.com/en-ca/en-ca/men/accessories?page=2" rel="next"/>
#   <link href="https://www.ssense.com/en-us/men/accessories" hreflang="en-us" rel="alternate"/>
#   <link href="https://www.ssense.com/en-ca/men/accessories" hreflang="en-ca" rel="alternate"/>
#   <link href="https://www.ssense.com/en-gb/men/accessories" hreflang="en-gb" rel="alternate"/>
#   <link href="https://www.ssense.com/ja-jp/men/accessories" hreflang="ja-jp" rel="alternate"/>
#   <link href="https://www.ssense.com/fr-fr/hommes/accessoires" hreflang="fr-fr" rel="alternate"/>
#   <link href="https://www.ssense.com/zh-cn/men/accessories" hreflang="zh-Hans-cn" rel="alternate"/>
#   <link href="https://www.ssense.com/en-us/men/accessories" hreflang="en" rel="alternate"/>
#   <link href="https://www.ssense.com/ja-jp/men/accessories" hreflang="ja" rel="alternate"/>
#   <link href="https://www.ssense.com/fr-fr/hommes/accessoires" hreflang="fr" rel="alternate"/>
#   <link href="https://www.ssense.com/zh-cn/men/accessories" hreflang="zh-Hans" rel="alternate"/>
#   <link href="//res.cloudinary.com/ssenseweb/image/upload/v1472005257/web/favicon.ico" rel="icon" type="image/x-icon"/>
#   <link href="//img.ssensemedia.com/image/upload/v1574192255/favicon_ssense/favicon-16x16_byyzld.png" rel="shortcut icon" type="image/png"/>
#   <link href="//img.ssensemedia.com/image/upload/v1574192255/favicon_ssense/favicon-16x16_byyzld.png" rel="apple-touch-icon"/>
#   <link href="//img.ssensemedia.com/image/upload/v1574192255/favicon_ssense/apple-touch-icon-57x57_prssda.png" rel="apple-touch-icon" sizes="57x57"/>
#   <link href="//img.ssensemedia.com/image/upload/v1574192255/favicon_ssense/apple-touch-icon-114x114_uep0gt.png" rel="apple-touch-icon" sizes="114x114"/>
#   <link href="//img.ssensemedia.com/image/upload/v1574192255/favicon_ssense/apple-touch-icon-72x72_h1wgtx.png" rel="apple-touch-icon" sizes="72x72"/>
#   <link href="//img.ssensemedia.com/image/upload/v1574192254/favicon_ssense/mstile-144x144_x0cjmg.png" rel="apple-touch-icon" sizes="144x144"/>
#   <link href="//img.ssensemedia.com/image/upload/v1574192255/favicon_ssense/apple-touch-icon-60x60_rasic3.png" rel="apple-touch-icon" sizes="60x60"/>
#   <link href="//img.ssensemedia.com/image/upload/v1574192254/favicon_ssense/mstile-70x70_zaidh0.png" rel="apple-touch-icon" sizes="70x70"/>
#   <link href="//img.ssensemedia.com/image/upload/v1574192254/favicon_ssense/apple-touch-icon-120x120_sdj78o.png" rel="apple-touch-icon" sizes="120x120"/>
#   <link href="//img.ssensemedia.com/image/upload/v1574192255/favicon_ssense/apple-touch-icon-76x76_r9mdrx.png" rel="apple-touch-icon" sizes="76x76"/>
#   <link href="//img.ssensemedia.com/image/upload/v1574192254/favicon_ssense/mstile-150x150_aawpmj.png" rel="apple-touch-icon" sizes="150x150"/>
#   <link href="//img.ssensemedia.com/image/upload/v1574192254/favicon_ssense/apple-touch-icon-152x152_b8pday.png" rel="apple-touch-icon" sizes="152x152"/>
#   <link href="//img.ssensemedia.com/image/upload/v1574192255/favicon_ssense/favicon-196x196_vvei5a.png" rel="icon" sizes="196x196"/>
#   <link href="//img.ssensemedia.com/image/upload/v1574192254/favicon_ssense/mstile-150x150_aawpmj.png" rel="icon" sizes="150x150"/>
#   <link href="//img.ssensemedia.com/image/upload/v1574192255/favicon_ssense/favicon-96x96_f2fnwr.png" rel="icon" sizes="96x96"/>
#   <link href="//img.ssensemedia.com/image/upload/v1574192255/favicon_ssense/favicon-16x16_byyzld.png" rel="icon" sizes="16x16"/>
#   <link href="//img.ssensemedia.com/image/upload/v1574192255/favicon_ssense/favicon-32x32_sdslfh.png" rel="icon" sizes="32x32"/>
#   <link href="/assets/app.2d99c1d4b15b4ea364bd38a424126182.css" rel="stylesheet" type="text/css"/>
#   <!--  Hide retargeting iframe -->
#   <style type="text/css">
#    iframe[name="google_conversion_frame"] { display:none; }
#   </style>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=AW-1063827787">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#   function gtag() {
#     dataLayer.push(arguments);
#   }
#   gtag('js', new Date());
#   gtag('config', 'AW-1063827787', { 'send_page_view': false });
#   </script>
#   <!--
#   script enabled:
#   Add here the <script> portion of tracking
#   -->
#   <script>
#    // ----------------------------------------------
#   // Google Analytics initialization
#   // ----------------------------------------------
#   window.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new Date;
#
#   // Method to parse cookie value and set to window property
#   // params:
#   // cookieName: name of cookie to parse (string)
#   // nullReturnValue: what to set if cookie doesn't exist (any)
#   function getCookie(cookieName, nullReturnValue) {
#      return document.cookie.split('; ').filter(
#          function(pair){
#              return pair.indexOf(cookieName + '=') == 0 })[0] ?
#           document.cookie.split('; ').filter(
#               function(pair){
#                   return pair.indexOf(cookieName + '=') == 0 })[0].split('=')[1]
#           : nullReturnValue;
#   }
#
#   window.trackingId = getCookie('trackingId', null);
#   window.guestExperimentStatus = getCookie('guest_checkout_enabled', 'no-cookie');
#
#   try {
#     ga('create', 'UA-519637-1', {'siteSpeedSampleRate': 100});
#     if (window.trackingId){
#       ga('set', 'dimension9', window.trackingId);
#     }
#     // Dimension 10 is the new custom dimension to track conversion on legacy stack and legacy/new hybrid stack
#     ga('set', 'dimension10', '1');
#
#     // send value of guest checkout cookie to ga
#     if(window.guestExperimentStatus) {
#       ga('set', 'dimension18', window.guestExperimentStatus);
#     }
#     ga('require', 'ecommerce');
#     ga('require', 'eventTracker');
#     ga('require', 'outboundLinkTracker');
#     ga('require', 'urlChangeTracker');
#     ga('send', 'pageview');
#   } catch (e) {
#     // Rethrow errors from external scripts due to Same-Origin Policy
#     throw e;
#   }
#
#   /**
#    * Utils function to inject script src tag
#    */
#   function injectScript(src, supportsCors, onload) {
#     var head = document.getElementsByTagName('head')[0],
#         script = document.createElement('script');
#
#     script.type = 'text/javascript';
#     script.src = src;
#     script.onload = onload || function() {};
#
#     if (supportsCors) {
#       script.crossOrigin = 'anonymous';
#     }
#
#     head.appendChild(script);
#   }
#
#   // -------------------
#   // Riskified Beacon
#   // ----------------------------------------------
#   window.riskifiedBeaconLoad = function(sid) {
#       var store_domain = 'ssense.com';
#       var url = ('https:' == document.location.protocol ? 'https://' : 'http://') + "beacon.riskified.com?shop="+store_domain + "&sid="+sid;
#       var s = document.createElement('script');
#       s.type = 'text/javascript';
#       s.async = true;
#       s.defer = true;
#       s.src = url;
#       s.crossOrigin = "anonymous";
#       var x = document.getElementsByTagName('script')[0];
#       x.parentNode.insertBefore(s, x);
#   };
#
#   /**
#    * Initialize tracking when page is loaded
#    */
#   window.addEventListener('load', function(event) {
#     // -------------------
#     // Google Analytics
#     // ----------------------------------------------
#     injectScript('//www.google-analytics.com/analytics.js', false);
#
#     injectScript('//cdnjs.cloudflare.com/ajax/libs/autotrack/1.0.1/autotrack.js', true);
#   });
#   </script>
#   <!-- No script:Add here the <noscript> portion of tracking -->
#   <noscript>
#    <!-- Google Conversion -->
#    <div style="display:inline">
#     <img alt="" height="1" src="//googleads.g.doubleclick.net/pagead/viewthroughconversion/1063827787/?value=0&amp;label=IFM5CImLwQMQy_Ki-wM&amp;guid=ON&amp;script=0" style="border-style:none" width="1"/>
#    </div>
#    <!-- Bing ads -->
#    <img alt="" height="0" src="//bat.bing.com/action/0?ti=4008316&amp;Ver=2" style="display:none; visibility: hidden" width="0"/>
#    <!-- Facebook pixel code -->
#    <img alt="" height="1" src="https://www.facebook.com/tr?id=1084416341572353&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
#   </noscript>
#  </head>
#  <body>
#   <script type="text/javascript">
#    /* We do not support all browsers; When a user is using one of these
#   unsupported browsers show them a warning. */
#
#   (function() {
#
#     /* Browsers with HTMLPictureElement defined should be modern enough to
#     support everything we do [1]. Exceptions are IE 10-12 and Safari 8 which
#     we support via an HTMLPictureElement polyfill, but adds support for many
#     browsers including those we do not want to support (ie9, Safari7, ...).
#     Thus we must find another way to not-warn said exceptions. We do this by
#     UA sniffing (gasp)[2].
#
#     [1] http://caniuse.com/#feat=picture
#     [2] For details on our regex see http://regexr.com/3emos. */
#
#     var polyfilledUserAgents = /MSIE 10|MSIE 11|IE 11|Trident.*rv:11|WOW64;.*rv:11|Edge\/12|AppleWebKit.*Version\/(:?8|9\.0|9\.1|9\.2)/;
#
#     var isSupported = window.HTMLPictureElement
#                    || polyfilledUserAgents.test(navigator.userAgent);
#
#     if (!isSupported) {
#       var div = document.createElement("div");
#       div.innerHTML = "Sorry, your browser is not supported. You may experience some difficulties when shopping on SSENSE.";
#       div.className = "message-box failed";
#       div.style.position = "relative"; // [1]
#       div.style.opacity = "1"; // [2]
#       div.onclick = function () { document.body.removeChild(div); };
#       document.body.insertBefore(div, document.body.firstChild); // [3]
#
#       /*
#       [1] .message-box is `position: fixed` so it "hovers" over body content,
#       but we want this warning to push body content down instead.
#
#       [2] .message-box is designed to be faded in by our JS app, but we cannot
#       rely on any external JS here, so force opacity to 100%.
#
#       [3] If firstChild is `null` then `insertBefore` will put `div` at
#       end of child list of body which in this case would just mean first
#       child. Reference:
#       https://developer.mozilla.org/en-US/docs/Web/API/Node/insertBefore. */
#     }
#   })();
#   </script>
#   <script type="text/javascript">
#    /* Include babel-polyfill if browser dos not support Object.assign or window.Promise */
#
#   (function() {
#     if (typeof Object.assign !== "function" ||
#         typeof window.Promise !== "function") {
#
#       var head = document.getElementsByTagName('head')[0],
#           script = document.createElement('script');
#
#       script.type = 'text/javascript';
#       script.src = 'https://cdnjs.cloudflare.com/ajax/libs/babel-polyfill/6.23.0/polyfill.min.js';
#       script.crossOrigin = 'anonymous';
#       head.appendChild(script);
#     }
#   })();
#   </script>
#   <div data-server-rendered="true">
#    <div class="lang-en" id="app">
#     <div class="body-wrapper" style="padding-top:55px;">
#      <!-- -->
#      <header class="header opaque-header">
#       <div class="container-fluid">
#        <div class="row-fluid">
#         <nav class="span7 header-nav header-nav-left" data-v-6734adc4="" role="navigation">
#          <ul class="nav hidden-tablet-landscape">
#           <li>
#            <a class="router-link-active" data-v-6734adc4="" href="/en-ca/men" id="men-link">
#             Men
#            </a>
#           </li>
#           <li>
#            <a data-v-6734adc4="" href="/en-ca/women" id="women-link">
#             Women
#            </a>
#           </li>
#           <li>
#            <a data-v-6734adc4="" href="/en-ca/men/sale" id="sale-link">
#             sale
#            </a>
#           </li>
#           <!-- -->
#          </ul>
#          <ul class="nav mobile-navigation display-block-tablet-landscape">
#           <li class="side-menu-toggle">
#            <a href="#">
#             <i class="fa fa-ssense-menu">
#             </i>
#             <span class="menu-animated">
#             </span>
#            </a>
#           </li>
#           <li>
#            <a class="display-block-tablet-landscape" href="#">
#             <i class="fa fa-ssense-magnifier">
#             </i>
#            </a>
#           </li>
#          </ul>
#         </nav>
#         <div class="header-logo span2" data-v-37baba0c="" role="banner">
#          <a class="router-link-active" data-v-37baba0c="" href="/en-ca">
#           <img alt="SSENSE" class="site-logo dark" data-v-37baba0c="" src="//res.cloudinary.com/ssenseweb/image/upload/v1409080279/web/ssense_logo_v2.png"/>
#          </a>
#         </div>
#         <nav class="span7 header-nav header-nav-right" data-v-bd126e56="" role="navigation">
#          <ul class="nav hidden-tablet-landscape">
#           <li>
#            <a class="popover-hover-link" href="https://www.ssense.com/en-ca/men/accessories">
#             English
#            </a>
#            <div class="popover-center" data-v-88391330="" data-v-bd126e56="">
#             <div class="popover popover-alternate" id="language-menu-popover">
#              <ul data-v-bd126e56="">
#               <li>
#                <a href="https://www.ssense.com/fr-ca/hommes/accessoires" rel="nofollow">
#                 Français
#                </a>
#               </li>
#               <li>
#                <a href="https://www.ssense.com/ja-ca/men/accessories" rel="nofollow">
#                 日本語
#                </a>
#               </li>
#               <li>
#                <a href="https://www.ssense.com/zh-ca/men/accessories" rel="nofollow">
#                 中文
#                </a>
#               </li>
#              </ul>
#             </div>
#            </div>
#           </li>
#           <li>
#            <a data-v-bd126e56="" href="/en-ca/account/login">
#             login
#            </a>
#           </li>
#           <li>
#            <a class="right-nav-items" data-v-bd126e56="" href="/en-ca/account/wishlist">
#             wishlist
#            </a>
#           </li>
#           <li>
#            <a class="shopping-bag-link" data-v-bd126e56="" href="/en-ca/shopping-bag">
#             shopping bag (0)
#            </a>
#           </li>
#          </ul>
#          <ul class="nav mobile-navigation display-block-tablet-landscape">
#           <li class="account">
#            <a class="popover-hover-link" data-v-bd126e56="" href="/en-ca/account">
#             <i class="fa fa-ssense-account" data-v-bd126e56="">
#             </i>
#            </a>
#           </li>
#           <li class="shopping-bag">
#            <a class="shopping-bag-link" data-v-bd126e56="" href="/en-ca/shopping-bag">
#             <i class="fa fa-ssense-bag" data-v-bd126e56="">
#             </i>
#             <span class="header-shopping-bag-count miniBagCount" data-v-bd126e56="">
#              <span data-v-bd126e56="">
#               (
#              </span>
#              0
#              <span data-v-bd126e56="">
#               )
#              </span>
#             </span>
#            </a>
#           </li>
#          </ul>
#         </nav>
#        </div>
#       </div>
#       <!-- -->
#      </header>
#      <div>
#      </div>
#      <div class="notification-manager-container">
#       <span>
#       </span>
#      </div>
#      <!-- -->
#      <main class="main container-fluid" id="wrap" role="main">
#       <div class="browsing-page-root browsing-section-container view">
#        <div class="span12 browsing-column browsing-center-column tablet-landscape-full-fluid-width">
#         <section aria-labelledby="listing-title" class="browsing-product-container span12">
#          <div class="browsing-product-content">
#           <header class="row-fluid browsing-designer-header">
#            <div class="span12 offset2 browsing-header browsing-designer-header-content">
#             <h1 id="listing-title">
#              Accessories
#             </h1>
#             <p class="listing-description-text">
#              <span>
#               Treading a line between high-end appeal and irreverent attitude, our selection of menswear accessories runs the gamut from quiet and minimalist refinement to audacious creativity. Wide-brimmed fedoras, harness belts, and studded wraparound bracelets complement fringed scarves, cozy knit beanies, and fingerless gloves, while travel-ready timepieces, modernist eyewear, and iPhone cases showcase the futuristic touches of everyday lifestyle. Pocket essentials including bifold wallets, embossed card holders, money clips, and keychains enhance clean and simple design with subtly tongue-in-cheek details, in contrast to the rugged delicacy of understated necklaces and masculine carved rings. Together, they define a new and contemporary vision of elegance.
#              </span>
#              <!-- -->
#             </p>
#             <!-- -->
#            </div>
#           </header>
#           <!-- -->
#           <!-- -->
#           <div class="browsing-product-list">
#            <figure class="browsing-product-item">
#             <script type="application/ld+json">
#              {
#   "@context": "https://schema.org",
#   "@type": "Product",
#   "productID": 4607571,
#   "name": "Blue William De Morgan Edition Dragon Beanie",
#   "sku": "201677M138033",
#   "brand": {
#     "@type": "Brand",
#     "name": "Loewe"
#   },
#   "offers": {
#     "@type": "Offer",
#     "price": 1500,
#     "priceCurrency": "CAD",
#     "availability": "https://schema.org/InStock",
#     "url": "/men/product/loewe/blue-william-de-morgan-edition-dragon-beanie/4607571"
#   },
#   "url": "/men/product/loewe/blue-william-de-morgan-edition-dragon-beanie/4607571",
#   "image": "https://res.cloudinary.com/ssenseweb/image/upload/201677M138033_1.jpg"
# }
#             </script>
#             <a href="/en-ca/men/product/loewe/blue-william-de-morgan-edition-dragon-beanie/4607571">
#              <div class="image-container">
#               <picture data-v-60b7d3e3="">
#                <!-- -->
#                <!-- -->
#                <img alt="Loewe - Blue William De Morgan Edition Dragon Beanie" class="product-thumbnail lazyload" data-srcset="https://img.ssensemedia.com/images/b_white,c_lpad,g_south,h_706,w_470/c_scale,h_280/f_auto,dpr_1.0/201677M138033_1/loewe-blue-william-de-morgan-edition-dragon-beanie.jpg" src="https://res.cloudinary.com/ssenseweb/image/upload/v1472069180/product-placeholder_qulza9.png"/>
#               </picture>
#              </div>
#              <figcaption class="browsing-product-description text-center vspace1">
#               <p class="bold">
#                Loewe
#               </p>
#               <p class="product-name-plp">
#                Blue William De Morgan Edition Dragon Beanie
#               </p>
#              </figcaption>
#              <!-- -->
#             </a>
#             <div>
#              <p class="price">
#               <span class="price">
#                $1500
#               </span>
#               <!-- -->
#              </p>
#             </div>
#            </figure>
#            <figure class="browsing-product-item">
#             <script type="application/ld+json">
#              {
#   "@context": "https://schema.org",
#   "@type": "Product",
#   "productID": 4534841,
#   "name": "Black Industrial Belt",
#   "sku": "201607M131235",
#   "brand": {
#     "@type": "Brand",
#     "name": "Off-White"
#   },
#   "offers": {
#     "@type": "Offer",
#     "price": 285,
#     "priceCurrency": "CAD",
#     "availability": "https://schema.org/InStock",
#     "url": "/men/product/off-white/black-industrial-belt/4534841"
#   },
#   "url": "/men/product/off-white/black-industrial-belt/4534841",
#   "image": "https://res.cloudinary.com/ssenseweb/image/upload/201607M131235_1.jpg"
# }
#             </script>
#             <a href="/en-ca/men/product/off-white/black-industrial-belt/4534841">
#              <div class="image-container">
#               <picture data-v-60b7d3e3="">
#                <!-- -->
#                <!-- -->
#                <img alt="Off-White - Black Industrial Belt" class="product-thumbnail lazyload" data-srcset="https://img.ssensemedia.com/images/b_white,c_lpad,g_south,h_706,w_470/c_scale,h_280/f_auto,dpr_1.0/201607M131235_1/off-white-black-industrial-belt.jpg" src="https://res.cloudinary.com/ssenseweb/image/upload/v1472069180/product-placeholder_qulza9.png"/>
#               </picture>
#              </div>
#              <figcaption class="browsing-product-description text-center vspace1">
#               <p class="bold">
#                Off-White
#               </p>
#               <p class="product-name-plp">
#                Black Industrial Belt
#               </p>
#              </figcaption>
#              <!-- -->
#             </a>
#             <div>
#              <p class="price">
#               <span class="price">
#                $285
#               </span>
#               <!-- -->
#              </p>
#             </div>
#            </figure>
#            <figure class="browsing-product-item">
#             <script type="application/ld+json">
#              {
#   "@context": "https://schema.org",
#   "@type": "Product",
#   "productID": 4534851,
#   "name": "Yellow Industrial Belt",
#   "sku": "201607M131236",
#   "brand": {
#     "@type": "Brand",
#     "name": "Off-White"
#   },
#   "offers": {
#     "@type": "Offer",
#     "price": 285,
#     "priceCurrency": "CAD",
#     "availability": "https://schema.org/InStock",
#     "url": "/men/product/off-white/yellow-industrial-belt/4534851"
#   },
#   "url": "/men/product/off-white/yellow-industrial-belt/4534851",
#   "image": "https://res.cloudinary.com/ssenseweb/image/upload/201607M131236_1.jpg"
# }
#             </script>
#             <a href="/en-ca/men/product/off-white/yellow-industrial-belt/4534851">
#              <div class="image-container">
#               <picture data-v-60b7d3e3="">
#                <!-- -->
#                <!-- -->
#                <img alt="Off-White - Yellow Industrial Belt" class="product-thumbnail lazyload" data-srcset="https://img.ssensemedia.com/images/b_white,c_lpad,g_south,h_706,w_470/c_scale,h_280/f_auto,dpr_1.0/201607M131236_1/off-white-yellow-industrial-belt.jpg" src="https://res.cloudinary.com/ssenseweb/image/upload/v1472069180/product-placeholder_qulza9.png"/>
#               </picture>
#              </div>
#              <figcaption class="browsing-product-description text-center vspace1">
#               <p class="bold">
#                Off-White
#               </p>
#               <p class="product-name-plp">
#                Yellow Industrial Belt
#               </p>
#              </figcaption>
#              <!-- -->
#             </a>
#             <div>
#              <p class="price">
#               <span class="price">
#                $285
#               </span>
#               <!-- -->
#              </p>
#             </div>
#            </figure>
#            <figure class="browsing-product-item">
#             <script type="application/ld+json">
#              {
#   "@context": "https://schema.org",
#   "@type": "Product",
#   "productID": 4534861,
#   "name": "Black Mini Industrial Belt",
#   "sku": "201607M131237",
#   "brand": {
#     "@type": "Brand",
#     "name": "Off-White"
#   },
#   "offers": {
#     "@type": "Offer",
#     "price": 240,
#     "priceCurrency": "CAD",
#     "availability": "https://schema.org/InStock",
#     "url": "/men/product/off-white/black-mini-industrial-belt/4534861"
#   },
#   "url": "/men/product/off-white/black-mini-industrial-belt/4534861",
#   "image": "https://res.cloudinary.com/ssenseweb/image/upload/201607M131237_1.jpg"
# }
#             </script>
#             <a href="/en-ca/men/product/off-white/black-mini-industrial-belt/4534861">
#              <div class="image-container">
#               <picture data-v-60b7d3e3="">
#                <!-- -->
#                <!-- -->
#                <img alt="Off-White - Black Mini Industrial Belt" class="product-thumbnail lazyload" data-srcset="https://img.ssensemedia.com/images/b_white,c_lpad,g_south,h_706,w_470/c_scale,h_280/f_auto,dpr_1.0/201607M131237_1/off-white-black-mini-industrial-belt.jpg" src="https://res.cloudinary.com/ssenseweb/image/upload/v1472069180/product-placeholder_qulza9.png"/>
#               </picture>
#              </div>
#              <figcaption class="browsing-product-description text-center vspace1">
#               <p class="bold">
#                Off-White
#               </p>
#               <p class="product-name-plp">
#                Black Mini Industrial Belt
#               </p>
#              </figcaption>
#              <!-- -->
#             </a>
#             <div>
#              <p class="price">
#               <span class="price">
#                $240
#               </span>
#               <!-- -->
#              </p>
#             </div>
#            </figure>
#            <figure class="browsing-product-item">
#             <script type="application/ld+json">
#              {
#   "@context": "https://schema.org",
#   "@type": "Product",
#   "productID": 4534071,
#   "name": "Black Quote Yen Wallet",
#   "sku": "201607M164199",
#   "brand": {
#     "@type": "Brand",
#     "name": "Off-White"
#   },
#   "offers": {
#     "@type": "Offer",
#     "price": 400,
#     "priceCurrency": "CAD",
#     "availability": "https://schema.org/InStock",
#     "url": "/men/product/off-white/black-quote-yen-wallet/4534071"
#   },
#   "url": "/men/product/off-white/black-quote-yen-wallet/4534071",
#   "image": "https://res.cloudinary.com/ssenseweb/image/upload/201607M164199_1.jpg"
# }
#             </script>
#             <a href="/en-ca/men/product/off-white/black-quote-yen-wallet/4534071">
#              <div class="image-container">
#               <picture data-v-60b7d3e3="">
#                <!-- -->
#                <!-- -->
#                <img alt="Off-White - Black Quote Yen Wallet" class="product-thumbnail lazyload" data-srcset="https://img.ssensemedia.com/images/b_white,c_lpad,g_south,h_706,w_470/c_scale,h_280/f_auto,dpr_1.0/201607M164199_1/off-white-black-quote-yen-wallet.jpg" src="https://res.cloudinary.com/ssenseweb/image/upload/v1472069180/product-placeholder_qulza9.png"/>
#               </picture>
#              </div>
#              <figcaption class="browsing-product-description text-center vspace1">
#               <p class="bold">
#                Off-White
#               </p>
#               <p class="product-name-plp">
#                Black Quote Yen Wallet
#               </p>
#              </figcaption>
#              <!-- -->
#             </a>
#             <div>
#              <p class="price">
#               <span class="price">
#                $400
#               </span>
#               <!-- -->
#              </p>
#             </div>
#            </figure>
#            <figure class="browsing-product-item">
#             <script type="application/ld+json">
#              {
#   "@context": "https://schema.org",
#   "@type": "Product",
#   "productID": 4534221,
#   "name": "Black Quote Card Holder",
#   "sku": "201607M149208",
#   "brand": {
#     "@type": "Brand",
#     "name": "Off-White"
#   },
#   "offers": {
#     "@type": "Offer",
#     "price": 265,
#     "priceCurrency": "CAD",
#     "availability": "https://schema.org/InStock",
#     "url": "/men/product/off-white/black-quote-card-holder/4534221"
#   },
#   "url": "/men/product/off-white/black-quote-card-holder/4534221",
#   "image": "https://res.cloudinary.com/ssenseweb/image/upload/201607M149208_1.jpg"
# }
#             </script>
#             <a href="/en-ca/men/product/off-white/black-quote-card-holder/4534221">
#              <div class="image-container">
#               <picture data-v-60b7d3e3="">
#                <!-- -->
#                <!-- -->
#                <img alt="Off-White - Black Quote Card Holder" class="product-thumbnail lazyload" data-srcset="https://img.ssensemedia.com/images/b_white,c_lpad,g_south,h_706,w_470/c_scale,h_280/f_auto,dpr_1.0/201607M149208_1/off-white-black-quote-card-holder.jpg" src="https://res.cloudinary.com/ssenseweb/image/upload/v1472069180/product-placeholder_qulza9.png"/>
#               </picture>
#              </div>
#              <figcaption class="browsing-product-description text-center vspace1">
#               <p class="bold">
#                Off-White
#               </p>
#               <p class="product-name-plp">
#                Black Quote Card Holder
#               </p>
#              </figcaption>
#              <!-- -->
#             </a>
#             <div>
#              <p class="price">
#               <span class="price">
#                $265
#               </span>
#               <!-- -->
#              </p>
#             </div>
#            </figure>
#            <figure class="browsing-product-item">
#             <script type="application/ld+json">
#              {
#   "@context": "https://schema.org",
#   "@type": "Product",
#   "productID": 4534051,
#   "name": "Black Quote Passport Holder",
#   "sku": "201607M162200",
#   "brand": {
#     "@type": "Brand",
#     "name": "Off-White"
#   },
#   "offers": {
#     "@type": "Offer",
#     "price": 335,
#     "priceCurrency": "CAD",
#     "availability": "https://schema.org/InStock",
#     "url": "/men/product/off-white/black-quote-passport-holder/4534051"
#   },
#   "url": "/men/product/off-white/black-quote-passport-holder/4534051",
#   "image": "https://res.cloudinary.com/ssenseweb/image/upload/201607M162200_1.jpg"
# }
#             </script>
#             <a href="/en-ca/men/product/off-white/black-quote-passport-holder/4534051">
#              <div class="image-container">
#               <picture data-v-60b7d3e3="">
#                <!-- -->
#                <!-- -->
#                <img alt="Off-White - Black Quote Passport Holder" class="product-thumbnail lazyload" data-srcset="https://img.ssensemedia.com/images/b_white,c_lpad,g_south,h_706,w_470/c_scale,h_280/f_auto,dpr_1.0/201607M162200_1/off-white-black-quote-passport-holder.jpg" src="https://res.cloudinary.com/ssenseweb/image/upload/v1472069180/product-placeholder_qulza9.png"/>
#               </picture>
#              </div>
#              <figcaption class="browsing-product-description text-center vspace1">
#               <p class="bold">
#                Off-White
#               </p>
#               <p class="product-name-plp">
#                Black Quote Passport Holder
#               </p>
#              </figcaption>
#              <!-- -->
#             </a>
#             <div>
#              <p class="price">
#               <span class="price">
#                $335
#               </span>
#               <!-- -->
#              </p>
#             </div>
#            </figure>
#            <figure class="browsing-product-item">
#             <script type="application/ld+json">
#              {
#   "@context": "https://schema.org",
#   "@type": "Product",
#   "productID": 4534041,
#   "name": "Black Logo Passport Holder",
#   "sku": "201607M162199",
#   "brand": {
#     "@type": "Brand",
#     "name": "Off-White"
#   },
#   "offers": {
#     "@type": "Offer",
#     "price": 335,
#     "priceCurrency": "CAD",
#     "availability": "https://schema.org/InStock",
#     "url": "/men/product/off-white/black-logo-passport-holder/4534041"
#   },
#   "url": "/men/product/off-white/black-logo-passport-holder/4534041",
#   "image": "https://res.cloudinary.com/ssenseweb/image/upload/201607M162199_1.jpg"
# }
#             </script>
#             <a href="/en-ca/men/product/off-white/black-logo-passport-holder/4534041">
#              <div class="image-container">
#               <picture data-v-60b7d3e3="">
#                <!-- -->
#                <!-- -->
#                <img alt="Off-White - Black Logo Passport Holder" class="product-thumbnail lazyload" data-srcset="https://img.ssensemedia.com/images/b_white,c_lpad,g_south,h_706,w_470/c_scale,h_280/f_auto,dpr_1.0/201607M162199_1/off-white-black-logo-passport-holder.jpg" src="https://res.cloudinary.com/ssenseweb/image/upload/v1472069180/product-placeholder_qulza9.png"/>
#               </picture>
#              </div>
#              <figcaption class="browsing-product-description text-center vspace1">
#               <p class="bold">
#                Off-White
#               </p>
#               <p class="product-name-plp">
#                Black Logo Passport Holder
#               </p>
#              </figcaption>
#              <!-- -->
#             </a>
#             <div>
#              <p class="price">
#               <span class="price">
#                $335
#               </span>
#               <!-- -->
#              </p>
#             </div>
#            </figure>
#            <figure class="browsing-product-item">
#             <script type="application/ld+json">
#              {
#   "@context": "https://schema.org",
#   "@type": "Product",
#   "productID": 4534211,
#   "name": "Black Logo Card Holder",
#   "sku": "201607M163207",
#   "brand": {
#     "@type": "Brand",
#     "name": "Off-White"
#   },
#   "offers": {
#     "@type": "Offer",
#     "price": 265,
#     "priceCurrency": "CAD",
#     "availability": "https://schema.org/InStock",
#     "url": "/men/product/off-white/black-logo-card-holder/4534211"
#   },
#   "url": "/men/product/off-white/black-logo-card-holder/4534211",
#   "image": "https://res.cloudinary.com/ssenseweb/image/upload/201607M163207_1.jpg"
# }
#             </script>
#             <a href="/en-ca/men/product/off-white/black-logo-card-holder/4534211">
#              <div class="image-container">
#               <picture data-v-60b7d3e3="">
#                <!-- -->
#                <!-- -->
#                <img alt="Off-White - Black Logo Card Holder" class="product-thumbnail lazyload" data-srcset="https://img.ssensemedia.com/images/b_white,c_lpad,g_south,h_706,w_470/c_scale,h_280/f_auto,dpr_1.0/201607M163207_1/off-white-black-logo-card-holder.jpg" src="https://res.cloudinary.com/ssenseweb/image/upload/v1472069180/product-placeholder_qulza9.png"/>
#               </picture>
#              </div>
#              <figcaption class="browsing-product-description text-center vspace1">
#               <p class="bold">
#                Off-White
#               </p>
#               <p class="product-name-plp">
#                Black Logo Card Holder
#               </p>
#              </figcaption>
#              <!-- -->
#             </a>
#             <div>
#              <p class="price">
#               <span class="price">
#                $265
#               </span>
#               <!-- -->
#              </p>
#             </div>
#            </figure>
#            <figure class="browsing-product-item">
#             <script type="application/ld+json">
#              {
#   "@context": "https://schema.org",
#   "@type": "Product",
#   "productID": 4534021,
#   "name": "Black Quote Bifold Wallet",
#   "sku": "201607M164197",
#   "brand": {
#     "@type": "Brand",
#     "name": "Off-White"
#   },
#   "offers": {
#     "@type": "Offer",
#     "price": 355,
#     "priceCurrency": "CAD",
#     "availability": "https://schema.org/InStock",
#     "url": "/men/product/off-white/black-quote-bifold-wallet/4534021"
#   },
#   "url": "/men/product/off-white/black-quote-bifold-wallet/4534021",
#   "image": "https://res.cloudinary.com/ssenseweb/image/upload/201607M164197_1.jpg"
# }
#             </script>
#             <a href="/en-ca/men/product/off-white/black-quote-bifold-wallet/4534021">
#              <div class="image-container">
#               <picture data-v-60b7d3e3="">
#                <!-- -->
#                <!-- -->
#                <img alt="Off-White - Black Quote Bifold Wallet" class="product-thumbnail lazyload" data-srcset="https://img.ssensemedia.com/images/b_white,c_lpad,g_south,h_706,w_470/c_scale,h_280/f_auto,dpr_1.0/201607M164197_1/off-white-black-quote-bifold-wallet.jpg" src="https://res.cloudinary.com/ssenseweb/image/upload/v1472069180/product-placeholder_qulza9.png"/>
#               </picture>
#              </div>
#              <figcaption class="browsing-product-description text-center vspace1">
#               <p class="bold">
#                Off-White
#               </p>
#               <p class="product-name-plp">
#                Black Quote Bifold Wallet
#               </p>
#              </figcaption>
#              <!-- -->
#             </a>
#             <div>
#              <p class="price">
#               <span class="price">
#                $355
#               </span>
#               <!-- -->
#              </p>
#             </div>
#            </figure>
#            <figure class="browsing-product-item">
#             <script type="application/ld+json">
#              {
#   "@context": "https://schema.org",
#   "@type": "Product",
#   "productID": 4534871,
#   "name": "Yellow Mini Industrial Belt",
#   "sku": "201607M131238",
#   "brand": {
#     "@type": "Brand",
#     "name": "Off-White"
#   },
#   "offers": {
#     "@type": "Offer",
#     "price": 240,
#     "priceCurrency": "CAD",
#     "availability": "https://schema.org/InStock",
#     "url": "/men/product/off-white/yellow-mini-industrial-belt/4534871"
#   },
#   "url": "/men/product/off-white/yellow-mini-industrial-belt/4534871",
#   "image": "https://res.cloudinary.com/ssenseweb/image/upload/201607M131238_1.jpg"
# }
#             </script>
#             <a href="/en-ca/men/product/off-white/yellow-mini-industrial-belt/4534871">
#              <div class="image-container">
#               <picture data-v-60b7d3e3="">
#                <!-- -->
#                <!-- -->
#                <img alt="Off-White - Yellow Mini Industrial Belt" class="product-thumbnail lazyload" data-srcset="https://img.ssensemedia.com/images/b_white,c_lpad,g_south,h_706,w_470/c_scale,h_280/f_auto,dpr_1.0/201607M131238_1/off-white-yellow-mini-industrial-belt.jpg" src="https://res.cloudinary.com/ssenseweb/image/upload/v1472069180/product-placeholder_qulza9.png"/>
#               </picture>
#              </div>
#              <figcaption class="browsing-product-description text-center vspace1">
#               <p class="bold">
#                Off-White
#               </p>
#               <p class="product-name-plp">
#                Yellow Mini Industrial Belt
#               </p>
#              </figcaption>
#              <!-- -->
#             </a>
#             <div>
#              <p class="price">
#               <span class="price">
#                $240
#               </span>
#               <!-- -->
#              </p>
#             </div>
#            </figure>
#            <figure class="browsing-product-item">
#             <script type="application/ld+json">
#              {
#   "@context": "https://schema.org",
#   "@type": "Product",
#   "productID": 4534101,
#   "name": "Black Quote Wallet",
#   "sku": "201607M164202",
#   "brand": {
#     "@type": "Brand",
#     "name": "Off-White"
#   },
#   "offers": {
#     "@type": "Offer",
#     "price": 335,
#     "priceCurrency": "CAD",
#     "availability": "https://schema.org/InStock",
#     "url": "/men/product/off-white/black-quote-wallet/4534101"
#   },
#   "url": "/men/product/off-white/black-quote-wallet/4534101",
#   "image": "https://res.cloudinary.com/ssenseweb/image/upload/201607M164202_1.jpg"
# }
#             </script>
#             <a href="/en-ca/men/product/off-white/black-quote-wallet/4534101">
#              <div class="image-container">
#               <picture data-v-60b7d3e3="">
#                <!-- -->
#                <!-- -->
#                <img alt="Off-White - Black Quote Wallet" class="product-thumbnail lazyload" data-srcset="https://img.ssensemedia.com/images/b_white,c_lpad,g_south,h_706,w_470/c_scale,h_280/f_auto,dpr_1.0/201607M164202_1/off-white-black-quote-wallet.jpg" src="https://res.cloudinary.com/ssenseweb/image/upload/v1472069180/product-placeholder_qulza9.png"/>
#               </picture>
#              </div>
#              <figcaption class="browsing-product-description text-center vspace1">
#               <p class="bold">
#                Off-White
#               </p>
#               <p class="product-name-plp">
#                Black Quote Wallet
#               </p>
#              </figcaption>
#              <!-- -->
#             </a>
#             <div>
#              <p class="price">
#               <span class="price">
#                $335
#               </span>
#               <!-- -->
#              </p>
#             </div>
#            </figure>
#            <figure class="browsing-product-item">
#             <script type="application/ld+json">
#              {
#   "@context": "https://schema.org",
#   "@type": "Product",
#   "productID": 4534721,
#   "name": "Black & Beige Tape Arrows iPhone XR Case",
#   "sku": "201607M153228",
#   "brand": {
#     "@type": "Brand",
#     "name": "Off-White"
#   },
#   "offers": {
#     "@type": "Offer",
#     "price": 120,
#     "priceCurrency": "CAD",
#     "availability": "https://schema.org/InStock",
#     "url": "/men/product/off-white/black-and-beige-tape-arrows-iphone-xr-case/4534721"
#   },
#   "url": "/men/product/off-white/black-and-beige-tape-arrows-iphone-xr-case/4534721",
#   "image": "https://res.cloudinary.com/ssenseweb/image/upload/201607M153228_1.jpg"
# }
#             </script>
#             <a href="/en-ca/men/product/off-white/black-and-beige-tape-arrows-iphone-xr-case/4534721">
#              <div class="image-container">
#               <picture data-v-60b7d3e3="">
#                <!-- -->
#                <!-- -->
#                <img alt="Off-White - Black &amp; Beige Tape Arrows iPhone XR Case" class="product-thumbnail lazyload" data-srcset="https://img.ssensemedia.com/images/b_white,c_lpad,g_south,h_706,w_470/c_scale,h_280/f_auto,dpr_1.0/201607M153228_1/off-white-black--beige-tape-arrows-iphone-xr-case.jpg" src="https://res.cloudinary.com/ssenseweb/image/upload/v1472069180/product-placeholder_qulza9.png"/>
#               </picture>
#              </div>
#              <figcaption class="browsing-product-description text-center vspace1">
#               <p class="bold">
#                Off-White
#               </p>
#               <p class="product-name-plp">
#                Black &amp; Beige Tape Arrows iPhone XR Case
#               </p>
#              </figcaption>
#              <!-- -->
#             </a>
#             <div>
#              <p class="price">
#               <span class="price">
#                $120
#               </span>
#               <!-- -->
#              </p>
#             </div>
#            </figure>
#            <figure class="browsing-product-item">
#             <script type="application/ld+json">
#              {
#   "@context": "https://schema.org",
#   "@type": "Product",
#   "productID": 4534731,
#   "name": "Black 3D Crossed Off iPhone XS Case",
#   "sku": "201607M153229",
#   "brand": {
#     "@type": "Brand",
#     "name": "Off-White"
#   },
#   "offers": {
#     "@type": "Offer",
#     "price": 135,
#     "priceCurrency": "CAD",
#     "availability": "https://schema.org/InStock",
#     "url": "/men/product/off-white/black-3d-crossed-off-iphone-xs-case/4534731"
#   },
#   "url": "/men/product/off-white/black-3d-crossed-off-iphone-xs-case/4534731",
#   "image": "https://res.cloudinary.com/ssenseweb/image/upload/201607M153229_1.jpg"
# }
#             </script>
#             <a href="/en-ca/men/product/off-white/black-3d-crossed-off-iphone-xs-case/4534731">
#              <div class="image-container">
#               <picture data-v-60b7d3e3="">
#                <!-- -->
#                <!-- -->
# ...
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#           <!-- -->
#          </nav>
#         </div>
#        </div>
#       </div>
#      </main>
#     </div>
#     <footer class="footer" data-v-17f2a208="" style="visibility:visible;">
#      <div class="container-fluid">
#       <div class="row-fluid">
#        <div class="footer-desktop span16 hidden-tablet-landscape" data-v-17f2a208="">
#         <nav class="footer-desktop-right-nav" data-v-17f2a208="" data-v-363cdc87="" role="navigation">
#          <div class="row-fluid">
#           <div class="span16">
#            <ul class="social hide-social-tablet" data-v-363cdc87="">
#             <li>
#              <a aria-label="facebook" class="i facebook" href="//www.facebook.com/SSENSEofficial" target="_blank">
#               <i class="fa fa-facebook fa-fw">
#               </i>
#              </a>
#             </li>
#             <li>
#              <a aria-label="twitter" class="i twitter" href="//twitter.com/ssense" target="_blank">
#               <i class="fa fa-twitter fa-fw">
#               </i>
#              </a>
#             </li>
#             <li>
#              <a aria-label="instagram" class="i instagram" href="//instagram.com/ssense" target="_blank">
#               <i class="fa fa-instagram fa-fw">
#               </i>
#              </a>
#             </li>
#             <li>
#              <a aria-label="youtube" class="i youtube" href="//www.youtube.com/user/ssense" target="_blank">
#               <i class="fa fa-youtube fa-fw">
#               </i>
#              </a>
#             </li>
#            </ul>
#            <ul class="nav footer-links">
#             <li>
#              <a data-current-country="Canada" href="#">
#               COUNTRY/REGION: Canada
#              </a>
#              <div class="popover-center" data-v-363cdc87="" data-v-88391330="">
#               <div class="popover popover-alternate popover-padding no-border" id="footer-country-select">
#                <div class="footer-country-popover popover-alternate" data-v-363cdc87="" data-v-7d47f068="" style="display:block;">
#                 <ul class="country-list" data-v-1011490a="" data-v-7d47f068="">
#                  <div>
#                   <li>
#                    <a href="https://www.ssense.com/en-ca/men/accessories">
#                     Canada
#                    </a>
#                   </li>
#                   <li>
#                    <a href="https://www.ssense.com/en-us/men/accessories">
#                     United States
#                    </a>
#                   </li>
#                   <li>
#                    <a href="https://www.ssense.com/en-gb/men/accessories">
#                     United Kingdom
#                    </a>
#                   </li>
#                   <li>
#                    <a href="https://www.ssense.com/ja-jp/men/accessories">
#                     Japan
#                    </a>
#                   </li>
#                   <li>
#                    <a href="https://www.ssense.com/zh-cn/men/accessories">
#                     China
#                    </a>
#                   </li>
#                   <li>
#                    <a href="https://www.ssense.com/fr-fr/hommes/accessoires">
#                     France
#                    </a>
#                   </li>
#                  </div>
#                  <!-- -->
#                  <li>
#                   <a data-v-1011490a="" href="/en-ca/countries" rel="nofollow">
#                    <b data-v-1011490a="">
#                     View all
#                    </b>
#                   </a>
#                  </li>
#                 </ul>
#                 <input class="country-search-input" placeholder="SEARCH COUNTRY/REGION" type="text" value=""/>
#                </div>
#               </div>
#              </div>
#             </li>
#             <li>
#              <a href="#">
#               newsletter signup
#              </a>
#              <div class="popover-center" data-v-363cdc87="" data-v-88391330="">
#               <div class="popover popover-alternate popover-padding" id="footer-nl-form">
#                <div data-v-09e96a47="" data-v-363cdc87="">
#                 <!-- -->
#                 <form action="/en-ca/newsletters/subscribers" class="newsletter-form-container" method="POST">
#                  <input id="source" name="source" type="hidden" value="SSENSE_NL_SIGNUP"/>
#                  <div class="row-fluid">
#                   <div class="span16">
#                    <p>
#                     Sign up for email updates and promotions
#                    </p>
#                   </div>
#                   <div class="span16 relative tablet-portrait-full-fluid-width vspace2">
#                    <input autocapitalize="off" autocorrect="off" class="email-input" id="popover-footer_email" name="email" placeholder="Email address" tabindex="1" type="text" value=""/>
#                    <!-- -->
#                   </div>
#                   <div class="relative smartphone-portrait-full-fluid-width genders-container visible span16 vspace1">
#                    <div class="radio-input-wrap">
#                     <input checked="checked" class="capitalize" name="genderFooter" tabindex="2" type="radio" value="men"/>
#                     <label class="capitalize" for="popover-footer_gender_men">
#                      Men
#                     </label>
#                    </div>
#                    <div class="radio-input-wrap">
#                     <input class="capitalize" name="genderFooter" tabindex="2" type="radio" value="women"/>
#                     <label class="capitalize" for="popover-footer_gender_women">
#                      Women
#                     </label>
#                    </div>
#                    <div id="error_genderFooter" style="display:none;">
#                    </div>
#                   </div>
#                   <!-- -->
#                   <div class="span16 vspace1 submit-container visible">
#                    <button class="button full-width lighter" data-v-09e96a47="" type="submit">
#                     <span class="button-label">
#                      subscribe
#                     </span>
#                     <span class="load-wrapper" style="display:none;">
#                      <span class="load-animation">
#                       <span class="dot" style="width:3px;height:3px;border-radius:3px;margin-right:12px;animation:0.44999999999999996s 0s blink step-end infinite;">
#                       </span>
#                       <span class="dot" style="width:3px;height:3px;border-radius:3px;margin-right:12px;animation:0.44999999999999996s 0.075s blink step-end infinite;">
#                       </span>
#                       <span class="dot" style="width:3px;height:3px;border-radius:3px;margin-right:0px;animation:0.44999999999999996s 0.15s blink step-end infinite;">
#                       </span>
#                      </span>
#                     </span>
#                    </button>
#                   </div>
#                   <div class="relative smartphone-portrait-full-fluid-width legal-consent-wrapper span16 visible">
#                    <p class="legal-consent-1">
#                     You may unsubscribe at any time.
#                    </p>
#                    <p>
#                     To find out more, please visit our
#                     <a href="/en-ca/privacy-policy">
#                      Privacy Policy
#                     </a>
#                     .
#                    </p>
#                   </div>
#                  </div>
#                 </form>
#                 <!-- -->
#                </div>
#               </div>
#              </div>
#             </li>
#             <li>
#              <a data-v-363cdc87="" href="/en-ca/customer-service">
#               customer care
#              </a>
#             </li>
#             <li>
#              <a href="#">
#               locations
#              </a>
#              <div class="popover-center footer-location-select" data-v-363cdc87="" data-v-88391330="">
#               <div class="popover popover-alternate" id="footer-locations-select">
#                <ul class="footer-location-select-items" data-v-363cdc87="" data-v-addbeaa0="">
#                 <li>
#                  <a class-active="" data-v-addbeaa0="" href="/en-ca/locations/montreal">
#                   <span data-v-addbeaa0="">
#                    SSENSE MONTRÉAL
#                   </span>
#                  </a>
#                 </li>
#                 <li class="footer-location-select-items-border-top">
#                  <a class-active="" data-v-addbeaa0="" href="/en-ca/appointments">
#                   <span data-v-addbeaa0="">
#                    APPOINTMENTS
#                   </span>
#                  </a>
#                 </li>
#                </ul>
#               </div>
#              </div>
#             </li>
#             <li>
#              <a data-v-363cdc87="" href="/en-ca/editorial">
#               Editorial Archive
#              </a>
#             </li>
#             <li>
#              <a href="/en-ca/careers">
#               careers
#              </a>
#             </li>
#             <li>
#              <a href="/en-ca/affiliates">
#               affiliates
#              </a>
#             </li>
#             <li>
#              <a data-v-363cdc87="" href="/en-ca/sitemap">
#               sitemap
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </nav>
#         <div class="footer-desktop-left-nav" data-v-17f2a208="" data-v-5d95572c="" role="contentinfo">
#          <div class="row-fluid">
#           <div class="span16 flex-straight">
#            <ul class="nav copyright">
#             <li>
#              © 2019 ssense.com
#             </li>
#             <li class="hidden-tablet-landscape">
#              <a data-v-5d95572c="" href="/en-ca/terms-conditions">
#               Terms &amp; Conditions
#              </a>
#             </li>
#             <li class="hidden-tablet-landscape">
#              <a data-v-5d95572c="" href="/en-ca/privacy-policy">
#               Privacy Policy
#              </a>
#             </li>
#             <li>
#              <a data-v-5d95572c="" href="/en-ca/customer-service/accessibility">
#               Accessibility
#              </a>
#             </li>
#            </ul>
#            <ul class="social show-social-tablet" data-v-5d95572c="">
#             <li>
#              <a aria-label="facebook" class="i facebook" href="//www.facebook.com/SSENSEofficial" target="_blank">
#               <i class="fa fa-facebook fa-fw">
#               </i>
#              </a>
#             </li>
#             <li>
#              <a aria-label="twitter" class="i twitter" href="//twitter.com/ssense" target="_blank">
#               <i class="fa fa-twitter fa-fw">
#               </i>
#              </a>
#             </li>
#             <li>
#              <a aria-label="instagram" class="i instagram" href="//instagram.com/ssense" target="_blank">
#               <i class="fa fa-instagram fa-fw">
#               </i>
#              </a>
#             </li>
#             <li>
#              <a aria-label="youtube" class="i youtube" href="//www.youtube.com/user/ssense" target="_blank">
#               <i class="fa fa-youtube fa-fw">
#               </i>
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </footer>
#     <div class="gdpr-popup desktop" data-v-198a9b00="" style="display:none;">
#      <p>
#       SSENSE uses cookies that identify your device to provide you with a better online shopping experience, tailored to your preferences.
#      </p>
#      <p>
#       To find out more and learn how to opt out, please visit our
#       <a data-v-198a9b00="" href="/en-ca/privacy-policy">
#        Privacy Policy
#       </a>
#       .
#      </p>
#      <button>
#       accept and close
#      </button>
#     </div>
#     <!-- -->
#    </div>
#   </div>
#   <script>
#    window.INITIAL_STATE={"modals":{"modals":{}},"component":{"name":"ProductList","props":{"gender":"men","page":1,"category":{"id":1,"name":"ACCESSORIES","description":"Treading a line between high-end appeal and irreverent attitude, our selection of menswear accessories runs the gamut from quiet and minimalist refinement to audacious creativity. Wide-brimmed fedoras, harness belts, and studded wraparound bracelets complement fringed scarves, cozy knit beanies, and fingerless gloves, while travel-ready timepieces, modernist eyewear, and iPhone cases showcase the futuristic touches of everyday lifestyle. Pocket essentials including bifold wallets, embossed card holders, money clips, and keychains enhance clean and simple design with subtly tongue-in-cheek details, in contrast to the rugged delicacy of understated necklaces and masculine carved rings. Together, they define a new and contemporary vision of elegance.","gender":"all","seoKeyword":{"en":"accessories","fr":"accessoires","ja":"accessories","zh":"accessories"},"sizes":["34\u002F35","5.5","60","36\u002F37","6","65","38\u002F39","6.5","70","40\u002F41","7","75","80","42\u002F43","7.5","8","85","44\u002F45","46\u002F47","8.5","90","9","95","100","9.5","10","105","10.5","110","11","115","120"]},"displayLaunchingSoon":null}},"context":{"isBrowser":false,"viewport":{"width":0,"height":0,"isDesktop":false,"isMobile":false,"isTablet":false,"isTabletMobile":false,"isSmartphone":false},"locale":"en","region":"ca","country":{"name":"Canada","code":"ca","currency":"CAD","showOrigin":true,"priceDisplayRule":"base_price","freeShippingThreshold":100,"shippingThresholds":[{"shippingType":"outbound","thresholds":[{"countryCode":"CA","currencyCode":"CAD","orderMinValue":100,"orderMaxValue":null,"price":0},{"countryCode":"CA","currencyCode":"USD","orderMinValue":null,"orderMaxValue":null,"price":0}]},{"shippingType":"returns","thresholds":[{"countryCode":"CA","currencyCode":"CAD","orderMinValue":null,"orderMaxValue":null,"price":0},{"countryCode":"CA","currencyCode":"USD","orderMinValue":null,"orderMaxValue":null,"price":0}]}]},"title":"Designer accessories for Men | SSENSE Canada","alternateUrls":{"en-us":"https:\u002F\u002Fwww.ssense.com\u002Fen-us\u002Fmen\u002Faccessories","en-ca":"https:\u002F\u002Fwww.ssense.com\u002Fen-ca\u002Fmen\u002Faccessories","en-gb":"https:\u002F\u002Fwww.ssense.com\u002Fen-gb\u002Fmen\u002Faccessories","ja-jp":"https:\u002F\u002Fwww.ssense.com\u002Fja-jp\u002Fmen\u002Faccessories","fr-fr":"https:\u002F\u002Fwww.ssense.com\u002Ffr-fr\u002Fhommes\u002Faccessoires","zh-cn":"https:\u002F\u002Fwww.ssense.com\u002Fzh-cn\u002Fmen\u002Faccessories"},"hostUrl":"https:\u002F\u002Fwww.ssense.com","gender":"men","isSaleEnabled":true,"isSearchEnabled":true,"isSaleSoon":false,"isFreeShippingEnabled":true,"isNilSearchEnabled":true,"isRetailLinksEnabled":true,"isLiveAssistanceEnabled":true,"isAppointmentsEnabled":true,"isAppointmentSectionEnabled":false,"isAutocompleteEnabled":true,"maxPendingAppointments":2,"liveAssistanceApiKey":"4EUlI6cuYHKKYy7MRbJs2FL8EdPFQrrS","liveAssistanceVersion":"4EUlI6cuYHKKYy7MRbJs2FL8EdPFQrrS","isCaptchaEnabled":true,"isNewLoginCaptchaEnabled":true,"isGoogleHireIFrameEnabled":false,"isGdprPopupEnabled":true,"captchaPublicKey":"6LcJOjkUAAAAAL3zscDofxFZre0jDq_Yi-o24XVh","captchaModules":["pdp","login"],"isSkuCaptchaProtected":false,"gaProperty":"UA-519637-1","displayRemainingStockWishlist":true,"displayRemainingStockPdp":true,"displayRemainingStockCart":true,"geoCountry":{"code":"ca","name":"Canada"},"countryDefaultLanguage":["en-us","ja-jp","fr-fr","zh-cn"],"facets":{"categories":[],"brands":[]},"opaqueHeader":false,"departmentsWithSizeFiltering":[4],"captchaSupportedCountry":true,"displayPrivacyPolicy":true,"china":{"homepageImageUrl":{"men":"","women":""}},"isHongKongFreeReturnEnabled":true,"memberVerification":null,"isLVEnabled":false,"isAlipayBannerEnabled":true,"isGAServerSideEnabled":true,"isFreeReturnBannerEnabled":false,"isNewPDPShipp ...
#   </script>
#   <script src="/assets/manifest.7cc1932d1fccb35f5224.js" type="text/javascript">
#   </script>
#   <script src="/assets/vendor.1b90a8723c89089173c2.js" type="text/javascript">
#   </script>
#   <script src="/assets/app.ae7d67ab604f3795b02d.js" type="text/javascript">
#   </script>
#  </body>
# </html>

# %%
#Number of pages for a particular category

cat_soup.find_all('li', class_='last-page')[0].get_text()
# Out:
# '91'

# %%
#Getting product information of a particular item on a page

json.loads(cat_soup.find_all("script", {"type": "application/ld+json"})[59].get_text())
# Out:
# {'@context': 'https://schema.org',
#  '@type': 'Product',
#  'productID': 5057171,
#  'name': 'Blue Dystopy 384 Glasses',
#  'sku': '201463M133009',
#  'brand': {'@type': 'Brand', 'name': 'Thierry Lasry'},
#  'offers': {'@type': 'Offer',
#   'price': 560,
#   'priceCurrency': 'CAD',
#   'availability': 'https://schema.org/InStock',
#   'url': '/men/product/thierry-lasry/blue-dystopy-384-glasses/5057171'},
#  'url': '/men/product/thierry-lasry/blue-dystopy-384-glasses/5057171',
#  'image': 'https://res.cloudinary.com/ssenseweb/image/upload/201463M133009_1.jpg'}

# %%
#Number of products or items on a page

len(cat_soup.find_all("script", {"type": "application/ld+json"}))
# Out:
# 60

# %% [markdown]
# ### Product Level

# %%
#Getting HTML codes for a particular product

product = requests.get("https://ssense.com/en-ca/men/product/random-identities/black-faux-leather-hoodie/5230331")
product_soup = BeautifulSoup(product.content, 'html.parser')

print(product_soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-ca">
#  <head>
#   <meta content="en" name="language"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    Random Identities: Black Faux-Leather Hoodie | SSENSE Canada
#   </title>
#   <meta content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=no,minimal-ui" name="viewport"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <script type="text/javascript">
#    window.NREUM||(NREUM={});NREUM.info = {"agent":"","beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"901b49cf57","applicationID":"233360527","applicationTime":5.108502,"transactionName":"ZlFbYEBRXkdWV0wPDV8bfExCQlVHRF5LSSV0YBYbV14dDlRbTQgWQ00WWVdeH0RFW1wTAUUbA1ZAUV5QGA5LChdWGwNdVg==","queueTime":0,"ttGuid":"aa7736f44bb540","agentToken":null}; (window.NREUM||(NREUM={})).loader_config={xpid:"VQIGUVBaCBACV1JRAQECVFM=",licenseKey:"901b49cf57",applicationID:"233360527"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{s.console&&console.log(t)}catch(e){}}var o,i=t("ee"),a=t(24),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,e,n){r(n.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,s){try{l?l-=1:o(s||new UncaughtException(t,e,n),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function o(t,e){var n=e?null:c.now();i("err",[t,n])}var i=t("handle"),a=t(25),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,p="nr@seenError",l=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(13),t(12),"addEventListener"in window&&t(6),c.xhrWrappable&&t(14),d=!0)}s.on("fn-start",function(t,e,n){d&&(l+=1)}),s.on("fn-err",function(t,e,n){d&&!n[p]&&(f(n,p,function(){return!0}),this.thrown=!0,o(n))}),s.on("fn-end",function(){d&&!this.thrown&&l>0&&(l-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})},{}],3:[function(t,e,n){t("loader").features.ins=!0},{}],4:[function(t,e,n){function r(){L++,C=g.hash,this[u]=y.now()}function o(){L--,g.hash!==C&&i(0,!0);var t=y.now();this[h]=~~this[h]+t-this[u],this[d]=t}function i(t,e){E.emit("newURL",[""+g,e])}function a(t,e){t.on(e,function(){this[e]=y.now()})}var s="-start",c="-end",f="-body",u="fn"+s,d="fn"+c,p="cb"+s,l="cb"+c,h="jsTime",m="fetch",v="addEventListener",w=window,g=w.location,y=t("loader");if(w[v]&&y.xhrWrappable){var x=t(10),b=t(11),E=t(8),R=t(6),O=t(13),N=t(7),P=t(14),M=t(9),T=t("ee"),S=T.get("tracer");t(16),y.features.spa=!0;var C,L=0;T.on(u,r),T.on(p,r),T.on(d,o),T.on(l,o),T.buffer([u,d,"xhr-done","xhr-resolved"]),R.buffer([u]),O.buffer(["setTimeout"+c,"clearTimeout"+s,u]),P.buffer([u,"new-xhr","send-xhr"+s]),N.buffer([m+s,m+"-done",m+f+s,m+f+c]),E.buffer(["newURL"]),x.buffer([u]),b.buffer(["propagate",p,l,"executor-err","resolve"+s]),S.buffer([u,"no-"+u]),M.buffer(["new-jsonp","cb-start","jsonp-error","jsonp-end"]),a(P,"send-xhr"+s),a(T,"xhr-resolved"),a(T,"xhr-done"),a(N,m+s),a(N,m+"-done"),a(M,"new-jsonp"),a(M,"jsonp-end"),a(M,"cb-start"),E.on("pushState-end",i),E.on("replaceState-end",i),w[v]("hashchange",i,!0),w[v]("load",i,!0),w[v]("popstate",function(){i(0,L>1)},!0)}},{}],5:[function(t,e,n){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(13),s=t(12),c="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",p="resource",l="-start",h="-end",m="fn"+l,v="fn"+h,w="bstTimer",g="pushState",y=t("loader");y.features.stn=!0,t(8),"addEventListener"in window&&t(6);var x=NREUM.o.EV;o.on(m,function(t,e){var n=t[0];n instanceof x&&(this.bstStart=y.now())}),o.on(v,function(t,e){var n=t[0];n instanceof x&&i("bst",[n,e ...
#   </script>
#   <meta content="SSENSE" name="author"/>
#   <meta content="Buy Random Identities Black Faux-Leather Hoodie on SSENSE.com and get free shipping &amp; returns in Canada. Long sleeve grained faux-leather hoodie in black. Bungee-style drawstring at hood. Zip closure at front. Patch pockets at waist." name="description"/>
#   <meta content="product" name="twitter:card"/>
#   <meta content="@ssense" name="twitter:site"/>
#   <meta content="@ssense" name="twitter:creator"/>
#   <meta content="ssense.com" name="twitter:domain"/>
#   <meta content="Random Identities - Black Faux-Leather Hoodie" name="twitter:title"/>
#   <meta content="Long sleeve grained faux-leather hoodie in black. Bungee-style drawstring at hood. Zip closure at front. Patch pockets at waist. Elasticized cuffs and hem. Raglan sleeves." name="twitter:description"/>
#   <meta content="https://res.cloudinary.com/ssenseweb/image/upload/b_white,c_lpad,g_south,h_706,w_470/c_scale,h_480/v550/192172M202054_1.jpg" name="twitter:img:src"/>
#   <meta content="Price" name="twitter:label1"/>
#   <meta content="$761 CAD" name="twitter:data1"/>
#   <meta content="Designer" name="twitter:label2"/>
#   <meta content="Random Identities" name="twitter:data2"/>
#   <meta content="Random Identities - Black Faux-Leather Hoodie" property="og:title"/>
#   <meta content="ssense" property="og:site_name"/>
#   <meta content="https://www.ssense.com/en-ca/en-ca/men/product/random-identities/black-faux-leather-hoodie/5230331" property="og:url"/>
#   <meta content="Long sleeve grained faux-leather hoodie in black. Bungee-style drawstring at hood. Zip closure at front. Patch pockets at waist. Elasticized cuffs and hem. Raglan sleeves. Full faux-fur lining in green. Silver-tone hardware.
#
# Supplier color: Black" property="og:description"/>
#   <meta content="product" property="og:type"/>
#   <meta content="en-ca" property="og:locale"/>
#   <meta content="en-ca" property="og:locale:alternate"/>
#   <meta content="https://res.cloudinary.com/ssenseweb/image/upload/b_white,c_lpad,g_south,h_706,w_470/c_scale,h_480/v550/192172M202054_1.jpg" property="og:image"/>
#   <meta content="243" property="og:image:width"/>
#   <meta content="328" property="og:image:height"/>
#   <meta content="761" property="product:price:amount"/>
#   <meta content="CAD" property="product:price:currency"/>
#   <meta content="adult" property="product:age_group"/>
#   <meta content="instock" property="product:availability"/>
#   <meta content="Random Identities" property="product:brand"/>
#   <meta content="Hoodies &amp; zipups" property="product:category"/>
#   <meta content="new" property="product:condition"/>
#   <meta content="Body: 80% polyester, 18% acrylic, 2% polyurethane." property="product:material"/>
#   <link href="//beacon.riskified.com" rel="dns-prefetch"/>
#   <link href="//c.riskified.com" rel="dns-prefetch"/>
#   <link href="//googleads.g.doubleclick.net" rel="dns-prefetch"/>
#   <link href="//stats.g.doubleclick.net" rel="dns-prefetch"/>
#   <link href="//www.google-analytics.com" rel="dns-prefetch"/>
#   <link href="//www.google.ca" rel="dns-prefetch"/>
#   <link href="//www.google.com" rel="dns-prefetch"/>
#   <link href="//www.googleadservices.com" rel="dns-prefetch"/>
#   <link href="//bat.bing.com" rel="dns-prefetch"/>
#   <link href="//connect.facebook.net" rel="dns-prefetch"/>
#   <link href="//res.cloudinary.com" rel="preconnect"/>
#   <link href="//res-1.cloudinary.com" rel="preconnect"/>
#   <link href="//res-2.cloudinary.com" rel="preconnect"/>
#   <link href="//res-3.cloudinary.com" rel="preconnect"/>
#   <link href="//res-4.cloudinary.com" rel="preconnect"/>
#   <link href="//res-5.cloudinary.com" rel="preconnect"/>
#   <link href="https://www.ssense.com/en-ca/men/product/random-identities/black-faux-leather-hoodie/5230331" rel="canonical"/>
#   <link href="https://www.ssense.com/en-ca/men/opensearch.xml" rel="search" title="SSENSE Search Men" type="application/opensearchdescription+xml"/>
#   <link href="https://www.ssense.com/en-ca/women/opensearch.xml" rel="search" title="SSENSE Search Women" type="application/opensearchdescription+xml"/>
#   <link href="https://www.ssense.com/en-us/men/product/random-identities/black-faux-leather-hoodie/5230331" hreflang="en-us" rel="alternate"/>
#   <link href="https://www.ssense.com/en-ca/men/product/random-identities/black-faux-leather-hoodie/5230331" hreflang="en-ca" rel="alternate"/>
#   <link href="https://www.ssense.com/en-gb/men/product/random-identities/black-faux-leather-hoodie/5230331" hreflang="en-gb" rel="alternate"/>
#   <link href="https://www.ssense.com/ja-jp/men/product/random-identities/black-faux-leather-hoodie/5230331" hreflang="ja-jp" rel="alternate"/>
#   <link href="https://www.ssense.com/fr-fr/hommes/produit/random-identities/pull-a-capuche-en-cuir-synthetique-noir/5230331" hreflang="fr-fr" rel="alternate"/>
#   <link href="https://www.ssense.com/zh-cn/men/product/random-identities/black-faux-leather-hoodie/5230331" hreflang="zh-Hans-cn" rel="alternate"/>
#   <link href="https://www.ssense.com/en-us/men/product/random-identities/black-faux-leather-hoodie/5230331" hreflang="en" rel="alternate"/>
#   <link href="https://www.ssense.com/ja-jp/men/product/random-identities/black-faux-leather-hoodie/5230331" hreflang="ja" rel="alternate"/>
#   <link href="https://www.ssense.com/fr-fr/hommes/produit/random-identities/pull-a-capuche-en-cuir-synthetique-noir/5230331" hreflang="fr" rel="alternate"/>
#   <link href="https://www.ssense.com/zh-cn/men/product/random-identities/black-faux-leather-hoodie/5230331" hreflang="zh-Hans" rel="alternate"/>
#   <link href="//res.cloudinary.com/ssenseweb/image/upload/v1472005257/web/favicon.ico" rel="icon" type="image/x-icon"/>
#   <link href="//img.ssensemedia.com/image/upload/v1574192255/favicon_ssense/favicon-16x16_byyzld.png" rel="shortcut icon" type="image/png"/>
#   <link href="//img.ssensemedia.com/image/upload/v1574192255/favicon_ssense/favicon-16x16_byyzld.png" rel="apple-touch-icon"/>
#   <link href="//img.ssensemedia.com/image/upload/v1574192255/favicon_ssense/apple-touch-icon-57x57_prssda.png" rel="apple-touch-icon" sizes="57x57"/>
#   <link href="//img.ssensemedia.com/image/upload/v1574192255/favicon_ssense/apple-touch-icon-114x114_uep0gt.png" rel="apple-touch-icon" sizes="114x114"/>
#   <link href="//img.ssensemedia.com/image/upload/v1574192255/favicon_ssense/apple-touch-icon-72x72_h1wgtx.png" rel="apple-touch-icon" sizes="72x72"/>
#   <link href="//img.ssensemedia.com/image/upload/v1574192254/favicon_ssense/mstile-144x144_x0cjmg.png" rel="apple-touch-icon" sizes="144x144"/>
#   <link href="//img.ssensemedia.com/image/upload/v1574192255/favicon_ssense/apple-touch-icon-60x60_rasic3.png" rel="apple-touch-icon" sizes="60x60"/>
#   <link href="//img.ssensemedia.com/image/upload/v1574192254/favicon_ssense/mstile-70x70_zaidh0.png" rel="apple-touch-icon" sizes="70x70"/>
#   <link href="//img.ssensemedia.com/image/upload/v1574192254/favicon_ssense/apple-touch-icon-120x120_sdj78o.png" rel="apple-touch-icon" sizes="120x120"/>
#   <link href="//img.ssensemedia.com/image/upload/v1574192255/favicon_ssense/apple-touch-icon-76x76_r9mdrx.png" rel="apple-touch-icon" sizes="76x76"/>
#   <link href="//img.ssensemedia.com/image/upload/v1574192254/favicon_ssense/mstile-150x150_aawpmj.png" rel="apple-touch-icon" sizes="150x150"/>
#   <link href="//img.ssensemedia.com/image/upload/v1574192254/favicon_ssense/apple-touch-icon-152x152_b8pday.png" rel="apple-touch-icon" sizes="152x152"/>
#   <link href="//img.ssensemedia.com/image/upload/v1574192255/favicon_ssense/favicon-196x196_vvei5a.png" rel="icon" sizes="196x196"/>
#   <link href="//img.ssensemedia.com/image/upload/v1574192254/favicon_ssense/mstile-150x150_aawpmj.png" rel="icon" sizes="150x150"/>
#   <link href="//img.ssensemedia.com/image/upload/v1574192255/favicon_ssense/favicon-96x96_f2fnwr.png" rel="icon" sizes="96x96"/>
#   <link href="//img.ssensemedia.com/image/upload/v1574192255/favicon_ssense/favicon-16x16_byyzld.png" rel="icon" sizes="16x16"/>
#   <link href="//img.ssensemedia.com/image/upload/v1574192255/favicon_ssense/favicon-32x32_sdslfh.png" rel="icon" sizes="32x32"/>
#   <link href="/assets/app.2d99c1d4b15b4ea364bd38a424126182.css" rel="stylesheet" type="text/css"/>
#   <!--  Hide retargeting iframe -->
#   <style type="text/css">
#    iframe[name="google_conversion_frame"] { display:none; }
#   </style>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=AW-1063827787">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#   function gtag() {
#     dataLayer.push(arguments);
#   }
#   gtag('js', new Date());
#   gtag('config', 'AW-1063827787', { 'send_page_view': false });
#   </script>
#   <!--
#   script enabled:
#   Add here the <script> portion of tracking
#   -->
#   <script>
#    // ----------------------------------------------
#   // Google Analytics initialization
#   // ----------------------------------------------
#   window.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new Date;
#
#   // Method to parse cookie value and set to window property
#   // params:
#   // cookieName: name of cookie to parse (string)
#   // nullReturnValue: what to set if cookie doesn't exist (any)
#   function getCookie(cookieName, nullReturnValue) {
#      return document.cookie.split('; ').filter(
#          function(pair){
#              return pair.indexOf(cookieName + '=') == 0 })[0] ?
#           document.cookie.split('; ').filter(
#               function(pair){
#                   return pair.indexOf(cookieName + '=') == 0 })[0].split('=')[1]
#           : nullReturnValue;
#   }
#
#   window.trackingId = getCookie('trackingId', null);
#   window.guestExperimentStatus = getCookie('guest_checkout_enabled', 'no-cookie');
#
#   try {
#     ga('create', 'UA-519637-1', {'siteSpeedSampleRate': 100});
#     if (window.trackingId){
#       ga('set', 'dimension9', window.trackingId);
#     }
#     // Dimension 10 is the new custom dimension to track conversion on legacy stack and legacy/new hybrid stack
#     ga('set', 'dimension10', '1');
#
#     // send value of guest checkout cookie to ga
#     if(window.guestExperimentStatus) {
#       ga('set', 'dimension18', window.guestExperimentStatus);
#     }
#     ga('require', 'ecommerce');
#     ga('require', 'eventTracker');
#     ga('require', 'outboundLinkTracker');
#     ga('require', 'urlChangeTracker');
#     ga('send', 'pageview');
#   } catch (e) {
#     // Rethrow errors from external scripts due to Same-Origin Policy
#     throw e;
#   }
#
#   /**
#    * Utils function to inject script src tag
#    */
#   function injectScript(src, supportsCors, onload) {
#     var head = document.getElementsByTagName('head')[0],
#         script = document.createElement('script');
#
#     script.type = 'text/javascript';
#     script.src = src;
#     script.onload = onload || function() {};
#
#     if (supportsCors) {
#       script.crossOrigin = 'anonymous';
#     }
#
#     head.appendChild(script);
#   }
#
#   // -------------------
#   // Riskified Beacon
#   // ----------------------------------------------
#   window.riskifiedBeaconLoad = function(sid) {
#       var store_domain = 'ssense.com';
#       var url = ('https:' == document.location.protocol ? 'https://' : 'http://') + "beacon.riskified.com?shop="+store_domain + "&sid="+sid;
#       var s = document.createElement('script');
#       s.type = 'text/javascript';
#       s.async = true;
#       s.defer = true;
#       s.src = url;
#       s.crossOrigin = "anonymous";
#       var x = document.getElementsByTagName('script')[0];
#       x.parentNode.insertBefore(s, x);
#   };
#
#   /**
#    * Initialize tracking when page is loaded
#    */
#   window.addEventListener('load', function(event) {
#     // -------------------
#     // Google Analytics
#     // ----------------------------------------------
#     injectScript('//www.google-analytics.com/analytics.js', false);
#
#     injectScript('//cdnjs.cloudflare.com/ajax/libs/autotrack/1.0.1/autotrack.js', true);
#   });
#   </script>
#   <!-- No script:Add here the <noscript> portion of tracking -->
#   <noscript>
#    <!-- Google Conversion -->
#    <div style="display:inline">
#     <img alt="" height="1" src="//googleads.g.doubleclick.net/pagead/viewthroughconversion/1063827787/?value=0&amp;label=IFM5CImLwQMQy_Ki-wM&amp;guid=ON&amp;script=0" style="border-style:none" width="1"/>
#    </div>
#    <!-- Bing ads -->
#    <img alt="" height="0" src="//bat.bing.com/action/0?ti=4008316&amp;Ver=2" style="display:none; visibility: hidden" width="0"/>
#    <!-- Facebook pixel code -->
#    <img alt="" height="1" src="https://www.facebook.com/tr?id=1084416341572353&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
#   </noscript>
#  </head>
#  <body>
#   <script type="text/javascript">
#    /* We do not support all browsers; When a user is using one of these
#   unsupported browsers show them a warning. */
#
#   (function() {
#
#     /* Browsers with HTMLPictureElement defined should be modern enough to
#     support everything we do [1]. Exceptions are IE 10-12 and Safari 8 which
#     we support via an HTMLPictureElement polyfill, but adds support for many
#     browsers including those we do not want to support (ie9, Safari7, ...).
#     Thus we must find another way to not-warn said exceptions. We do this by
#     UA sniffing (gasp)[2].
#
#     [1] http://caniuse.com/#feat=picture
#     [2] For details on our regex see http://regexr.com/3emos. */
#
#     var polyfilledUserAgents = /MSIE 10|MSIE 11|IE 11|Trident.*rv:11|WOW64;.*rv:11|Edge\/12|AppleWebKit.*Version\/(:?8|9\.0|9\.1|9\.2)/;
#
#     var isSupported = window.HTMLPictureElement
#                    || polyfilledUserAgents.test(navigator.userAgent);
#
#     if (!isSupported) {
#       var div = document.createElement("div");
#       div.innerHTML = "Sorry, your browser is not supported. You may experience some difficulties when shopping on SSENSE.";
#       div.className = "message-box failed";
#       div.style.position = "relative"; // [1]
#       div.style.opacity = "1"; // [2]
#       div.onclick = function () { document.body.removeChild(div); };
#       document.body.insertBefore(div, document.body.firstChild); // [3]
#
#       /*
#       [1] .message-box is `position: fixed` so it "hovers" over body content,
#       but we want this warning to push body content down instead.
#
#       [2] .message-box is designed to be faded in by our JS app, but we cannot
#       rely on any external JS here, so force opacity to 100%.
#
#       [3] If firstChild is `null` then `insertBefore` will put `div` at
#       end of child list of body which in this case would just mean first
#       child. Reference:
#       https://developer.mozilla.org/en-US/docs/Web/API/Node/insertBefore. */
#     }
#   })();
#   </script>
#   <script type="text/javascript">
#    /* Include babel-polyfill if browser dos not support Object.assign or window.Promise */
#
#   (function() {
#     if (typeof Object.assign !== "function" ||
#         typeof window.Promise !== "function") {
#
#       var head = document.getElementsByTagName('head')[0],
#           script = document.createElement('script');
#
#       script.type = 'text/javascript';
#       script.src = 'https://cdnjs.cloudflare.com/ajax/libs/babel-polyfill/6.23.0/polyfill.min.js';
#       script.crossOrigin = 'anonymous';
#       head.appendChild(script);
#     }
#   })();
#   </script>
#   <div data-server-rendered="true">
#    <div class="lang-en" id="app">
#     <div class="body-wrapper" style="padding-top:55px;">
#      <!-- -->
#      <header class="header opaque-header">
#       <div class="container-fluid">
#        <div class="row-fluid">
#         <nav class="span7 header-nav header-nav-left" data-v-6734adc4="" role="navigation">
#          <ul class="nav hidden-tablet-landscape">
#           <li>
#            <a class="router-link-active" data-v-6734adc4="" href="/en-ca/men" id="men-link">
#             Men
#            </a>
#           </li>
#           <li>
#            <a data-v-6734adc4="" href="/en-ca/women" id="women-link">
#             Women
#            </a>
#           </li>
#           <li>
#            <a data-v-6734adc4="" href="/en-ca/men/sale" id="sale-link">
#             sale
#            </a>
#           </li>
#           <!-- -->
#          </ul>
#          <ul class="nav mobile-navigation display-block-tablet-landscape">
#           <li class="side-menu-toggle">
#            <a href="#">
#             <i class="fa fa-ssense-menu">
#             </i>
#             <span class="menu-animated">
#             </span>
#            </a>
#           </li>
#           <li>
#            <a class="display-block-tablet-landscape" href="#">
#             <i class="fa fa-ssense-magnifier">
#             </i>
#            </a>
#           </li>
#          </ul>
#         </nav>
#         <div class="header-logo span2" data-v-37baba0c="" role="banner">
#          <a class="router-link-active" data-v-37baba0c="" href="/en-ca">
#           <img alt="SSENSE" class="site-logo dark" data-v-37baba0c="" src="//res.cloudinary.com/ssenseweb/image/upload/v1409080279/web/ssense_logo_v2.png"/>
#          </a>
#         </div>
#         <nav class="span7 header-nav header-nav-right" data-v-bd126e56="" role="navigation">
#          <ul class="nav hidden-tablet-landscape">
#           <li>
#            <a class="popover-hover-link" href="https://www.ssense.com/en-ca/men/product/random-identities/black-faux-leather-hoodie/5230331">
#             English
#            </a>
#            <div class="popover-center" data-v-88391330="" data-v-bd126e56="">
#             <div class="popover popover-alternate" id="language-menu-popover">
#              <ul data-v-bd126e56="">
#               <li>
#                <a href="https://www.ssense.com/fr-ca/hommes/produit/random-identities/pull-a-capuche-en-cuir-synthetique-noir/5230331" rel="nofollow">
#                 Français
#                </a>
#               </li>
#               <li>
#                <a href="https://www.ssense.com/ja-ca/men/product/random-identities/black-faux-leather-hoodie/5230331" rel="nofollow">
#                 日本語
#                </a>
#               </li>
#               <li>
#                <a href="https://www.ssense.com/zh-ca/men/product/random-identities/black-faux-leather-hoodie/5230331" rel="nofollow">
#                 中文
#                </a>
#               </li>
#              </ul>
#             </div>
#            </div>
#           </li>
#           <li>
#            <a data-v-bd126e56="" href="/en-ca/account/login">
#             login
#            </a>
#           </li>
#           <li>
#            <a class="right-nav-items" data-v-bd126e56="" href="/en-ca/account/wishlist">
#             wishlist
#            </a>
#           </li>
#           <li>
#            <a class="shopping-bag-link" data-v-bd126e56="" href="/en-ca/shopping-bag">
#             shopping bag (0)
#            </a>
#           </li>
#          </ul>
#          <ul class="nav mobile-navigation display-block-tablet-landscape">
#           <li class="account">
#            <a class="popover-hover-link" data-v-bd126e56="" href="/en-ca/account">
#             <i class="fa fa-ssense-account" data-v-bd126e56="">
#             </i>
#            </a>
#           </li>
#           <li class="shopping-bag">
#            <a class="shopping-bag-link" data-v-bd126e56="" href="/en-ca/shopping-bag">
#             <i class="fa fa-ssense-bag" data-v-bd126e56="">
#             </i>
#             <span class="header-shopping-bag-count miniBagCount" data-v-bd126e56="">
#              <span data-v-bd126e56="">
#               (
#              </span>
#              0
#              <span data-v-bd126e56="">
#               )
#              </span>
#             </span>
#            </a>
#           </li>
#          </ul>
#         </nav>
#        </div>
#       </div>
#       <!-- -->
#      </header>
#      <div>
#      </div>
#      <div class="notification-manager-container">
#       <span>
#       </span>
#      </div>
#      <!-- -->
#      <main class="main container-fluid" id="wrap" role="main">
#       <div class="browsing-page-root product-item women view" data-v-4cdb0522="" id="product-item">
#        <script type="application/ld+json">
#         {
#   "@context": "https://schema.org",
#   "@type": "Product",
#   "productID": 5230331,
#   "name": "Black Faux-Leather Hoodie",
#   "sku": "192172M202054",
#   "brand": {
#     "@type": "Brand",
#     "name": "Random Identities"
#   },
#   "offers": {
#     "@type": "Offer",
#     "price": 761,
#     "priceCurrency": "CAD",
#     "availability": "https://schema.org/InStock",
#     "url": "/en-ca/men/product/random-identities/black-faux-leather-hoodie/5230331"
#   },
#   "url": "/en-ca/men/product/random-identities/black-faux-leather-hoodie/5230331",
#   "description": "Long sleeve grained faux-leather hoodie in black. Bungee-style drawstring at hood. Zip closure at front. Patch pockets at waist. Elasticized cuffs and hem. Raglan sleeves. Full faux-fur lining in green. Silver-tone hardware. \r\n\r\nSupplier color: Black",
#   "image": [
#     "https://res.cloudinary.com/ssenseweb/image/upload/192172M202054_1.jpg",
#     "https://res.cloudinary.com/ssenseweb/image/upload/192172M202054_2.jpg",
#     "https://res.cloudinary.com/ssenseweb/image/upload/192172M202054_3.jpg",
#     "https://res.cloudinary.com/ssenseweb/image/upload/192172M202054_4.jpg",
#     "https://res.cloudinary.com/ssenseweb/image/upload/192172M202054_5.jpg"
#   ]
# }
#        </script>
#        <!-- -->
#        <div class="product-item-container row-fluid">
#         <div class="span3 offset1 product-item-description tablet-landscape-full-fluid-width">
#          <div class="fixed-wrapper">
#           <div class="scroll-magnet-container" data-v-174cf372="" data-v-4cdb0522="" style="height:0px;">
#            <div class="scroll-magnet-item" data-v-4cdb0522="" data-v-7b5a289c="" style="width:falsepx;top:0;">
#             <div class="column-container" data-v-4cdb0522="" data-v-7b5a289c="">
#              <div class="column-contents" data-v-4cdb0522="" data-v-7b5a289c="">
#               <div class="product-description-container" data-v-19a2cfa9="" data-v-4cdb0522="">
#                <div class="content">
#                 <h1 class="product-brand">
#                  <a data-v-19a2cfa9="" href="/en-ca/men/designers/random-identities">
#                   Random Identities
#                  </a>
#                 </h1>
#                 <h2 class="product-name">
#                  Black Faux-Leather Hoodie
#                 </h2>
#                 <span class="product-sku" content="product.sku">
#                  192172M202054
#                 </span>
#                 <h1 class="product-price">
#                  <span class="price sale">
#                   $975 CAD
#                  </span>
#                  <span class="price">
#                   $761 CAD
#                  </span>
#                  <!-- -->
#                 </h1>
#                 <div>
#                  <!-- -->
#                  <!-- -->
#                 </div>
#                </div>
#                <div class="share-container vspace2">
#                 <div class="share-container-button" style="display:none;">
#                  <a class="share-reveal-button bold">
#                   Share
#                  </a>
#                 </div>
#                 <div class="share-container-button">
#                  <div class="share-button" data-v-19a2cfa9="" data-v-2795c86b="" style="display:none;">
#                   <a href="#">
#                    <i class="fa fa-facebook fa-fw">
#                    </i>
#                   </a>
#                  </div>
#                  <div class="share-button" data-v-19a2cfa9="" data-v-2795c86b="" style="display:none;">
#                   <a href="#">
#                    <i class="fa fa-twitter fa-fw">
#                    </i>
#                   </a>
#                  </div>
#                  <div class="share-button" data-v-19a2cfa9="" data-v-2795c86b="" style="display:none;">
#                   <a href="#">
#                    <i class="fa fa-pinterest fa-fw">
#                    </i>
#                   </a>
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="span8 product-item-images smartphone-portrait-narrow-full-fluid-width">
#          <div>
#           <div>
#            <div class="content vspace1" data-v-4cdb0522="">
#             <div class="product-images-container">
#              <div>
#               <div class="image-wrapper">
#                <div>
#                 <picture data-v-60b7d3e3="">
#                  <!-- -->
#                  <!-- -->
#                  <img alt="Random Identities - Black Faux-Leather Hoodie" class="product-detail lazyload" data-srcset="https://img.ssensemedia.com/images/b_white,c_lpad,g_center,h_960,w_960/c_scale,h_680/f_auto,dpr_1.0/192172M202054_1/random-identities-black-faux-leather-hoodie.jpg" src="https://res.cloudinary.com/ssenseweb/image/upload/v1472069180/product-placeholder_qulza9.png"/>
#                 </picture>
#                </div>
#               </div>
#               <div class="image-wrapper">
#                <div>
#                 <picture data-v-60b7d3e3="">
#                  <!-- -->
#                  <!-- -->
#                  <img alt="Random Identities - Black Faux-Leather Hoodie" class="product-detail lazyload" data-srcset="https://img.ssensemedia.com/images/b_white,c_lpad,g_center,h_960,w_960/c_scale,h_680/f_auto,dpr_1.0/192172M202054_2/random-identities-black-faux-leather-hoodie.jpg" src="https://res.cloudinary.com/ssenseweb/image/upload/v1472069180/product-placeholder_qulza9.png"/>
#                 </picture>
#                </div>
#               </div>
#               <div class="image-wrapper">
#                <div>
#                 <picture data-v-60b7d3e3="">
#                  <!-- -->
#                  <!-- -->
#                  <img alt="Random Identities - Black Faux-Leather Hoodie" class="product-detail lazyload" data-srcset="https://img.ssensemedia.com/images/b_white,c_lpad,g_center,h_960,w_960/c_scale,h_680/f_auto,dpr_1.0/192172M202054_3/random-identities-black-faux-leather-hoodie.jpg" src="https://res.cloudinary.com/ssenseweb/image/upload/v1472069180/product-placeholder_qulza9.png"/>
#                 </picture>
#                </div>
#               </div>
#               <div class="image-wrapper">
#                <div>
#                 <picture data-v-60b7d3e3="">
#                  <!-- -->
#                  <!-- -->
#                  <img alt="Random Identities - Black Faux-Leather Hoodie" class="product-detail lazyload" data-srcset="https://img.ssensemedia.com/images/b_white,c_lpad,g_center,h_960,w_960/c_scale,h_680/f_auto,dpr_1.0/192172M202054_4/random-identities-black-faux-leather-hoodie.jpg" src="https://res.cloudinary.com/ssenseweb/image/upload/v1472069180/product-placeholder_qulza9.png"/>
#                 </picture>
#                </div>
#               </div>
#               <div class="image-wrapper">
#                <div>
#                 <picture data-v-60b7d3e3="">
#                  <!-- -->
#                  <!-- -->
#                  <img alt="Random Identities - Black Faux-Leather Hoodie" class="product-detail lazyload" data-srcset="https://img.ssensemedia.com/images/b_white,c_lpad,g_center,h_960,w_960/c_scale,h_680/f_auto,dpr_1.0/192172M202054_5/random-identities-black-faux-leather-hoodie.jpg" src="https://res.cloudinary.com/ssenseweb/image/upload/v1472069180/product-placeholder_qulza9.png"/>
#                 </picture>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="span3 product-cta-container">
#          <div class="fixed-wrapper">
#           <div class="scroll-magnet-container" data-v-174cf372="" data-v-4cdb0522="" style="height:0px;">
#            <div class="scroll-magnet-item" data-v-4cdb0522="" data-v-7b5a289c="" style="width:falsepx;top:0;">
#             <div class="column-container" data-v-4cdb0522="" data-v-7b5a289c="">
#              <div class="column-contents" data-v-4cdb0522="" data-v-7b5a289c="">
#               <div class="content" data-v-1dd5763a="" data-v-4cdb0522="">
#                <div class="description">
#                 <!-- -->
#                 <a href="#">
#                  View details
#                 </a>
#                 <!-- -->
#                </div>
#                <div class="row-fluid">
#                 <div class="span16 price-container">
#                  <h3 class="price">
#                   <span class="price sale">
#                    $975 CAD
#                   </span>
#                   <span class="price">
#                    $761 CAD
#                   </span>
#                  </h3>
#                 </div>
#                 <div class="span16 promotions-container">
#                  <div class="promotions-container" data-v-10584c49="" data-v-1dd5763a="">
#                   <div class="vspace2 display-block-smartphone-portrait">
#                   </div>
#                   <p>
#                    You save 22%
#                   </p>
#                   <div>
#                    <p>
#                    </p>
#                    <!-- -->
#                    <!-- -->
#                    <p>
#                     Canada : Free shipping on orders over $100 CAD and free returns on all orders.
#                    </p>
#                   </div>
#                   <div class="vspace1 display-block-smartphone-portrait">
#                   </div>
#                   <!-- -->
#                  </div>
#                 </div>
#                </div>
#                <div class="add-to-bag-form" data-v-02e0366f="" data-v-1dd5763a="">
#                 <div class="span16" data-v-02e0366f="" data-v-73e7d24e="">
#                  <div>
#                   <div class="vspace1">
#                    <div data-v-73e7d24e="">
#                     <a class="btn-show-chart" data-v-73e7d24e="" href="#">
#                      View Size Chart
#                     </a>
#                    </div>
#                   </div>
#                   <div style="position:relative">
#                    <select class="vspace2 hide-text" data-v-73e7d24e="" id="size" name="size">
#                     <option data-v-73e7d24e="" disabled="disabled" selected="selected" value="SELECT A SIZE">
#                      SELECT A SIZE
#                     </option>
#                     <option data-v-73e7d24e="" disabled="disabled" value="XS_192172M20205401">
#                      XS - Sold Out
#                     </option>
#                     <option data-v-73e7d24e="" value="S_192172M20205402">
#                      S
#                     </option>
#                     <option data-v-73e7d24e="" value="L_192172M20205403">
#                      L
#                     </option>
#                    </select>
#                    <div class="loading-animation-container">
#                     <span class="load-animation" data-v-73e7d24e="">
#                      <span class="dot" style="width:3px;height:3px;border-radius:3px;margin-right:12px;animation:0.44999999999999996s 0s blink step-end infinite;">
#                      </span>
#                      <span class="dot" style="width:3px;height:3px;border-radius:3px;margin-right:12px;animation:0.44999999999999996s 0.075s blink step-end infinite;">
#                      </span>
#                      <span class="dot" style="width:3px;height:3px;border-radius:3px;margin-right:0px;animation:0.44999999999999996s 0.15s blink step-end infinite;">
#                      </span>
#                     </span>
#                    </div>
#                   </div>
#                  </div>
#                 </div>
#                 <form data-v-02e0366f="" data-v-f4bdd476="" id="addBagForm" type="post">
#                  <div class="span16 vspace1">
#                   <!-- -->
#                   <button class="button full-width btn-add-to-bag button full-width no-border button-primary" data-v-f4bdd476="" type="submit">
#                    <span class="button-label">
#                     Add to bag
#                    </span>
#                    <span class="load-wrapper" style="display:none;">
#                     <span class="load-animation">
#                      <span class="dot" style="width:3px;height:3px;border-radius:3px;margin-right:12px;animation:0.44999999999999996s 0s blink step-end infinite;">
#                      </span>
#                      <span class="dot" style="width:3px;height:3px;border-radius:3px;margin-right:12px;animation:0.44999999999999996s 0.075s blink step-end infinite;">
#                      </span>
#                      <span class="dot" style="width:3px;height:3px;border-radius:3px;margin-right:0px;animation:0.44999999999999996s 0.15s blink step-end infinite;">
#                      </span>
#                     </span>
#                    </span>
#                   </button>
#                  </div>
#                 </form>
#                 <!-- -->
#                 <div>
#                  <form data-v-02e0366f="" type="post">
#                   <div class="span16 vspace1">
#                    <button class="button full-width no-border heart-icon" type="submit">
#                     <span class="button-label">
#                      Add to wishlist
#                     </span>
#                     <span class="load-wrapper" style="display:none;">
#                      <span class="load-animation">
#                       <span class="dot" style="width:3px;height:3px;border-radius:3px;margin-right:12px;animation:0.44999999999999996s 0s blink step-end infinite;">
#                       </span>
#                       <span class="dot" style="width:3px;height:3px;border-radius:3px;margin-right:12px;animation:0.44999999999999996s 0.075s blink step-end infinite;">
#                       </span>
#                       <span class="dot" style="width:3px;height:3px;border-radius:3px;margin-right:0px;animation:0.44999999999999996s 0.15s blink step-end infinite;">
#                       </span>
#                      </span>
#                     </span>
#                    </button>
#                   </div>
#                  </form>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="span16 text-center vspace4 display-block-smartphone-portrait">
#          <div class="share-button" data-v-2795c86b="" data-v-4cdb0522="" style="display:none;">
#           <a href="#">
#            <i class="fa fa-facebook fa-fw">
#            </i>
#           </a>
#          </div>
#          <div class="share-button" data-v-2795c86b="" data-v-4cdb0522="" style="display:none;">
#           <a href="#">
#            <i class="fa fa-twitter fa-fw">
#            </i>
#           </a>
#          </div>
#          <div class="share-button" data-v-2795c86b="" data-v-4cdb0522="" style="display:none;">
#           <a href="#">
#            <i class="fa fa-pinterest fa-fw">
#            </i>
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="vspace4 related-section-container relative" data-v-4cdb0522="" data-v-d5dfea50="">
#         <div class="related-product-container tab-container">
#          <div class="span16">
#           <span class="tab-btn active smartphone-portrait-narrow-full-width" data-v-d5dfea50="" data-v-f45d71fe="" isdefaulttab="true">
#            <div class="related-product-tab inline-block smartphone-portrait-narrow-full-width" data-v-d5dfea50="" data-v-f45d71fe="">
#             <a class="tab-btn active" data-v-d5dfea50="" data-v-f45d71fe="" href="#">
#              <span data-v-d5dfea50="" data-v-f45d71fe="">
#               Random Identities
#              </span>
#              <span class="underline" data-v-d5dfea50="" data-v-f45d71fe="">
#              </span>
#             </a>
#            </div>
#           </span>
#           <span class="tab-btn smartphone-portrait-narrow-full-width" data-v-d5dfea50="" data-v-f45d71fe="">
#            <div class="related-product-tab inline-block smartphone-portrait-narrow-full-width" data-v-d5dfea50="" data-v-f45d71fe="">
#             <a class="tab-btn" data-v-d5dfea50="" data-v-f45d71fe="" href="#">
#              <span data-v-d5dfea50="" data-v-f45d71fe="">
#               HOODIES &amp; ZIPUPS
#              </span>
#              <span class="underline" data-v-d5dfea50="" data-v-f45d71fe="">
#              </span>
#             </a>
#            </div>
#           </span>
#           <span class="tab-btn smartphone-portrait-narrow-full-width" data-v-d5dfea50="" data-v-f45d71fe="">
#            <div class="related-product-tab inline-block smartphone-portrait-narrow-full-width" data-v-d5dfea50="" data-v-f45d71fe="">
#             <a class="tab-btn" data-v-d5dfea50="" data-v-f45d71fe="" href="#">
#              <span data-v-d5dfea50="" data-v-f45d71fe="">
#               Styled with
#              </span>
#              <span class="underline" data-v-d5dfea50="" data-v-f45d71fe="">
#              </span>
#             </a>
#            </div>
#           </span>
#          </div>
#          <div class="tab-pane span16 tab-content vspace2 active" data-v-d5dfea50="">
#           <div class="slider-container-overflow" data-v-d5dfea50="">
#            <div class="static-related" data-v-d5dfea50="">
#             <div class="static-related-item" data-v-d5dfea50="">
#              <div class="product-item" data-v-d5dfea50="">
#               <a data-v-d5dfea50="" href="/en-ca/men/product/random-identities/black-cropped-sleeveless-hoodie-/4580291">
#                <picture data-v-60b7d3e3="" data-v-d5dfea50="">
#                 <!-- -->
#                 <!-- -->
#                 <img alt="Black Cropped Sleeveless Hoodie " class="product-thumbnail lazyload" data-srcset="https://img.ssensemedia.com/images/b_white,c_lpad,g_south,h_706,w_470/c_scale,h_280/f_auto,dpr_1.0/192172M202024_1/black-cropped-sleeveless-hoodie-.jpg" src="https://res.cloudinary.com/ssenseweb/image/upload/v1472069180/product-placeholder_qulza9.png"/>
#                </picture>
#                <div class="text-center vspace1" data-v-d5dfea50="">
#                 <p class="medium" data-v-d5dfea50="">
#                  Random Identities
#                 </p>
#                 <p class="price" data-v-d5dfea50="">
#                  <span class="price sale" data-v-d5dfea50="">
#                   $225
#                  </span>
#                  <span class="price" data-v-d5dfea50="">
#                   $162
#                  </span>
#                 </p>
#                </div>
#               </a>
#              </div>
#             </div>
#             <div class="static-related-item" data-v-d5dfea50="">
#              <div class="product-item" data-v-d5dfea50="">
#               <a data-v-d5dfea50="" href="/en-ca/men/product/random-identities/black-mohair-dotted-hoodie/3950931">
#                <picture data-v-60b7d3e3="" data-v-d5dfea50="">
#                 <!-- -->
#                 <!-- -->
#                 <img alt="Black Mohair Dotted Hoodie" class="product-thumbnail lazyload" data-srcset="https://img.ssensemedia.com/images/b_white,c_lpad,g_south,h_706,w_470/c_scale,h_280/f_auto,dpr_1.0/191172M202003_1/black-mohair-dotted-hoodie.jpg" src="https://res.cloudinary.com/ssenseweb/image/upload/v1472069180/product-placeholder_qulza9.png"/>
#                </picture>
#                <div class="text-center vspace1" data-v-d5dfea50="">
#                 <p class="medium" data-v-d5dfea50="">
#                  Random Identities
#                 </p>
#                 <p class="price" data-v-d5dfea50="">
#                  <span class="price sale" data-v-d5dfea50="">
#                   $385
#                  </span>
#                  <span class="price" data-v-d5dfea50="">
#                   $262
#                  </span>
#                 </p>
#                </div>
#               </a>
#              </div>
#             </div>
#             <div class="static-related-item" data-v-d5dfea50="">
#              <div class="product-item" data-v-d5dfea50="">
#               <a data-v-d5dfea50="" href="/en-ca/men/product/random-identities/black-cropped-banana-hoodie/5230321">
#                <picture data-v-60b7d3e3="" data-v-d5dfea50="">
#                 <!-- -->
#                 <!-- -->
#                 <img alt="Black Cropped Banana Hoodie" class="product-thumbnail lazyload" data-srcset="https://img.ssensemedia.com/images/b_white,c_lpad,g_south,h_706,w_470/c_scale,h_280/f_auto,dpr_1.0/192172M202053_1/black-cropped-banana-hoodie.jpg" src="https://res.cloudinary.com/ssenseweb/image/upload/v1472069180/product-placeholder_qulza9.png"/>
#                </picture>
#                <div class="text-center vspace1" data-v-d5dfea50="">
#                 <p class="medium" data-v-d5dfea50="">
#                  Random Identities
#                 </p>
#                 <p class="price" data-v-d5dfea50="">
#                  <span class="price sale" data-v-d5dfea50="">
#                   $235
#                  </span>
#                  <span class="price" data-v-d5dfea50="">
#                   $190
#                  </span>
#                 </p>
#                </div>
#               </a>
#              </div>
#             </div>
#             <div class="static-related-item" data-v-d5dfea50="">
#              <div class="product-item" data-v-d5dfea50="">
#               <a data-v-d5dfea50="" href="/en-ca/men/product/random-identities/black-embroidered-zip-up-hoodie/5188641">
#                <picture data-v-60b7d3e3="" data-v-d5dfea50="">
#                 <!-- -->
#                 <!-- -->
#                 <img alt="Black Embroidered Zip-Up Hoodie" class="product-thumbnail lazyload" data-srcset="https://img.ssensemedia.com/images/b_white,c_lpad,g_south,h_706,w_470/c_scale,h_280/f_auto,dpr_1.0/192172M202048_1/black-embroidered-zip-up-hoodie.jpg" src="https://res.cloudinary.com/ssenseweb/image/upload/v1472069180/product-placeholder_qulza9.png"/>
#                </picture>
#                <div class="text-center vspace1" data-v-d5dfea50="">
#                 <p class="medium" data-v-d5dfea50="">
#                  Random Identities
#                 </p>
#                 <p class="price" data-v-d5dfea50="">
#                  <span class="price sale" data-v-d5dfea50="">
#                   $275
#                  </span>
#                  <span class="price" data-v-d5dfea50="">
#                   $248
#                  </span>
#                 </p>
#                </div>
#               </a>
#              </div>
#             </div>
#             <div class="static-related-item" data-v-d5dfea50="">
#              <div class="product-item" data-v-d5dfea50="">
#               <a data-v-d5dfea50="" href="/en-ca/men/product/random-identities/green-faux-leather-hoodie/4808851">
#                <picture data-v-60b7d3e3="" data-v-d5dfea50="">
#                 <!-- -->
#                 <!-- -->
#                 <img alt="Green Faux-Leather Hoodie" class="product-thumbnail lazyload" data-srcset="https://img.ssensemedia.com/images/b_white,c_lpad,g_south,h_706,w_470/c_scale,h_280/f_auto,dpr_1.0/192172M202028_1/green-faux-leather-hoodie.jpg" src="https://res.cloudinary.com/ssenseweb/image/upload/v1472069180/product-placeholder_qulza9.png"/>
#                </picture>
#                <div class="text-center vspace1" data-v-d5dfea50="">
#                 <p class="medium" data-v-d5dfea50="">
#                  Random Identities
#                 </p>
#                 <p class="price" data-v-d5dfea50="">
#                  <span class="price sale" data-v-d5dfea50="">
#                   $950
#                  </span>
#                  <span class="price" data-v-d5dfea50="">
#                   $684
#                  </span>
#                 </p>
#                </div>
#               </a>
#              </div>
#             </div>
#             <div class="static-related-item" data-v-d5dfea50="">
#              <div class="product-item" data-v-d5dfea50="">
#               <a data-v-d5dfea50="" href="/en-ca/men/product/random-identities/white-cropped-sleeveless-hoodie-/4580301">
#                <picture data-v-60b7d3e3="" data-v-d5dfea50="">
#                 <!-- -->
#                 <!-- -->
# ...
#       <div class="row-fluid">
#        <div class="footer-desktop span16 hidden-tablet-landscape" data-v-17f2a208="">
#         <nav class="footer-desktop-right-nav" data-v-17f2a208="" data-v-363cdc87="" role="navigation">
#          <div class="row-fluid">
#           <div class="span16">
#            <ul class="social hide-social-tablet" data-v-363cdc87="">
#             <li>
#              <a aria-label="facebook" class="i facebook" href="//www.facebook.com/SSENSEofficial" target="_blank">
#               <i class="fa fa-facebook fa-fw">
#               </i>
#              </a>
#             </li>
#             <li>
#              <a aria-label="twitter" class="i twitter" href="//twitter.com/ssense" target="_blank">
#               <i class="fa fa-twitter fa-fw">
#               </i>
#              </a>
#             </li>
#             <li>
#              <a aria-label="instagram" class="i instagram" href="//instagram.com/ssense" target="_blank">
#               <i class="fa fa-instagram fa-fw">
#               </i>
#              </a>
#             </li>
#             <li>
#              <a aria-label="youtube" class="i youtube" href="//www.youtube.com/user/ssense" target="_blank">
#               <i class="fa fa-youtube fa-fw">
#               </i>
#              </a>
#             </li>
#            </ul>
#            <ul class="nav footer-links">
#             <li>
#              <a data-current-country="Canada" href="#">
#               COUNTRY/REGION: Canada
#              </a>
#              <div class="popover-center" data-v-363cdc87="" data-v-88391330="">
#               <div class="popover popover-alternate popover-padding no-border" id="footer-country-select">
#                <div class="footer-country-popover popover-alternate" data-v-363cdc87="" data-v-7d47f068="" style="display:block;">
#                 <ul class="country-list" data-v-1011490a="" data-v-7d47f068="">
#                  <div>
#                   <li>
#                    <a href="https://www.ssense.com/en-ca/men/product/random-identities/black-faux-leather-hoodie/5230331">
#                     Canada
#                    </a>
#                   </li>
#                   <li>
#                    <a href="https://www.ssense.com/en-us/men/product/random-identities/black-faux-leather-hoodie/5230331">
#                     United States
#                    </a>
#                   </li>
#                   <li>
#                    <a href="https://www.ssense.com/en-gb/men/product/random-identities/black-faux-leather-hoodie/5230331">
#                     United Kingdom
#                    </a>
#                   </li>
#                   <li>
#                    <a href="https://www.ssense.com/ja-jp/men/product/random-identities/black-faux-leather-hoodie/5230331">
#                     Japan
#                    </a>
#                   </li>
#                   <li>
#                    <a href="https://www.ssense.com/zh-cn/men/product/random-identities/black-faux-leather-hoodie/5230331">
#                     China
#                    </a>
#                   </li>
#                   <li>
#                    <a href="https://www.ssense.com/fr-fr/hommes/produit/random-identities/pull-a-capuche-en-cuir-synthetique-noir/5230331">
#                     France
#                    </a>
#                   </li>
#                  </div>
#                  <!-- -->
#                  <li>
#                   <a data-v-1011490a="" href="/en-ca/countries" rel="nofollow">
#                    <b data-v-1011490a="">
#                     View all
#                    </b>
#                   </a>
#                  </li>
#                 </ul>
#                 <input class="country-search-input" placeholder="SEARCH COUNTRY/REGION" type="text" value=""/>
#                </div>
#               </div>
#              </div>
#             </li>
#             <li>
#              <a href="#">
#               newsletter signup
#              </a>
#              <div class="popover-center" data-v-363cdc87="" data-v-88391330="">
#               <div class="popover popover-alternate popover-padding" id="footer-nl-form">
#                <div data-v-09e96a47="" data-v-363cdc87="">
#                 <!-- -->
#                 <form action="/en-ca/newsletters/subscribers" class="newsletter-form-container" method="POST">
#                  <input id="source" name="source" type="hidden" value="SSENSE_NL_SIGNUP"/>
#                  <div class="row-fluid">
#                   <div class="span16">
#                    <p>
#                     Sign up for email updates and promotions
#                    </p>
#                   </div>
#                   <div class="span16 relative tablet-portrait-full-fluid-width vspace2">
#                    <input autocapitalize="off" autocorrect="off" class="email-input" id="popover-footer_email" name="email" placeholder="Email address" tabindex="1" type="text" value=""/>
#                    <!-- -->
#                   </div>
#                   <div class="relative smartphone-portrait-full-fluid-width genders-container visible span16 vspace1">
#                    <div class="radio-input-wrap">
#                     <input checked="checked" class="capitalize" name="genderFooter" tabindex="2" type="radio" value="men"/>
#                     <label class="capitalize" for="popover-footer_gender_men">
#                      Men
#                     </label>
#                    </div>
#                    <div class="radio-input-wrap">
#                     <input class="capitalize" name="genderFooter" tabindex="2" type="radio" value="women"/>
#                     <label class="capitalize" for="popover-footer_gender_women">
#                      Women
#                     </label>
#                    </div>
#                    <div id="error_genderFooter" style="display:none;">
#                    </div>
#                   </div>
#                   <!-- -->
#                   <div class="span16 vspace1 submit-container visible">
#                    <button class="button full-width lighter" data-v-09e96a47="" type="submit">
#                     <span class="button-label">
#                      subscribe
#                     </span>
#                     <span class="load-wrapper" style="display:none;">
#                      <span class="load-animation">
#                       <span class="dot" style="width:3px;height:3px;border-radius:3px;margin-right:12px;animation:0.44999999999999996s 0s blink step-end infinite;">
#                       </span>
#                       <span class="dot" style="width:3px;height:3px;border-radius:3px;margin-right:12px;animation:0.44999999999999996s 0.075s blink step-end infinite;">
#                       </span>
#                       <span class="dot" style="width:3px;height:3px;border-radius:3px;margin-right:0px;animation:0.44999999999999996s 0.15s blink step-end infinite;">
#                       </span>
#                      </span>
#                     </span>
#                    </button>
#                   </div>
#                   <div class="relative smartphone-portrait-full-fluid-width legal-consent-wrapper span16 visible">
#                    <p class="legal-consent-1">
#                     You may unsubscribe at any time.
#                    </p>
#                    <p>
#                     To find out more, please visit our
#                     <a href="/en-ca/privacy-policy">
#                      Privacy Policy
#                     </a>
#                     .
#                    </p>
#                   </div>
#                  </div>
#                 </form>
#                 <!-- -->
#                </div>
#               </div>
#              </div>
#             </li>
#             <li>
#              <a data-v-363cdc87="" href="/en-ca/customer-service">
#               customer care
#              </a>
#             </li>
#             <li>
#              <a href="#">
#               locations
#              </a>
#              <div class="popover-center footer-location-select" data-v-363cdc87="" data-v-88391330="">
#               <div class="popover popover-alternate" id="footer-locations-select">
#                <ul class="footer-location-select-items" data-v-363cdc87="" data-v-addbeaa0="">
#                 <li>
#                  <a class-active="" data-v-addbeaa0="" href="/en-ca/locations/montreal">
#                   <span data-v-addbeaa0="">
#                    SSENSE MONTRÉAL
#                   </span>
#                  </a>
#                 </li>
#                 <li class="footer-location-select-items-border-top">
#                  <a class-active="" data-v-addbeaa0="" href="/en-ca/appointments">
#                   <span data-v-addbeaa0="">
#                    APPOINTMENTS
#                   </span>
#                  </a>
#                 </li>
#                </ul>
#               </div>
#              </div>
#             </li>
#             <li>
#              <a data-v-363cdc87="" href="/en-ca/editorial">
#               Editorial Archive
#              </a>
#             </li>
#             <li>
#              <a href="/en-ca/careers">
#               careers
#              </a>
#             </li>
#             <li>
#              <a href="/en-ca/affiliates">
#               affiliates
#              </a>
#             </li>
#             <li>
#              <a data-v-363cdc87="" href="/en-ca/sitemap">
#               sitemap
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </nav>
#         <div class="footer-desktop-left-nav" data-v-17f2a208="" data-v-5d95572c="" role="contentinfo">
#          <div class="row-fluid">
#           <div class="span16 flex-straight">
#            <ul class="nav copyright">
#             <li>
#              © 2019 ssense.com
#             </li>
#             <li class="hidden-tablet-landscape">
#              <a data-v-5d95572c="" href="/en-ca/terms-conditions">
#               Terms &amp; Conditions
#              </a>
#             </li>
#             <li class="hidden-tablet-landscape">
#              <a data-v-5d95572c="" href="/en-ca/privacy-policy">
#               Privacy Policy
#              </a>
#             </li>
#             <li>
#              <a data-v-5d95572c="" href="/en-ca/customer-service/accessibility">
#               Accessibility
#              </a>
#             </li>
#            </ul>
#            <ul class="social show-social-tablet" data-v-5d95572c="">
#             <li>
#              <a aria-label="facebook" class="i facebook" href="//www.facebook.com/SSENSEofficial" target="_blank">
#               <i class="fa fa-facebook fa-fw">
#               </i>
#              </a>
#             </li>
#             <li>
#              <a aria-label="twitter" class="i twitter" href="//twitter.com/ssense" target="_blank">
#               <i class="fa fa-twitter fa-fw">
#               </i>
#              </a>
#             </li>
#             <li>
#              <a aria-label="instagram" class="i instagram" href="//instagram.com/ssense" target="_blank">
#               <i class="fa fa-instagram fa-fw">
#               </i>
#              </a>
#             </li>
#             <li>
#              <a aria-label="youtube" class="i youtube" href="//www.youtube.com/user/ssense" target="_blank">
#               <i class="fa fa-youtube fa-fw">
#               </i>
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </footer>
#     <div class="gdpr-popup desktop live-assistance" data-v-198a9b00="" style="display:none;">
#      <p>
#       SSENSE uses cookies that identify your device to provide you with a better online shopping experience, tailored to your preferences.
#      </p>
#      <p>
#       To find out more and learn how to opt out, please visit our
#       <a data-v-198a9b00="" href="/en-ca/privacy-policy">
#        Privacy Policy
#       </a>
#       .
#      </p>
#      <button>
#       accept and close
#      </button>
#     </div>
#     <!-- -->
#    </div>
#   </div>
#   <script>
#    window.INITIAL_STATE={"modals":{"modals":{"size-chart":{"open":false}}},"component":{"name":"ProductDetails","props":{"gender":"men"}},"context":{"isBrowser":false,"viewport":{"width":0,"height":0,"isDesktop":false,"isMobile":false,"isTablet":false,"isTabletMobile":false,"isSmartphone":false},"locale":"en","region":"ca","country":{"name":"Canada","code":"ca","currency":"CAD","showOrigin":true,"priceDisplayRule":"base_price","freeShippingThreshold":100,"shippingThresholds":[{"shippingType":"outbound","thresholds":[{"countryCode":"CA","currencyCode":"CAD","orderMinValue":100,"orderMaxValue":null,"price":0},{"countryCode":"CA","currencyCode":"USD","orderMinValue":null,"orderMaxValue":null,"price":0}]},{"shippingType":"returns","thresholds":[{"countryCode":"CA","currencyCode":"CAD","orderMinValue":null,"orderMaxValue":null,"price":0},{"countryCode":"CA","currencyCode":"USD","orderMinValue":null,"orderMaxValue":null,"price":0}]}]},"title":"Random Identities: Black Faux-Leather Hoodie | SSENSE Canada","alternateUrls":{"en-us":"https:\u002F\u002Fwww.ssense.com\u002Fen-us\u002Fmen\u002Fproduct\u002Frandom-identities\u002Fblack-faux-leather-hoodie\u002F5230331","en-ca":"https:\u002F\u002Fwww.ssense.com\u002Fen-ca\u002Fmen\u002Fproduct\u002Frandom-identities\u002Fblack-faux-leather-hoodie\u002F5230331","en-gb":"https:\u002F\u002Fwww.ssense.com\u002Fen-gb\u002Fmen\u002Fproduct\u002Frandom-identities\u002Fblack-faux-leather-hoodie\u002F5230331","ja-jp":"https:\u002F\u002Fwww.ssense.com\u002Fja-jp\u002Fmen\u002Fproduct\u002Frandom-identities\u002Fblack-faux-leather-hoodie\u002F5230331","fr-fr":"https:\u002F\u002Fwww.ssense.com\u002Ffr-fr\u002Fhommes\u002Fproduit\u002Frandom-identities\u002Fpull-a-capuche-en-cuir-synthetique-noir\u002F5230331","zh-cn":"https:\u002F\u002Fwww.ssense.com\u002Fzh-cn\u002Fmen\u002Fproduct\u002Frandom-identities\u002Fblack-faux-leather-hoodie\u002F5230331"},"hostUrl":"https:\u002F\u002Fwww.ssense.com","gender":"men","isSaleEnabled":true,"isSearchEnabled":true,"isSaleSoon":false,"isFreeShippingEnabled":true,"isNilSearchEnabled":true,"isRetailLinksEnabled":true,"isLiveAssistanceEnabled":true,"isAppointmentsEnabled":true,"isAppointmentSectionEnabled":false,"isAutocompleteEnabled":true,"maxPendingAppointments":2,"liveAssistanceApiKey":"4EUlI6cuYHKKYy7MRbJs2FL8EdPFQrrS","liveAssistanceVersion":"4EUlI6cuYHKKYy7MRbJs2FL8EdPFQrrS","isCaptchaEnabled":true,"isNewLoginCaptchaEnabled":true,"isGoogleHireIFrameEnabled":false,"isGdprPopupEnabled":true,"captchaPublicKey":"6LcJOjkUAAAAAL3zscDofxFZre0jDq_Yi-o24XVh","captchaModules":["pdp","login"],"isSkuCaptchaProtected":false,"gaProperty":"UA-519637-1","displayRemainingStockWishlist":true,"displayRemainingStockPdp":true,"displayRemainingStockCart":true,"geoCountry":{"code":"ca","name":"Canada"},"countryDefaultLanguage":["en-us","ja-jp","fr-fr","zh-cn"],"facets":{"categories":[],"brands":[]},"opaqueHeader":false,"departmentsWithSizeFiltering":[4],"captchaSupportedCountry":true,"displayPrivacyPolicy":true,"china":{"homepageImageUrl":{"men":"","women":""}},"isHongKongFreeReturnEnabled":true,"memberVerification":null,"isLVEnabled":false,"isAlipayBannerEnabled":true,"isGAServerSideEnabled":true,"isFreeReturnBannerEnabled":false,"isNewPDPShippingThresholdsEnabled":true,"isInternalCustomer":false,"environment":"production","isRelatedProductsEnabled":true,"isSizeChartEnabled":true,"isStyledWithEnabled":true,"defaultCountries":[{"code":"ca","lang":"en"},{"code":"us","lang":"en"},{"code":"gb","lang":"en"},{"code":"jp","lang":"ja"},{"code":"cn","lang":"zh"},{"code":"fr","lang":"fr"}],"captchaBlockedCountries":["cn"],"cdnLocation":"img.ssensemedia.com","googleMapAPIKey":"AIzaSyDsCqVhVNjLw6KyPU_pQdErXErFCY6xSmg","newRelicBrowser":"\u003Cscript type='text\u002Fjavascript' \u003Ewindow.NREUM||(NREUM={});NREUM.info = {\"agent\":\"\",\"beacon\":\"bam.nr-data.net\",\"errorBeacon\":\"bam.nr-data.net\",\"licenseKey\":\"901b49cf57\",\"applicationID\":\"233360527\",\"applicationTime\":5.108502,\"tr ...
#   </script>
#   <script src="/assets/manifest.7cc1932d1fccb35f5224.js" type="text/javascript">
#   </script>
#   <script src="/assets/vendor.1b90a8723c89089173c2.js" type="text/javascript">
#   </script>
#   <script src="/assets/app.ae7d67ab604f3795b02d.js" type="text/javascript">
#   </script>
#  </body>
# </html>

# %%
#Getting information of a product on product page.

js = json.loads(product_soup.find_all("script", {"type": "application/ld+json"})[0].get_text())

js
# Out:
# {'@context': 'https://schema.org',
#  '@type': 'Product',
#  'productID': 5230331,
#  'name': 'Black Faux-Leather Hoodie',
#  'sku': '192172M202054',
#  'brand': {'@type': 'Brand', 'name': 'Random Identities'},
#  'offers': {'@type': 'Offer',
#   'price': 761,
#   'priceCurrency': 'CAD',
#   'availability': 'https://schema.org/InStock',
#   'url': '/en-ca/men/product/random-identities/black-faux-leather-hoodie/5230331'},
#  'url': '/en-ca/men/product/random-identities/black-faux-leather-hoodie/5230331',
#  'description': 'Long sleeve grained faux-leather hoodie in black. Bungee-style drawstring at hood. Zip closure at front. Patch pockets at waist. Elasticized cuffs and hem. Raglan sleeves. Full faux-fur lining in green. Silver-tone hardware. \r\n\r\nSupplier color: Black',
#  'image': ['https://res.cloudinary.com/ssenseweb/image/upload/192172M202054_1.jpg',
#   'https://res.cloudinary.com/ssenseweb/image/upload/192172M202054_2.jpg',
#   'https://res.cloudinary.com/ssenseweb/image/upload/192172M202054_3.jpg',
#   'https://res.cloudinary.com/ssenseweb/image/upload/192172M202054_4.jpg',
#   'https://res.cloudinary.com/ssenseweb/image/upload/192172M202054_5.jpg']}

# %% [markdown]
# On product page, it has more info regarding the description of the product which the one on category page does not have.

# %%
#Product name

test_name = js['name']
test_name
# Out:
# 'Black Faux-Leather Hoodie'

# %%
#Product SKU

test_sku = js['sku']
test_sku
# Out:
# '192172M202054'

# %%
#Product Price

test_price = js['offers']['price']
test_price
# Out:
# 761

# %%
#Product Price currency

test_currency = js['offers']['priceCurrency']
test_currency
# Out:
# 'CAD'

# %%
#Product description

test_description = js['description']
test_description
# Out:
# 'Long sleeve grained faux-leather hoodie in black. Bungee-style drawstring at hood. Zip closure at front. Patch pockets at waist. Elasticized cuffs and hem. Raglan sleeves. Full faux-fur lining in green. Silver-tone hardware. \r\n\r\nSupplier color: Black'

# %%
#Product's current sizes

test_size = product_soup.find_all('option')

test_size = [i.get_text().strip() for i in test_size][1:]

print(test_size)
# Out:
# ['XS - Sold Out', 'S', 'L']

# %% [markdown]
# ### Putting Everything Together

# %% [markdown]
# Looping through every pages of each categories to obtain all info (except sizes for now) of all products and combining them together into a list of list

# %%
all_products = []

for i, j in mens_categories.items():
    cat_page = requests.get("https://ssense.com" + j, timeout = 5)
    cat_soup = BeautifulSoup(cat_page.content, 'html.parser')
    cat_page.close()
    
    last_page = int(cat_soup.find_all('li', class_='last-page')[0].get_text())
    
    #first page
    
    num_product = len(cat_soup.find_all("script", {"type": "application/ld+json"}))
    
    for p in range(num_product):
        product_json = json.loads(cat_soup.find_all("script", {"type": "application/ld+json"})[p].get_text())
        
        prod_id = product_json['productID']
        prod_name = product_json['name']
        prod_sku = product_json['sku']
        prod_brand = product_json['brand']['name']
        prod_price = product_json['offers']['price']
        prod_currency = product_json['offers']['priceCurrency']
        prod_url = product_json['url']
        prod_img = product_json['image']                  

        prod_details = [i, prod_id, prod_brand, prod_name, prod_sku, prod_price, prod_currency, prod_url, prod_img]
        
        all_products.append(prod_details)
        
    sleep(5)
        
    for page in range(1,last_page):
        cat_page = requests.get("https://ssense.com" + j + '?page=' + str(page+1), timeout = 5)
        cat_soup = BeautifulSoup(cat_page.content, 'html.parser')
        cat_page.close()
        
        num_product = len(cat_soup.find_all("script", {"type": "application/ld+json"}))

        for p in range(num_product):
            product_json = json.loads(cat_soup.find_all("script", {"type": "application/ld+json"})[p].get_text())
        
            prod_id = product_json['productID']
            prod_name = product_json['name']
            prod_sku = product_json['sku']
            prod_brand = product_json['brand']['name']
            prod_price = product_json['offers']['price']
            prod_currency = product_json['offers']['priceCurrency']
            prod_url = product_json['url']
            prod_img = product_json['image']                  

            prod_details = [i, prod_id, prod_brand, prod_name, prod_sku, prod_price, prod_currency, prod_url, prod_img]
        
            all_products.append(prod_details)
        
        sleep(5)
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     383                     # otherwise it looks like a programming error was the cause.
# --> 384                     six.raise_from(e, None)
#     385         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\Anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#
# ~\Anaconda3\lib\http\client.py in getresponse(self)
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#
# ~\Anaconda3\lib\http\client.py in begin(self)
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#
# ~\Anaconda3\lib\http\client.py in _read_status(self)
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     311             else:
# --> 312                 return self.recv_into(*args, **kwargs)
#     313
#
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     309             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
# --> 310                 raise timeout('The read operation timed out')
#     311             else:
#
# timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeoutError                          Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# ~\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     367             if read is False or not self._is_method_retryable(method):
# --> 368                 raise six.reraise(type(error), error, _stacktrace)
#     369             elif read is not None:
#
# ~\Anaconda3\lib\site-packages\urllib3\packages\six.py in reraise(tp, value, tb)
#     685             raise value.with_traceback(tb)
# --> 686         raise value
#     687
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385         except (SocketTimeout, BaseSSLError, SocketError) as e:
# --> 386             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     387             raise
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _raise_timeout(self, err, url, timeout_value)
#     305         if isinstance(err, SocketTimeout):
# --> 306             raise ReadTimeoutError(self, url, "Read timed out. (read timeout=%s)" % timeout_value)
#     307
#
# ReadTimeoutError: HTTPSConnectionPool(host='www.ssense.com', port=443): Read timed out. (read timeout=5)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# <ipython-input-30-634e46a38c12> in <module>
#      31
#      32     for page in range(1,last_page):
# ---> 33         cat_page = requests.get("https://ssense.com" + j + '?page=' + str(page+1), timeout = 5)
#      34         cat_soup = BeautifulSoup(cat_page.content, 'html.parser')
#      35         cat_page.close()
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     666
#     667         # Resolve redirects if allowed.
# --> 668         history = [resp for resp in gen] if allow_redirects else []
#     669
#     670         # Shuffle things around if there's history.
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in <listcomp>(.0)
#     666
#     667         # Resolve redirects if allowed.
# --> 668         history = [resp for resp in gen] if allow_redirects else []
#     669
#     670         # Shuffle things around if there's history.
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     245                     proxies=proxies,
#     246                     allow_redirects=False,
# --> 247                     **adapter_kwargs
#     248                 )
#     249
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     527                 raise SSLError(e, request=request)
#     528             elif isinstance(e, ReadTimeoutError):
# --> 529                 raise ReadTimeout(e, request=request)
#     530             else:
#     531                 raise
#
# ReadTimeout: HTTPSConnectionPool(host='www.ssense.com', port=443): Read timed out. (read timeout=5)

# %%
#Getting the product description

for prod in all_products:
     
    prod_page = requests.get("https://www.ssense.com/en-ca" + prod[7], timeout = 5)
    prod_soup = BeautifulSoup(prod_page.content, 'html.parser')        
    prod_desc = json.loads(prod_soup.find_all("script", {"type": "application/ld+json"})[0].get_text())['description']
    
    prod.append(prod_desc)
    
    sleep(5)

# %%
print(all_products)
# Out:
# [['ACCESSORIES', 4607571, 'Loewe', 'Blue William De Morgan Edition Dragon Beanie', '201677M138033', 1500, 'CAD', '/men/product/loewe/blue-william-de-morgan-edition-dragon-beanie/4607571', 'https://res.cloudinary.com/ssenseweb/image/upload/201677M138033_1.jpg'], ['ACCESSORIES', 4534841, 'Off-White', 'Black Industrial Belt', '201607M131235', 285, 'CAD', '/men/product/off-white/black-industrial-belt/4534841', 'https://res.cloudinary.com/ssenseweb/image/upload/201607M131235_1.jpg'], ['ACCESSORIES', 4534851, 'Off-White', 'Yellow Industrial Belt', '201607M131236', 285, 'CAD', '/men/product/off-white/yellow-industrial-belt/4534851', 'https://res.cloudinary.com/ssenseweb/image/upload/201607M131236_1.jpg'], ['ACCESSORIES', 4534861, 'Off-White', 'Black Mini Industrial Belt', '201607M131237', 240, 'CAD', '/men/product/off-white/black-mini-industrial-belt/4534861', 'https://res.cloudinary.com/ssenseweb/image/upload/201607M131237_1.jpg'], ['ACCESSORIES', 4534071, 'Off-White', 'Black Quote Yen Wallet', '201607M164199', 400, 'CAD', '/men/product/off-white/black-quote-yen-wallet/4534071', 'https://res.cloudinary.com/ssenseweb/image/upload/201607M164199_1.jpg'], ['ACCESSORIES', 4534221, 'Off-White', 'Black Quote Card Holder', '201607M149208', 265, 'CAD', '/men/product/off-white/black-quote-card-holder/4534221', 'https://res.cloudinary.com/ssenseweb/image/upload/201607M149208_1.jpg'], ['ACCESSORIES', 4534051, 'Off-White', 'Black Quote Passport Holder', '201607M162200', 335, 'CAD', '/men/product/off-white/black-quote-passport-holder/4534051', 'https://res.cloudinary.com/ssenseweb/image/upload/201607M162200_1.jpg'], ['ACCESSORIES', 4534041, 'Off-White', 'Black Logo Passport Holder', '201607M162199', 335, 'CAD', '/men/product/off-white/black-logo-passport-holder/4534041', 'https://res.cloudinary.com/ssenseweb/image/upload/201607M162199_1.jpg'], ['ACCESSORIES', 4534211, 'Off-White', 'Black Logo Card Holder', '201607M163207', 265, 'CAD', '/men/product/off-white/black-logo-card-holder/4534211', 'https://res.cloudinary.com/ssenseweb/image/upload/201607M163207_1.jpg'], ['ACCESSORIES', 4534021, 'Off-White', 'Black Quote Bifold Wallet', '201607M164197', 355, 'CAD', '/men/product/off-white/black-quote-bifold-wallet/4534021', 'https://res.cloudinary.com/ssenseweb/image/upload/201607M164197_1.jpg'], ['ACCESSORIES', 4534871, 'Off-White', 'Yellow Mini Industrial Belt', '201607M131238', 240, 'CAD', '/men/product/off-white/yellow-mini-industrial-belt/4534871', 'https://res.cloudinary.com/ssenseweb/image/upload/201607M131238_1.jpg'], ['ACCESSORIES', 4534101, 'Off-White', 'Black Quote Wallet', '201607M164202', 335, 'CAD', '/men/product/off-white/black-quote-wallet/4534101', 'https://res.cloudinary.com/ssenseweb/image/upload/201607M164202_1.jpg'], ['ACCESSORIES', 4534721, 'Off-White', 'Black & Beige Tape Arrows iPhone XR Case', '201607M153228', 120, 'CAD', '/men/product/off-white/black-and-beige-tape-arrows-iphone-xr-case/4534721', 'https://res.cloudinary.com/ssenseweb/image/upload/201607M153228_1.jpg'], ['ACCESSORIES', 4534731, 'Off-White', 'Black 3D Crossed Off iPhone XS Case', '201607M153229', 135, 'CAD', '/men/product/off-white/black-3d-crossed-off-iphone-xs-case/4534731', 'https://res.cloudinary.com/ssenseweb/image/upload/201607M153229_1.jpg'], ['ACCESSORIES', 4534741, 'Off-White', 'Black Dripping Arrows iPhone XS Max Case', '201607M153230', 135, 'CAD', '/men/product/off-white/black-dripping-arrows-iphone-xs-max-case/4534741', 'https://res.cloudinary.com/ssenseweb/image/upload/201607M153230_1.jpg'], ['ACCESSORIES', 4534251, 'Off-White', 'Black Logo Badge Card Holder', '201607M163210', 310, 'CAD', '/men/product/off-white/black-logo-badge-card-holder/4534251', 'https://res.cloudinary.com/ssenseweb/image/upload/201607M163210_1.jpg'], ['ACCESSORIES', 4572181, 'Off-White', 'Yellow Industrial Necklace Keychain', '201607M148230', 300, 'CAD', '/men/product/off-white/yellow-industrial-necklace-keychain/4572181', 'https://res.cloudinary.com/ssenseweb/image/upload/20160 ...

# %%
len(all_products)
# Out:
# 12277
